# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Category ID for Assigned Items

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
# ## Load Data Files

# %%
consolidated_df = pd.read_csv(os.getcwd() + "/data/Misc/Consolidated_purchases/OK_consol_purchases_march1_april21.csv")
consolidated_df.head()
# Out:
#    invoice_counter invoice_num  invoice_total  item_num   qty  line_amount  \
# 0           252033  M123033004         -172.0     69025 -59.0       -123.9
# 1           252099     0252099          153.3     69025  15.0         31.5
# 2           252100     0252099         -153.3     69025 -15.0        -31.5
# 3           252099     0252099          153.3     68933  14.0         29.4
# 4           252100     0252099         -153.3     68933 -14.0        -29.4
#
#    adj_line_amount   uom  unit_cost             item_descrip  ...  \
# 0           -123.9  each        2.1  CANDIED CINNAMON ALMOND  ...
# 1             31.5  each        2.1  CANDIED CINNAMON ALMOND  ...
# 2            -31.5  each        2.1  CANDIED CINNAMON ALMOND  ...
# 3             29.4  each        2.1     CANDIED COCONUT ALMO  ...
# 4            -29.4  each        2.1     CANDIED COCONUT ALMO  ...
#
#   prod_group_descrip order_code  compute_0022 pak_qty case_qty  purchase_uom  \
# 0     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 1     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 2     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 3     CANDIES SNACKS   KK051093             N     1.0      1.0          each
# 4     CANDIES SNACKS   KK051093             N     1.0      1.0          each
#
#   cat_num  cat_descrip  has_credit credit_pak_amount
# 0       7       Candy            N                 0
# 1       7       Candy            N                 0
# 2       7       Candy            N                 0
# 3       7       Candy            N                 0
# 4       7       Candy            N                 0
#
# [5 rows x 29 columns]

# %%
categories_df = pd.read_csv(os.getcwd() + "/data/Misc/GHG_categories/ghge_factors.csv")
categories_df
# Out:
#     Category ID              Food Category  \
# 0             1        beef & buffalo meat
# 1             2    lamb/mutton & goat meat
# 2             3            pork (pig meat)
# 3             4  poultry (chicken, turkey)
# 4             5                     butter
# ..          ...                        ...
# 58           59          manually adjusted
# 59           60                human labor
# 60           61           kitchen supplies
# 61           62                  mushrooms
# 62           63                      herbs
#
#     Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                             41.3463
# 1                                             41.6211
# 2                                              9.8315
# 3                                              4.3996
# 4                                             11.4316
# ..                                                ...
# 58                                             0.0000
# 59                                             0.0000
# 60                                             0.0000
# 61                                             1.5000
# 62                                             0.5029
#
# [63 rows x 3 columns]

# %%
items_list = pd.read_csv(os.getcwd() + '/data/mapping/Items_List_Assigned.csv')
items_list
# Out:
#        ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0     I-57545           1         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1     I-10869           1             BEEF STIRFRY COV FR     5.00      Kg
# 2      I-7064           1           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3     I-37005           1                  BEEF MEATBALLS     4.54      Kg
# 4     I-37002           1        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...       ...         ...                             ...      ...     ...
# 2816  I-17622          24         WAFFLES BLUBRRY - GF/WF    12.00     box
# 2817  I-45754          55        WATER ACTIVE LEMON LIME     12.00   450ML
# 2818  I-45755          55       WATER ACTIVE ORANGE MANGO    12.00   450ML
# 2819  I-45756          55  WATER ACTIVE STRAWB BLK CHERRY    12.00   450ML
# 2820  I-43251          55    WATER FRUIT 500ML PINEAPPLE     12.00   500ML
#
#       PakQty  PakUOM  InventoryGroup
# 0        1.0      Kg            MEAT
# 1        1.0      Kg            MEAT
# 2        1.0      Kg            MEAT
# 3     1000.0       g            MEAT
# 4     1000.0       g            MEAT
# ...      ...     ...             ...
# 2816     6.0      ea  FOOD - GROCERY
# 2817     1.0   450ML        BEVERAGE
# 2818     1.0   450ML        BEVERAGE
# 2819     1.0   450ML        BEVERAGE
# 2820     1.0  bottle        BEVERAGE
#
# [2821 rows x 8 columns]

# %%
consolidated_df.columns
# Out:
# Index(['invoice_counter', 'invoice_num', 'invoice_total', 'item_num', 'qty',
#        'line_amount', 'adj_line_amount', 'uom', 'unit_cost', 'item_descrip',
#        'invoice_date', 'supplier_name', 'store_num', 'type_bill_credit',
#        'cost_over_ride', 'line_amount_qty', 'case_uom', 'supplier_num',
#        'prod_group_num', 'prod_group_descrip', 'order_code', 'compute_0022',
#        'pak_qty', 'case_qty', 'purchase_uom', 'cat_num', 'cat_descrip',
#        'has_credit', 'credit_pak_amount'],
#       dtype='object')

# %%
# if item_num == items_list ItemId then match the category with it
consolidated_df["item_num"] = consolidated_df["item_num"].astype(str) #Just to avoid warnings
for index, row in consolidated_df.iterrows():
    cos_id = "I-" + str(row['item_num'])
    consolidated_df.loc[index, 'item_num'] = cos_id

# %%
consolidated_df.head()
# Out:
#    invoice_counter invoice_num  invoice_total item_num   qty  line_amount  \
# 0           252033  M123033004         -172.0  I-69025 -59.0       -123.9
# 1           252099     0252099          153.3  I-69025  15.0         31.5
# 2           252100     0252099         -153.3  I-69025 -15.0        -31.5
# 3           252099     0252099          153.3  I-68933  14.0         29.4
# 4           252100     0252099         -153.3  I-68933 -14.0        -29.4
#
#    adj_line_amount   uom  unit_cost             item_descrip  ...  \
# 0           -123.9  each        2.1  CANDIED CINNAMON ALMOND  ...
# 1             31.5  each        2.1  CANDIED CINNAMON ALMOND  ...
# 2            -31.5  each        2.1  CANDIED CINNAMON ALMOND  ...
# 3             29.4  each        2.1     CANDIED COCONUT ALMO  ...
# 4            -29.4  each        2.1     CANDIED COCONUT ALMO  ...
#
#   prod_group_descrip order_code  compute_0022 pak_qty case_qty  purchase_uom  \
# 0     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 1     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 2     CANDIES SNACKS   KK051094             N     1.0      1.0          each
# 3     CANDIES SNACKS   KK051093             N     1.0      1.0          each
# 4     CANDIES SNACKS   KK051093             N     1.0      1.0          each
#
#   cat_num  cat_descrip  has_credit credit_pak_amount
# 0       7       Candy            N                 0
# 1       7       Candy            N                 0
# 2       7       Candy            N                 0
# 3       7       Candy            N                 0
# 4       7       Candy            N                 0
#
# [5 rows x 29 columns]

# %%
# Create an empty list to store the matching CategoryID values
category_ids = []

# Iterate over each row in consolidated_df
for index, row in consolidated_df.iterrows():
    item_num = row['item_num']
    
    if item_num in items_list['ItemId'].values:
        category_id = items_list.loc[items_list['ItemId'] == item_num, 'CategoryID'].values[0]
        category_ids.append(category_id)
    else:
        category_ids.append(None) 

# Add the category_ids list as a new column to consolidated_df
consolidated_df['Items_assign_category_ID'] = category_ids

# %%
consolidated_df.head()
# Out:
#    invoice_counter invoice_num  invoice_total item_num   qty  line_amount  \
# 0           252033  M123033004         -172.0  I-69025 -59.0       -123.9
# 1           252099     0252099          153.3  I-69025  15.0         31.5
# 2           252100     0252099         -153.3  I-69025 -15.0        -31.5
# 3           252099     0252099          153.3  I-68933  14.0         29.4
# 4           252100     0252099         -153.3  I-68933 -14.0        -29.4
#
#    adj_line_amount   uom  unit_cost             item_descrip  ... order_code  \
# 0           -123.9  each        2.1  CANDIED CINNAMON ALMOND  ...   KK051094
# 1             31.5  each        2.1  CANDIED CINNAMON ALMOND  ...   KK051094
# 2            -31.5  each        2.1  CANDIED CINNAMON ALMOND  ...   KK051094
# 3             29.4  each        2.1     CANDIED COCONUT ALMO  ...   KK051093
# 4            -29.4  each        2.1     CANDIED COCONUT ALMO  ...   KK051093
#
#   compute_0022  pak_qty case_qty purchase_uom  cat_num cat_descrip  \
# 0            N      1.0      1.0         each        7      Candy
# 1            N      1.0      1.0         each        7      Candy
# 2            N      1.0      1.0         each        7      Candy
# 3            N      1.0      1.0         each        7      Candy
# 4            N      1.0      1.0         each        7      Candy
#
#    has_credit  credit_pak_amount Items_assign_category_ID
# 0           N                  0                      NaN
# 1           N                  0                      NaN
# 2           N                  0                      NaN
# 3           N                  0                      NaN
# 4           N                  0                      NaN
#
# [5 rows x 30 columns]

# %%
# Sort the dataframe by 'item_num' and 'qty'
consolidated_df.sort_values(by=['item_num', 'qty'], inplace=True)

# Find the rows to keep
rows_to_keep = []
prev_item_num = None

for index, row in consolidated_df.iterrows():
    if row['item_num'] != prev_item_num:
        rows_to_keep.append(index)
        prev_item_num = row['item_num']
    elif row['qty'] < 0:
        rows_to_keep.pop()
        rows_to_keep.append(index)

# Filter the dataframe to keep the selected rows
unique_rows = consolidated_df.loc[rows_to_keep]

# Display the unique rows
unique_rows
# Out:
#        invoice_counter invoice_num  invoice_total item_num  qty  line_amount  \
# 11476           247768  1061818515         216.40  I-10117  1.0         6.90
# 287             247973  9001094224        8190.64   I-1016  1.0        69.53
# 73              247973  9001094224        8190.64   I-1020  1.0        57.18
# 215             248086  9001070978         520.60   I-1028  1.0        42.24
# 3381            251703  9001385802        1271.19   I-1033  1.0        51.20
# ...                ...         ...            ...      ...  ...          ...
# 3185            252584      311232         125.84   I-9641  1.0        18.00
# 7016            247853     0247852         -19.40   I-9687 -2.0       -19.40
# 6304            248149  9001111671        1062.80   I-9830  1.0        42.66
# 13405           248299  1061818077        1640.75   I-9831  2.0         8.60
# 10811           248317  1061818516         272.60   I-9832  1.0        51.80
#
#        adj_line_amount    uom  unit_cost                    item_descrip  ...  \
# 11476             6.90    pak       6.90                HERB MINT BC 4OZ  ...
# 287              69.53     cs      69.53  BROWNIE ROCKY ROAD 12X16IN TFC  ...
# 73               57.18     cs      57.18     BAR NANAIMO SCORED 12X16IN   ...
# 215              42.24     cs      42.24    BREAD NAAN ORIGINAL TEARDROP  ...
# 3381             51.20     cs      51.20          PITA GREEK THK 7IN TFC  ...
# ...                ...    ...        ...                             ...  ...
# 3185             18.00  SHEET      18.00        FOCACCIA HERB FULL SHEET  ...
# 7016            -19.40     Kg       9.70         PASTE MISO YELLOW SHIRO  ...
# 6304             42.66     cs      42.66            GRAVY MIX POUTINE GF  ...
# 13405             8.60    bag       4.30             RADISH BUNCHED 48CT  ...
# 10811            51.80     cs      51.80                          DAIKON  ...
#
#       order_code compute_0022  pak_qty case_qty purchase_uom  cat_num  \
# 11476     680804            N      1.0      4.0          pak        2
# 287      5801205            N      1.0      2.0           cs        2
# 73       1174120            N      1.0      2.0           cs        2
# 215      1290728            N      1.0     48.0           cs        2
# 3381     1346507            N      1.0    120.0           cs        2
# ...          ...          ...      ...      ...          ...      ...
# 3185        3902            N      1.0      1.0        SHEET        2
# 7016     0412106            N      1.0      1.0           Kg        2
# 6304     1253421            N    453.0      6.0           cs        2
# 13405    0258025            N      1.0      3.0          bag        2
# 10811    0280948            N      1.0     40.0           cs        2
#
#       cat_descrip  has_credit  credit_pak_amount Items_assign_category_ID
# 11476        Food           Y                  0                     40.0
# 287          Food           N                  0                     24.0
# 73           Food           N                  0                     24.0
# 215          Food           N                  0                     24.0
# 3381         Food           N                  0                     24.0
# ...           ...         ...                ...                      ...
# 3185         Food           Y                  0                     24.0
# 7016         Food           N                  0                     20.0
# 6304         Food           N                  0                     58.0
# 13405        Food           N                  0                     36.0
# 10811        Food           Y                  0                     38.0
#
# [1103 rows x 30 columns]

# %%
# Filter rows with no NaN values in "Items_assign_category_ID" from unique_rows DataFrame
filtered_df = unique_rows[~pd.isnull(unique_rows['Items_assign_category_ID'])]

# Print the filtered DataFrame
filtered_df
# Out:
#        invoice_counter invoice_num  invoice_total item_num  qty  line_amount  \
# 11476           247768  1061818515         216.40  I-10117  1.0         6.90
# 287             247973  9001094224        8190.64   I-1016  1.0        69.53
# 73              247973  9001094224        8190.64   I-1020  1.0        57.18
# 215             248086  9001070978         520.60   I-1028  1.0        42.24
# 3381            251703  9001385802        1271.19   I-1033  1.0        51.20
# ...                ...         ...            ...      ...  ...          ...
# 3185            252584      311232         125.84   I-9641  1.0        18.00
# 7016            247853     0247852         -19.40   I-9687 -2.0       -19.40
# 6304            248149  9001111671        1062.80   I-9830  1.0        42.66
# 13405           248299  1061818077        1640.75   I-9831  2.0         8.60
# 10811           248317  1061818516         272.60   I-9832  1.0        51.80
#
#        adj_line_amount    uom  unit_cost                    item_descrip  ...  \
# 11476             6.90    pak       6.90                HERB MINT BC 4OZ  ...
# 287              69.53     cs      69.53  BROWNIE ROCKY ROAD 12X16IN TFC  ...
# 73               57.18     cs      57.18     BAR NANAIMO SCORED 12X16IN   ...
# 215              42.24     cs      42.24    BREAD NAAN ORIGINAL TEARDROP  ...
# 3381             51.20     cs      51.20          PITA GREEK THK 7IN TFC  ...
# ...                ...    ...        ...                             ...  ...
# 3185             18.00  SHEET      18.00        FOCACCIA HERB FULL SHEET  ...
# 7016            -19.40     Kg       9.70         PASTE MISO YELLOW SHIRO  ...
# 6304             42.66     cs      42.66            GRAVY MIX POUTINE GF  ...
# 13405             8.60    bag       4.30             RADISH BUNCHED 48CT  ...
# 10811            51.80     cs      51.80                          DAIKON  ...
#
#       order_code compute_0022  pak_qty case_qty purchase_uom  cat_num  \
# 11476     680804            N      1.0      4.0          pak        2
# 287      5801205            N      1.0      2.0           cs        2
# 73       1174120            N      1.0      2.0           cs        2
# 215      1290728            N      1.0     48.0           cs        2
# 3381     1346507            N      1.0    120.0           cs        2
# ...          ...          ...      ...      ...          ...      ...
# 3185        3902            N      1.0      1.0        SHEET        2
# 7016     0412106            N      1.0      1.0           Kg        2
# 6304     1253421            N    453.0      6.0           cs        2
# 13405    0258025            N      1.0      3.0          bag        2
# 10811    0280948            N      1.0     40.0           cs        2
#
#       cat_descrip  has_credit  credit_pak_amount Items_assign_category_ID
# 11476        Food           Y                  0                     40.0
# 287          Food           N                  0                     24.0
# 73           Food           N                  0                     24.0
# 215          Food           N                  0                     24.0
# 3381         Food           N                  0                     24.0
# ...           ...         ...                ...                      ...
# 3185         Food           Y                  0                     24.0
# 7016         Food           N                  0                     20.0
# 6304         Food           N                  0                     58.0
# 13405        Food           N                  0                     36.0
# 10811        Food           Y                  0                     38.0
#
# [817 rows x 30 columns]

# %%
assigned_data = pd.read_csv(os.getcwd() + '/data/Misc/GHG_categories/GHG_assigned_data.csv')
assigned_data
# Out:
#        invoice_counter invoice_num  invoice_total  item_num   qty  \
# 0               247973  9001094224        8190.64      1016   1.0
# 1               248381  9001112003        5367.66      1016   1.0
# 2               248383  9001132129        4406.91      1016   1.0
# 3               248663  9001144510        9116.11      1016   1.0
# 4               248997  9001185341        7931.74      1016   1.0
# ...                ...         ...            ...       ...   ...
# 18381           249360     5200356         213.43     70875   2.0
# 18382           251688     5204180         265.48     70875   2.0
# 18383           252734     5206230         265.48     70875   2.0
# 18384           248077    05197159        1042.32     70875  18.0
# 18385           249821    05201007        1368.05     70875  18.0
#
#        line_amount  adj_line_amount uom  unit_cost  \
# 0            69.53            69.53  cs      69.53
# 1            69.53            69.53  cs      69.53
# 2            69.53            69.53  cs      69.53
# 3            69.53            69.53  cs      69.53
# 4            69.53            69.53  cs      69.53
# ...            ...              ...  ..        ...
# 18381        87.36            87.36  BX      43.68
# 18382        89.56            89.56  BX      44.78
# 18383        89.56            89.56  BX      44.78
# 18384       796.32           796.32  BX      44.24
# 18385       796.32           796.32  BX      44.24
#
#                          item_descrip  ... compute_0022 pak_qty  case_qty  \
# 0      brownie rocky road 12x16in tfc  ...            N     1.0       2.0
# 1      brownie rocky road 12x16in tfc  ...            N     1.0       2.0
# 2      brownie rocky road 12x16in tfc  ...            N     1.0       2.0
# 3      brownie rocky road 12x16in tfc  ...            N     1.0       2.0
# 4      brownie rocky road 12x16in tfc  ...            N     1.0       2.0
# ...                               ...  ...          ...     ...       ...
# 18381                 beef medium grd  ...            N     1.0       5.0
# 18382                 beef medium grd  ...            N     1.0       5.0
# 18383                 beef medium grd  ...            N     1.0       5.0
# 18384                 beef medium grd  ...            N     1.0       5.0
# 18385                 beef medium grd  ...            N     1.0       5.0
#
#       purchase_uom cat_num  cat_descrip has_credit  credit_pak_amount  \
# 0               cs       2         Food          N                  0
# 1               cs       2         Food          N                  0
# 2               cs       2         Food          N                  0
# 3               cs       2         Food          N                  0
# 4               cs       2         Food          N                  0
# ...            ...     ...          ...        ...                ...
# 18381           BX       2         Food          N                  0
# 18382           BX       2         Food          Y                  0
# 18383           BX       2         Food          Y                  0
# 18384           BX       2         Food          Y                  0
# 18385           BX       2         Food          Y                  0
#
#                                Food Category Category ID
# 0      wheat/rye (bread, pasta, baked goods)        24.0
# 1      wheat/rye (bread, pasta, baked goods)        24.0
# 2      wheat/rye (bread, pasta, baked goods)        24.0
# 3      wheat/rye (bread, pasta, baked goods)        24.0
# 4      wheat/rye (bread, pasta, baked goods)        24.0
# ...                                      ...         ...
# 18381                    beef & buffalo meat         1.0
# 18382                    beef & buffalo meat         1.0
# 18383                    beef & buffalo meat         1.0
# 18384                    beef & buffalo meat         1.0
# 18385                    beef & buffalo meat         1.0
#
# [18386 rows x 31 columns]

# %%
# filtered_df.rename(columns={'Items_assign_category_ID': 'Category ID'}, inplace=True)
assigned_data["item_num"] = assigned_data["item_num"].astype(str) #Just to avoid warnings
for index, row in assigned_data.iterrows():
    cos_id = "I-" + str(row['item_num'])
    assigned_data.loc[index, 'item_num'] = cos_id

# %%
for index, row in filtered_df.iterrows():
    get_r = assigned_data.loc[assigned_data['item_num'] == row['item_num']]
    if not get_r.empty:
        Category_ID = get_r['Category ID'].values[0]
        filtered_df.loc[index, 'Category ID'] = Category_ID
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_3077/1008378781.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.loc[index, 'Category ID'] = Category_ID

# %%
filtered_df
# Out:
#        invoice_counter invoice_num  invoice_total item_num  qty  line_amount  \
# 11476           247768  1061818515         216.40  I-10117  1.0         6.90
# 287             247973  9001094224        8190.64   I-1016  1.0        69.53
# 73              247973  9001094224        8190.64   I-1020  1.0        57.18
# 215             248086  9001070978         520.60   I-1028  1.0        42.24
# 3381            251703  9001385802        1271.19   I-1033  1.0        51.20
# ...                ...         ...            ...      ...  ...          ...
# 3185            252584      311232         125.84   I-9641  1.0        18.00
# 7016            247853     0247852         -19.40   I-9687 -2.0       -19.40
# 6304            248149  9001111671        1062.80   I-9830  1.0        42.66
# 13405           248299  1061818077        1640.75   I-9831  2.0         8.60
# 10811           248317  1061818516         272.60   I-9832  1.0        51.80
#
#        adj_line_amount    uom  unit_cost                    item_descrip  ...  \
# 11476             6.90    pak       6.90                HERB MINT BC 4OZ  ...
# 287              69.53     cs      69.53  BROWNIE ROCKY ROAD 12X16IN TFC  ...
# 73               57.18     cs      57.18     BAR NANAIMO SCORED 12X16IN   ...
# 215              42.24     cs      42.24    BREAD NAAN ORIGINAL TEARDROP  ...
# 3381             51.20     cs      51.20          PITA GREEK THK 7IN TFC  ...
# ...                ...    ...        ...                             ...  ...
# 3185             18.00  SHEET      18.00        FOCACCIA HERB FULL SHEET  ...
# 7016            -19.40     Kg       9.70         PASTE MISO YELLOW SHIRO  ...
# 6304             42.66     cs      42.66            GRAVY MIX POUTINE GF  ...
# 13405             8.60    bag       4.30             RADISH BUNCHED 48CT  ...
# 10811            51.80     cs      51.80                          DAIKON  ...
#
#       compute_0022 pak_qty  case_qty purchase_uom cat_num  cat_descrip  \
# 11476            N     1.0       4.0          pak       2         Food
# 287              N     1.0       2.0           cs       2         Food
# 73               N     1.0       2.0           cs       2         Food
# 215              N     1.0      48.0           cs       2         Food
# 3381             N     1.0     120.0           cs       2         Food
# ...            ...     ...       ...          ...     ...          ...
# 3185             N     1.0       1.0        SHEET       2         Food
# 7016             N     1.0       1.0           Kg       2         Food
# 6304             N   453.0       6.0           cs       2         Food
# 13405            N     1.0       3.0          bag       2         Food
# 10811            N     1.0      40.0           cs       2         Food
#
#       has_credit  credit_pak_amount  Items_assign_category_ID Category ID
# 11476          Y                  0                      40.0        63.0
# 287            N                  0                      24.0        24.0
# 73             N                  0                      24.0        24.0
# 215            N                  0                      24.0        24.0
# 3381           N                  0                      24.0        24.0
# ...          ...                ...                       ...         ...
# 3185           Y                  0                      24.0        24.0
# 7016           N                  0                      20.0        58.0
# 6304           N                  0                      58.0        54.0
# 13405          N                  0                      36.0         NaN
# 10811          Y                  0                      38.0        36.0
#
# [817 rows x 31 columns]

# %%
#Change by Vivaan on 28th May
# Create a DataFrame containing only rows where 'Items_assign_category_ID' is not equal to 'Category ID'
need_to_manually_check_data = filtered_df[filtered_df['Items_assign_category_ID'] != filtered_df['Category ID']]

# %%
# check to see if automated approach is correctly assigning items to the right category
need_to_manually_check_data
# Out:
#        invoice_counter invoice_num  invoice_total item_num  qty  line_amount  \
# 11476           247768  1061818515         216.40  I-10117  1.0         6.90
# 8865            247877  9001094408        7899.82  I-10503  4.0       344.56
# 8420            249278  1061820702        2206.80  I-10611  1.0        49.25
# 553             247972  9001070965        4973.26   I-1064  1.0       111.33
# 11514           248312  1061818519        4630.10  I-10758  1.0        11.30
# ...                ...         ...            ...      ...  ...          ...
# 8354            248354  9001070972        5360.83   I-9382  1.0        19.29
# 7016            247853     0247852         -19.40   I-9687 -2.0       -19.40
# 6304            248149  9001111671        1062.80   I-9830  1.0        42.66
# 13405           248299  1061818077        1640.75   I-9831  2.0         8.60
# 10811           248317  1061818516         272.60   I-9832  1.0        51.80
#
#        adj_line_amount    uom  unit_cost                    item_descrip  ...  \
# 11476             6.90    pak       6.90                HERB MINT BC 4OZ  ...
# 8865            344.56     cs      86.14  HOT DOG PLANT BASED WIENER FZN  ...
# 8420             49.25     cs      49.25                 WON TON WRAPPER  ...
# 553             111.33     cs     111.33       CAKE STRAWBERRY CREAM TFC  ...
# 11514            11.30  BUNCH      11.30            HERB TARRAGON BC 4oz  ...
# ...                ...    ...        ...                             ...  ...
# 8354             19.29     cs      19.29        VINEGAR APPLE CIDER PURE  ...
# 7016            -19.40     Kg       9.70         PASTE MISO YELLOW SHIRO  ...
# 6304             42.66     cs      42.66            GRAVY MIX POUTINE GF  ...
# 13405             8.60    bag       4.30             RADISH BUNCHED 48CT  ...
# 10811            51.80     cs      51.80                          DAIKON  ...
#
#       compute_0022 pak_qty  case_qty purchase_uom cat_num  cat_descrip  \
# 11476            N     1.0       4.0          pak       2         Food
# 8865             N     4.0       1.0           cs       2         Food
# 8420             N     1.0       1.0           lb       2         Food
# 553              N    30.0       2.0           cs       2         Food
# 11514            N     4.0       1.0        BUNCH       2         Food
# ...            ...     ...       ...          ...     ...          ...
# 8354             N     5.0       2.0           cs       2         Food
# 7016             N     1.0       1.0           Kg       2         Food
# 6304             N   453.0       6.0           cs       2         Food
# 13405            N     1.0       3.0          bag       2         Food
# 10811            N     1.0      40.0           cs       2         Food
#
#       has_credit  credit_pak_amount  Items_assign_category_ID Category ID
# 11476          Y                  0                      40.0        63.0
# 8865           N                  0                       1.0         NaN
# 8420           N                  0                      24.0         NaN
# 553            N                  0                      24.0         8.0
# 11514          Y                  0                      58.0        63.0
# ...          ...                ...                       ...         ...
# 8354           N                  0                      57.0        32.0
# 7016           N                  0                      20.0        58.0
# 6304           N                  0                      58.0        54.0
# 13405          N                  0                      36.0         NaN
# 10811          Y                  0                      38.0        36.0
#
# [233 rows x 31 columns]

# %%
# Unfilter rows with NaN values in "Items_assign_category_ID" and unique item_num
# unfiltered_df = consolidated_df[pd.isnull(consolidated_df['Items_assign_category_ID']) & ~consolidated_df['item_num'].duplicated(keep=False)]
unfiltered_df = unique_rows[pd.isnull(unique_rows['Items_assign_category_ID'])]

for index, row in unfiltered_df.iterrows():
    get_r = assigned_data.loc[assigned_data['item_num'] == row['item_num']]
    if not get_r.empty:
        Category_ID = get_r['Category ID'].values[0]
        unfiltered_df.loc[index, 'Category ID'] = Category_ID
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_3077/1617589581.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unfiltered_df.loc[index, 'Category ID'] = Category_ID

# %%
# Create a DataFrame containing only rows where 'Items_assign_category_ID' is not equal to 'Category ID'
not_assigned_from_list_method = unfiltered_df[unfiltered_df['Items_assign_category_ID'] != unfiltered_df['Category ID']]

# %%
# Create a dictionary mapping Category ID to Food Category from categories_df
category_dict = categories_df.set_index('Category ID')['Food Category'].to_dict()

# Create a new column "Category" in unfiltered_df based on the Category ID values
unfiltered_df['Category'] = unfiltered_df['Category ID'].map(category_dict)

# Print the updated unfiltered_df DataFrame
unfiltered_df
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_3077/2307717775.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unfiltered_df['Category'] = unfiltered_df['Category ID'].map(category_dict)
#        invoice_counter invoice_num  invoice_total item_num  qty  line_amount  \
# 12585           248143  1061818523         711.90  I-10482  1.0         6.20
# 519             247972  9001070965        4973.26   I-1063  1.0        50.31
# 671             250775  9001346509        1370.36   I-1084  1.0        28.60
# 1404            251903  9001459647        6270.89   I-1086  4.0       218.56
# 1356            249799  9001259668        5011.22   I-1091  2.0       116.60
# ...                ...         ...            ...      ...  ...          ...
# 15316           250914    00022966         357.14  I-70756  1.0        70.00
# 8603            251629  0000869104         968.35  I-70806  4.0       192.00
# 8612            248410  0000860921        1872.55  I-70837  4.0       192.00
# 8750            247689     5197332         263.28  I-70875  2.0        87.36
# 3350            247563      546291         214.00   I-8100  2.0        12.24
#
#        adj_line_amount  uom  unit_cost                    item_descrip  ...  \
# 12585             6.20   cs       6.20                ONIONS JUMBO 5lb  ...
# 519              50.31   CA      50.31   CAKE SHEET SLAB ORANGE CITRUS  ...
# 671              28.60   cs      28.60        COOKIE DBL CHOC CHIP T/S  ...
# 1404            218.56   cs      54.64  COOKIE DOUGH CHOC CHIP N/HYDRO  ...
# 1356            116.60   cs      58.30  COOKIE DOUGH  WHITE CHOC MACA   ...
# ...                ...  ...        ...                             ...  ...
# 15316            70.00   ea      70.00  CK|BULK|Seasonal Chia/ Oat 8kg  ...
# 8603            192.00  TUB      48.00        ICE CREAM ESPRESSO 11.4L  ...
# 8612            192.00  TUB      48.00         ICE CREAM VANILLA 11.4L  ...
# 8750             87.36   BX      43.68                 BEEF MEDIUM GRD  ...
# 3350             12.24   CT       6.12        LOAF WHWHT 3/4 SANDWICH   ...
#
#       pak_qty case_qty  purchase_uom cat_num cat_descrip  has_credit  \
# 12585     1.0      5.0            cs       2        Food           N
# 519       1.0      2.0            CA       2        Food           N
# 671       1.0     72.0            cs       2        Food           N
# 1404      1.0    128.0            cs       2        Food           Y
# 1356      1.0    128.0            cs       2        Food           N
# ...       ...      ...           ...     ...         ...         ...
# 15316     1.0      1.0            ea       2        Food           N
# 8603     11.4      1.0           TUB       2        Food           N
# 8612     11.4      1.0           TUB       2        Food           N
# 8750      1.0      5.0            BX       2        Food           N
# 3350      1.0      1.0            CT       2        Food           Y
#
#       credit_pak_amount  Items_assign_category_ID  Category ID  \
# 12585                 0                       NaN         39.0
# 519                   0                       NaN         24.0
# 671                   0                       NaN         41.0
# 1404                  0                       NaN         24.0
# 1356                  0                       NaN         24.0
# ...                 ...                       ...          ...
# 15316                 0                       NaN         26.0
# 8603                  0                       NaN          7.0
# 8612                  0                       NaN          7.0
# 8750                  0                       NaN          1.0
# 3350                  0                       NaN         24.0
#
#                                     Category
# 12585                       onions and leeks
# 519    wheat/rye (bread, pasta, baked goods)
# 671                                 potatoes
# 1404   wheat/rye (bread, pasta, baked goods)
# 1356   wheat/rye (bread, pasta, baked goods)
# ...                                      ...
# 15316                    tree nuts and seeds
# 8603                               ice cream
# 8612                               ice cream
# 8750                     beef & buffalo meat
# 3350   wheat/rye (bread, pasta, baked goods)
#
# [286 rows x 32 columns]

# %%
unfiltered_df.to_csv(os.getcwd() + '/data/Misc/GHG_categories/selected_unassigned_GHG_categories.csv', index = False)

# %%
unfiltered_df.shape
# Out:
# (286, 32)

# %%
unfiltered_df.head(60)
# Out:
#        invoice_counter invoice_num  invoice_total item_num    qty  \
# 12585           248143  1061818523         711.90  I-10482   1.00
# 519             247972  9001070965        4973.26   I-1063   1.00
# 671             250775  9001346509        1370.36   I-1084   1.00
# 1404            251903  9001459647        6270.89   I-1086   4.00
# 1356            249799  9001259668        5011.22   I-1091   2.00
# 1409            249799  9001259668        5011.22   I-1094   2.00
# 1608            251190  2000155272        -145.52  I-11052  -1.00
# 9373            251701  1061826032         216.25  I-11078   1.00
# 17487           249084    IN161559         630.22  I-11173   1.00
# 8393            248533     2035373        4083.92  I-11575   1.00
# 6597            248533     2035373        4083.92  I-11579   1.00
# 8405            250390     2043233        5728.31  I-11587   8.00
# 18037           250257  9001312343        6348.98  I-11763   4.00
# 9066            250442    05200978        6001.27  I-13424  10.00
# 8605            249032  0000860923         906.35  I-13551   2.00
# 8598            249032  0000860923         906.35  I-13553   2.00
# 8582            248597  0000862469        1132.35  I-13630   2.00
# 2522            248964  INV1215107         236.08  I-13756   2.00
# 706             248888     0248887        -676.69  I-13787  -1.00
# 13974           249482  1061819938          47.70  I-13898   1.00
# 4502            249266  6881010175         306.80  I-14040   1.00
# 8604            250731  0000867149         584.35  I-14305   3.00
# 18277           251363  9001385785         714.58  I-15334   1.00
# 2519            248040    71990539        2594.21   I-1568   1.00
# 2524            252207  INV1215570        1198.68   I-1577   6.00
# 2525            248433  INV1214974         478.36   I-1578   6.00
# 2547            252207  INV1215570        1198.68   I-1583   6.00
# 2449            247802  3192799647         885.95   I-1609   1.00
# 61              248844  9001112005        5870.81  I-16095   1.00
# 8931            248066  9001094419        1210.05  I-16135   1.00
# 2704            250181  9001216349         409.91   I-1633   1.00
# 1711            248012  3192835967        1794.57   I-1652   1.00
# 2283            251938     0251937        -299.27   I-1697 -75.00
# 2286            247802  3192799647         885.95   I-1707   1.00
# 2438            249117  9001195351         755.45   I-1719   1.00
# 2461            248012  3192835967        1794.57   I-1735   1.00
# 3415            248505  9001133184         903.53  I-17626   2.00
# 8930            251596    05204510        2184.48  I-17677   3.00
# 1939            248517     0248516         -26.39   I-1770  -1.00
# 1954            251640  2000165380        -365.19   I-1772 -10.00
# 17938           249796    06565767        -485.19  I-18641  -3.00
# 18095           247973  9001094224        8190.64  I-19169   1.00
# 7051            249089    71996424        1302.76  I-19567   1.00
# 9424            249405     0249404         -76.78  I-19636  -2.00
# 17655           248384  9001144506        4418.22   I-2016   1.00
# 17657           247874  9001070944        8370.49   I-2020   1.00
# 17670           247973  9001094224        8190.64   I-2026   1.00
# 17692           250988     0250987         -41.76   I-2027  -2.00
# 17757           250176  9001260319        1119.50   I-2036   1.00
# 17759           248844  9001112005        5870.81   I-2038   1.00
# 18034           250308  9001283316        7626.41  I-20435   1.00
# 17792           248362  9001094414        7971.34   I-2048   1.00
# 4512            251674  1061824518         131.42   I-2071   6.00
# 4418            247891  9001111653        1171.74   I-2161   1.00
# 5123            249038     2318855         900.24   I-2168  12.00
# 5276            250526  6881010358         421.33   I-2193   1.00
# 3169            252524  9001502072         430.47  I-22490   1.00
# 8712            251765  9001416314         979.00  I-22634   3.18
# 17836           248844  9001112005        5870.81   I-2381   1.00
# 17872           248686  9001094263        4305.55   I-2386   1.00
#
#        line_amount  adj_line_amount     uom  unit_cost  \
# 12585         6.20            6.200      cs       6.20
# 519          50.31           50.310      CA      50.31
# 671          28.60           28.600      cs      28.60
# 1404        218.56          218.560      cs      54.64
# 1356        116.60          116.600      cs      58.30
# 1409        106.78          106.780      cs      53.39
# 1608        -40.64          -40.640      ea      40.64
# 9373          9.75            9.750      cs       9.75
# 17487        74.74           74.740      cs      74.74
# 8393         61.11           61.110      ea      61.11
# 6597         14.45           14.450      CT      14.45
# 8405         75.60           75.600    each       9.45
# 18037        38.76           38.760      CT       9.69
# 9066       1001.50         1001.500      cs     100.15
# 8605         96.00           96.000     TUB      48.00
# 8598         96.00           96.000     TUB      48.00
# 8582         96.00           96.000     TUB      48.00
# 2522         25.42           25.420   750ML      12.71
# 706         -20.60          -20.600      cs      20.60
# 13974        31.75           31.750      cs      31.75
# 4502         10.46           10.460      cs      10.46
# 8604        144.00          144.000     TUB      48.00
# 18277        59.52           59.520      CA      59.52
# 2519         22.39           22.390  bottle      22.39
# 2524         76.26           76.260   750ML      12.71
# 2525         76.26           76.260   750ML      12.71
# 2547         76.26           76.260   750ML      12.71
# 2449         30.02           30.020      CA      30.02
# 61           56.10           56.100      cs      56.10
# 8931        131.16          131.160      cs     131.16
# 2704          5.77            5.770      CA       5.77
# 1711         15.91           15.910      cs      15.91
# 2283       -164.25         -164.250   473ML       2.19
# 2286         30.02           30.020      CA      30.02
# 2438         14.87           14.870      cs      14.87
# 2461         15.91           15.910      cs      15.91
# 3415         20.84           20.840      cs      10.42
# 8930        152.25          152.250      cs      50.75
# 1939        -26.39          -26.390      cs      26.39
# 1954       -347.80         -347.800      cs      34.78
# 17938      -433.20         -463.524      cs     144.40
# 18095       145.35          145.350      cs     145.35
# 7051         48.75           48.750      PL      48.75
# 9424        -14.20          -14.200      cs       7.10
# 17655       220.74          220.740     JUG     220.74
# 17657       163.40          163.400      cs     163.40
# 17670       183.92          183.920      cs     183.92
# 17692       -41.76          -41.760     JUG      20.88
# 17757        15.69           15.690     pak      15.69
# 17759       166.86          166.860      cs     166.86
# 18034        27.99           27.990      cs      27.99
# 17792        47.94           47.940      cs      47.94
# 4512         51.42           51.420      4L       8.57
# 4418         86.16           86.160      cs      86.16
# 5123        155.88          155.880     bag      12.99
# 5276          5.64            5.640     bag       5.64
# 3169         52.33           52.330      cs      52.33
# 8712         57.75           57.750      Kg      18.16
# 17836       147.96          147.960      cs     147.96
# 17872        47.32           47.320      cs      47.32
#
#                          item_descrip  ...  pak_qty case_qty  purchase_uom  \
# 12585                ONIONS JUMBO 5lb  ...    1.000      5.0            cs
# 519     CAKE SHEET SLAB ORANGE CITRUS  ...    1.000      2.0            CA
# 671          COOKIE DBL CHOC CHIP T/S  ...    1.000     72.0            cs
# 1404   COOKIE DOUGH CHOC CHIP N/HYDRO  ...    1.000    128.0            cs
# 1356   COOKIE DOUGH  WHITE CHOC MACA   ...    1.000    128.0            cs
# 1409     COOKIE DOUGH MONSTER N/HYDRO  ...    1.000    128.0            cs
# 1608                     CO2 CANISTER  ...    1.000      1.0            ea
# 9373            APPLES GALA  ROYAL lb  ...    1.000     38.0            CA
# 17487              PEPPER BLK CRACKED  ...  454.000      5.0            cs
# 8393               VINEGAR SUSHI SUMO  ...   20.000      1.0            CT
# 6597        NORI SUSHI FULL SHIRAKIKU  ...    1.000    100.0            cs
# 8405                      WAKAME CUT   ...   16.000      1.0            CT
# 18037            APRON BIB DISHWASHER  ...    1.000      1.0            CT
# 9066       CHICK SKEWERS 75g SOUVLAKI  ...   13.333      4.5            cs
# 8605       ICE CREAM STRAWBERRY 11.4L  ...   11.400      1.0           TUB
# 8598   ICE CREAM COOKIE & CREAM 11.4L  ...   11.400      1.0           TUB
# 8582    ICE CREAM BANA FUDGE SW 11.4L  ...   11.400      1.0           TUB
# 2522              SYRUP MONIN CARAMEL  ...    0.750      1.0         750ML
# 706                  COOKIE GINGER GF  ...    1.000     12.0            cs
# 13974               SUI CHOY SHREDDED  ...    1.000      5.0            cs
# 4502                MILK 2 GO VANILLA  ...    1.000      1.0            un
# 8604      ICE CREAM ROCKY ROAD 11.4 l  ...   11.400      1.0           TUB
# 18277      ROLL PPR THERMAL 2.25"X60'  ...    1.000    100.0            CA
# 2519                  SYRUP CHOCOLATE  ...    1.000      6.0            cs
# 2524                SYRUP MONIN LEMON  ...    1.000      1.0         750ML
# 2525           SYRUP MONIN LIME 750ML  ...    1.000      1.0         750ML
# 2547           SYRUP MONIN STRAWBERRY  ...    1.000      1.0         750ML
# 2449              ROOT BEER A&W 500ml  ...    1.000     24.0            cs
# 61           BAR LEMON BURST MACAROON  ...    1.000      2.0            cs
# 8931        SAUSAGE PORK CHORIZO MEAT  ...    1.000      1.0            Kg
# 2704           TONIC WATER CD  (12pk)  ...    1.000     12.0            cs
# 1711                     COKE DIET 2L  ...    1.000      8.0            cs
# 2283            MONSTER ENERGY-K 473M  ...    1.000     12.0            cs
# 2286        NESTEA COOL SW&LEMN 500ML  ...    1.000     24.0            cs
# 2438                   POWERADE GRAPE  ...    1.000     12.0            cs
# 2461                        SPRITE 2L  ...    1.000      8.0            cs
# 3415        CHIP PRINGLES REG SML CAN  ...    1.000     12.0            cs
# 8930          SAUSAGE PORK BREAKFAST.  ...    1.000      5.0            cs
# 1939             CRYSTAL LEM PINK TFC  ...  425.000     12.0            cs
# 1954                 CRYSTAL TEA ICED  ...  375.000     12.0            cs
# 17938      LINER PARCHMENT ENVIROBAKE  ...    1.000   1000.0            cs
# 18095    GLOVE NITRILE N/PWDR BLK XLG  ...  100.000     10.0            cs
# 7051        PEANUT BUTTER NATURAL TFC  ...    1.000     10.0            cs
# 9424             APPLES GALA ROYAL US  ...    1.000     10.0            cs
# 17655        CLEANER FLOORWASH N WALK  ...    1.000      1.0           JUG
# 17657        CLEANER ORANGE FORCE 137  ...    1.000      1.0            cs
# 17670    DETERGENT APEX MAN POT & PAN  ...    1.000      2.0            cs
# 17692   DETERGENT DISH PAN DANDY MANU  ...    1.000      4.0            cs
# 17757          FILTER GREASE CONE 10"  ...   50.000     10.0            cs
# 17759    PRESOAK FLATWARE LIQ CPS 490  ...    1.000      4.0            cs
# 18034  TISSUE FACIAL BOX WHT 2PLY 100  ...    1.000     36.0            cs
# 17792      SOAP HAND CLEAN AND SMOOTH  ...    1.000      6.0            cs
# 4512       MILK 2% (4/4LT)MEADOWFRESH  ...    4.000      4.0            cs
# 4418        EGG OMELETTE PLAIN FOLDED  ...    1.000     80.0            cs
# 5123            MILK POWDER SKIM INST  ...    0.500      1.0           bag
# 5276             MILKETTES 2% 160X9ML  ...  160.000      1.0           bag
# 3169       FLATBREAD OVEAL 5X12.5 FZN  ...    1.000     48.0            cs
# 8712       BACON BACK ERUO STYLE FRSH  ...    1.000      1.0            Kg
# 17836   CHOPSTICK BAMBOO PPR WRPD 9IN  ...   50.000     40.0            cs
# 17872         ECO CUTLERY FORK WOODEN  ...   50.000     20.0            cs
#
#       cat_num cat_descrip  has_credit credit_pak_amount  \
# 12585       2        Food           N                 0
# 519         2        Food           N                 0
# 671         2        Food           N                 0
# 1404        2        Food           Y                 0
# 1356        2        Food           N                 0
# 1409        2        Food           N                 0
# 1608        2        Food           N                 0
# 9373        2        Food           N                 0
# 17487       2        Food           N                 0
# 8393        2        Food           N                 0
# 6597        2        Food           N                 0
# 8405        2        Food           N                 0
# 18037       4      Misc.            N                 0
# 9066        2        Food           N                 0
# 8605        2        Food           N                 0
# 8598        2        Food           N                 0
# 8582        2        Food           N                 0
# 2522        2        Food           Y                 0
# 706         2        Food           N                 0
# 13974       2        Food           N                 0
# 4502        2        Food           N                 0
# 8604        2        Food           N                 0
# 18277       4      Misc.            N                 0
# 2519        2        Food           Y                 0
# 2524        2        Food           N                 0
# 2525        2        Food           N                 0
# 2547        2        Food           N                 0
# 2449        2        Food           N                 0
# 61          2        Food           N                 0
# 8931        2        Food           N                 0
# 2704        2        Food           N                 0
# 1711        2        Food           N                 0
# 2283        2        Food           N                 0
# 2286        2        Food           N                 0
# 2438        2        Food           N                 0
# 2461        2        Food           N                 0
# 3415        2        Food           N                 0
# 8930        2        Food           N                 0
# 1939        2        Food           N                 0
# 1954        2        Food           Y                 0
# 17938       4      Misc.            N                 0
# 18095       4      Misc.            N                 0
# 7051        2        Food           N                 0
# 9424        2        Food           N                 0
# 17655       4      Misc.            N                 0
# 17657       4      Misc.            N                 0
# 17670       4      Misc.            N                 0
# 17692       4      Misc.            N                 0
# 17757       4      Misc.            Y                 0
# 17759       4      Misc.            N                 0
# 18034       4      Misc.            N                 0
# 17792       4      Misc.            N                 0
# 4512        2        Food           N                 0
# 4418        2        Food           N                 0
# 5123        2        Food           N                 0
# 5276        2        Food           N                 0
# 3169        2        Food           Y                 0
# 8712        2        Food           Y                 0
# 17836       4      Misc.            N                 0
# 17872       4      Misc.            N                 0
#
#        Items_assign_category_ID  Category ID  \
# 12585                       NaN         39.0
# 519                         NaN         24.0
# 671                         NaN         41.0
# 1404                        NaN         24.0
# 1356                        NaN         24.0
# 1409                        NaN         24.0
# 1608                        NaN         61.0
# 9373                        NaN         32.0
# 17487                       NaN         54.0
# 8393                        NaN         57.0
# 6597                        NaN         40.0
# 8405                        NaN          NaN
# 18037                       NaN         61.0
# 9066                        NaN          4.0
# 8605                        NaN          7.0
# 8598                        NaN          7.0
# 8582                        NaN          7.0
# 2522                        NaN         43.0
# 706                         NaN         24.0
# 13974                       NaN         36.0
# 4502                        NaN          9.0
# 8604                        NaN          7.0
# 18277                       NaN         61.0
# 2519                        NaN         52.0
# 2524                        NaN         43.0
# 2525                        NaN         43.0
# 2547                        NaN         43.0
# 2449                        NaN         50.0
# 61                          NaN         24.0
# 8931                        NaN          3.0
# 2704                        NaN         55.0
# 1711                        NaN         55.0
# 2283                        NaN         55.0
# 2286                        NaN         55.0
# 2438                        NaN         55.0
# 2461                        NaN         55.0
# 3415                        NaN         41.0
# 8930                        NaN          3.0
# 1939                        NaN         55.0
# 1954                        NaN         55.0
# 17938                       NaN         61.0
# 18095                       NaN         61.0
# 7051                        NaN          5.0
# 9424                        NaN         32.0
# 17655                       NaN         61.0
# 17657                       NaN         61.0
# 17670                       NaN         61.0
# 17692                       NaN         61.0
# 17757                       NaN         61.0
# 17759                       NaN         61.0
# 18034                       NaN         61.0
# 17792                       NaN         61.0
# 4512                        NaN          9.0
# 4418                        NaN         11.0
# 5123                        NaN         54.0
# 5276                        NaN          9.0
# 3169                        NaN         24.0
# 8712                        NaN          3.0
# 17836                       NaN         61.0
# 17872                       NaN         61.0
#
#                                       Category
# 12585                         onions and leeks
# 519      wheat/rye (bread, pasta, baked goods)
# 671                                   potatoes
# 1404     wheat/rye (bread, pasta, baked goods)
# 1356     wheat/rye (bread, pasta, baked goods)
# 1409     wheat/rye (bread, pasta, baked goods)
# 1608                          kitchen supplies
# 9373                                    apples
# 17487                stimulants & spices misc.
# 8393                                  vinegar
# 6597                          other vegetables
# 8405                                       NaN
# 18037                         kitchen supplies
# 9066                 poultry (chicken, turkey)
# 8605                                 ice cream
# 8598                                 ice cream
# 8582                                 ice cream
# 2522                     sugars and sweeteners
# 706      wheat/rye (bread, pasta, baked goods)
# 13974  cabbages and other brassicas (broccoli)
# 4502                         milk (cow's milk)
# 8604                                 ice cream
# 18277                         kitchen supplies
# 2519                                     cocoa
# 2524                     sugars and sweeteners
# 2525                     sugars and sweeteners
# 2547                     sugars and sweeteners
# 2449                             barley (beer)
# 61       wheat/rye (bread, pasta, baked goods)
# 8931                           pork (pig meat)
# 2704                         water & beverages
# 1711                         water & beverages
# 2283                         water & beverages
# 2286                         water & beverages
# 2438                         water & beverages
# 2461                         water & beverages
# 3415                                  potatoes
# 8930                           pork (pig meat)
# 1939                         water & beverages
# 1954                         water & beverages
# 17938                         kitchen supplies
# 18095                         kitchen supplies
# 7051                                    butter
# 9424                                    apples
# 17655                         kitchen supplies
# 17657                         kitchen supplies
# 17670                         kitchen supplies
# 17692                         kitchen supplies
# 17757                         kitchen supplies
# 17759                         kitchen supplies
# 18034                         kitchen supplies
# 17792                         kitchen supplies
# 4512                         milk (cow's milk)
# 4418                                      eggs
# 5123                 stimulants & spices misc.
# 5276                         milk (cow's milk)
# 3169     wheat/rye (bread, pasta, baked goods)
# 8712                           pork (pig meat)
# 17836                         kitchen supplies
# 17872                         kitchen supplies
#
# [60 rows x 32 columns]

# %%
unfiltered_df.iloc[60:78, :]
# Out:
#        invoice_counter invoice_num  invoice_total item_num    qty  \
# 17800           251169  9001346513         210.09  I-23898   2.00
# 18078           249022  9001185335        7277.82   I-2392   1.00
# 18244           250173  9001238103        1701.47   I-2411   1.00
# 18265           247973  9001094224        8190.64   I-2422   1.00
# 18285           249851  9001271332        7700.61   I-2428   4.00
# 11172           248383  9001132129        4406.91   I-2616   2.00
# 1524            247784    71990893         609.06   I-2631   6.00
# 17649           249480     2036658         733.20  I-26887   1.00
# 7983            248126  9001081628         504.98   I-2716   1.00
# 8001            248593  9001111666         352.06   I-2752   1.00
# 8556            248541     7601064         546.76  I-27696   1.00
# 8561            251367     7608804         427.09  I-27697   1.00
# 7380            247830    20230158         754.80   I-2770  24.00
# 17925           250234     0250233         -51.96  I-28195  -0.25
# 17669           252241      144196         431.81  I-29517  12.00
# 18384           250792  9001333265        2352.89  I-30507   1.00
# 6339            250214    72002378         424.60   I-3067   1.00
# 17651           248950  9001156748        1231.70  I-31059   1.00
#
#        line_amount  adj_line_amount  uom  unit_cost  \
# 17800        10.72            10.72   ea     5.3600
# 18078        12.21            12.21   cs    12.2100
# 18244        15.54            15.54  pak    15.5400
# 18265        78.58            78.58   cs    78.5800
# 18285        42.56            42.56   cs    10.6400
# 11172       126.68           126.68   cs    63.3400
# 1524        190.80           190.80   PL    31.8000
# 17649        62.00            62.00   ea    62.0000
# 7983         49.03            49.03   cs    49.0300
# 8001         44.80            44.80   cs    44.8000
# 8556         36.72            36.72   cs    36.7200
# 8561         31.80            31.80   cs    31.8000
# 7380         46.08            46.08   CT     1.9200
# 17925       -13.56           -13.56   cs    54.2200
# 17669        29.20            29.20  box     2.4333
# 18384        75.19            75.19   cs    75.1900
# 6339        116.90           116.90   cs   116.9000
# 17651       220.74           220.74  JUG   220.7400
#
#                          item_descrip  ... pak_qty case_qty  purchase_uom  \
# 17800   STRIP TEST PPR QUAT SANITIZER  ...    1.00      1.0            ea
# 18078   FIRST AID BANDAGE FABRIC BLUE  ...    1.00    100.0            cs
# 18244  LBL FOOD ROTATION DISSOLVE 2X3  ...  250.00      1.0           pak
# 18265  PAD GRIDDLE POLS 46 BLK 4X5.25  ...   20.00      3.0            cs
# 18285   STRING BUTCHER MED WEIGHT #4R  ...    1.00      1.0            cs
# 11172    HASHBROWN DCD RISE N FRY TFC  ...    5.00      6.0            cs
# 1524           MUFFIN BATT CARROT TFC  ...    1.00      8.0            CA
# 17649                            SAKE  ...   18.00      1.0       BIB 20L
# 7983         SOUP CHOWDER CLAM BOSTON  ...    1.81      3.0            cs
# 8001      SOUP VEG BEEF BARLEY NO MSG  ...    1.81      1.0            cs
# 8556      Barbara Bakery Cheese Puffs  ...    1.00     12.0            cs
# 8561   Barbara Bakery Cheese Puffs WC  ...    1.00     12.0            cs
# 7380                  SAMOSA SPINACH   ...    1.00      1.0            CT
# 17925  LID FOR 10-20Z WHT CUP PPR HOT  ...    1.00   1000.0            cs
# 17669  CLEANING TABLET CAFIZA ESPRSS   ...    1.00    100.0           box
# 18384      WRAP FOIL HD 18" 45CMX100M  ...  328.00      1.0            cs
# 6339              JAM RASPBERRY 14kg   ...    1.00     14.0            cs
# 17651    CLEANER FLOOR WASH AND WALK   ...    1.00    332.9           JUG
#
#       cat_num     cat_descrip  has_credit credit_pak_amount  \
# 17800       4          Misc.            N                 0
# 18078       4          Misc.            N                 0
# 18244       4          Misc.            N                 0
# 18265       4          Misc.            N                 0
# 18285       4          Misc.            N                 0
# 11172       2            Food           N                 0
# 1524        2            Food           N                 0
# 17649       8  Liq,Wine,Beer            N                 0
# 7983        2            Food           N                 0
# 8001        2            Food           N                 0
# 8556        2            Food           N                 0
# 8561        2            Food           N                 0
# 7380        2            Food           Y                 0
# 17925       4          Misc.            N                 0
# 17669       4          Misc.            N                 0
# 18384       4          Misc.            N                 0
# 6339        2            Food           Y                 0
# 17651       4          Misc.            N                 0
#
#        Items_assign_category_ID  Category ID             Category
# 17800                       NaN         61.0     kitchen supplies
# 18078                       NaN         61.0     kitchen supplies
# 18244                       NaN         61.0     kitchen supplies
# 18265                       NaN         61.0     kitchen supplies
# 18285                       NaN         61.0     kitchen supplies
# 11172                       NaN         41.0             potatoes
# 1524                        NaN         38.0      root vegetables
# 17649                       NaN         51.0   wine grapes (wine)
# 7983                        NaN         59.0    manually adjusted
# 8001                        NaN          1.0  beef & buffalo meat
# 8556                        NaN          6.0               cheese
# 8561                        NaN          6.0               cheese
# 7380                        NaN         59.0    manually adjusted
# 17925                       NaN         61.0     kitchen supplies
# 17669                       NaN         61.0     kitchen supplies
# 18384                       NaN         61.0     kitchen supplies
# 6339                        NaN         34.0              berries
# 17651                       NaN         61.0     kitchen supplies
#
# [18 rows x 32 columns]

# %%
consolidated_df.to_csv(os.getcwd() + '/data/Misc/GHG_categories/GHG_categories_assigned_with_Items_List.csv', index = False)

# %%
items_list
# Out:
#        ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0     I-57545           1         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1     I-10869           1             BEEF STIRFRY COV FR     5.00      Kg
# 2      I-7064           1           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3     I-37005           1                  BEEF MEATBALLS     4.54      Kg
# 4     I-37002           1        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...       ...         ...                             ...      ...     ...
# 2816  I-17622          24         WAFFLES BLUBRRY - GF/WF    12.00     box
# 2817  I-45754          55        WATER ACTIVE LEMON LIME     12.00   450ML
# 2818  I-45755          55       WATER ACTIVE ORANGE MANGO    12.00   450ML
# 2819  I-45756          55  WATER ACTIVE STRAWB BLK CHERRY    12.00   450ML
# 2820  I-43251          55    WATER FRUIT 500ML PINEAPPLE     12.00   500ML
#
#       PakQty  PakUOM  InventoryGroup
# 0        1.0      Kg            MEAT
# 1        1.0      Kg            MEAT
# 2        1.0      Kg            MEAT
# 3     1000.0       g            MEAT
# 4     1000.0       g            MEAT
# ...      ...     ...             ...
# 2816     6.0      ea  FOOD - GROCERY
# 2817     1.0   450ML        BEVERAGE
# 2818     1.0   450ML        BEVERAGE
# 2819     1.0   450ML        BEVERAGE
# 2820     1.0  bottle        BEVERAGE
#
# [2821 rows x 8 columns]

# %%
df_to_be_added = unfiltered_df.rename(columns={"item_num": "ItemId", "Category ID": "CategoryID", "item_descrip": "Description", "case_qty": "CaseQty", "case_uom": "CaseUOM", "pak_qty": "PakQty", "uom": "PakUOM", "prod_group_descrip": "InventoryGroup"})

# %%
df_to_be_added = df_to_be_added[["ItemId", "CategoryID", "Description", "CaseQty", "CaseUOM", "PakQty", "PakUOM", "InventoryGroup"]]

# %%
df_to_be_added
# Out:
#         ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 12585  I-10482        39.0                ONIONS JUMBO 5lb      5.0      lb
# 519     I-1063        24.0   CAKE SHEET SLAB ORANGE CITRUS      2.0   SHEET
# 671     I-1084        41.0        COOKIE DBL CHOC CHIP T/S     72.0      ea
# 1404    I-1086        24.0  COOKIE DOUGH CHOC CHIP N/HYDRO    128.0      CT
# 1356    I-1091        24.0  COOKIE DOUGH  WHITE CHOC MACA     128.0    each
# ...        ...         ...                             ...      ...     ...
# 15316  I-70756        26.0  CK|BULK|Seasonal Chia/ Oat 8kg      1.0      ea
# 8603   I-70806         7.0        ICE CREAM ESPRESSO 11.4L      1.0     TUB
# 8612   I-70837         7.0         ICE CREAM VANILLA 11.4L      1.0     TUB
# 8750   I-70875         1.0                 BEEF MEDIUM GRD      5.0      Kg
# 3350    I-8100        24.0        LOAF WHWHT 3/4 SANDWICH       1.0      CT
#
#        PakQty PakUOM           InventoryGroup
# 12585     1.0     cs                  PRODUCE
# 519       1.0     CA              BAKED GOODS
# 671       1.0     cs              BAKED GOODS
# 1404      1.0     cs   BAKING-RAW INGREDIENTS
# 1356      1.0     cs   BAKING-RAW INGREDIENTS
# ...       ...    ...                      ...
# 15316     1.0     ea          PRODUCTION FOOD
# 8603     11.4    TUB  ICECREAM/NOVELTY/GELATO
# 8612     11.4    TUB  ICECREAM/NOVELTY/GELATO
# 8750      1.0     BX                     MEAT
# 3350      1.0     CT                    BREAD
#
# [286 rows x 8 columns]

# %%
# Append df_to_be_added to items_list

# CHECK ALL ITEMS CAREFULLY BEFORE DOING: 

# items_list = pd.concat([items_list, df_to_be_added], axis=0)
# items_list.tail(10)

# %%
# CHECK ALL ITEMS CAREFULLY BEFORE DOING: 

# items_list.to_csv(os.getcwd() + '/data/GHG_categories/Items_List_Assigned.csv', index = False)
