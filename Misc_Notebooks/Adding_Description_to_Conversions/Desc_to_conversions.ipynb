# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Adding Description to Conversions

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import csv
from itertools import islice
from decimal import Decimal
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
import openpyxl
import pytest

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ****
#
# ## Load Data Files
#
# ### Set Data File Path

# %%
#OK
filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "OK 23-24 Sep-Dec*", "*.oc"))
filepath_list += glob.glob(os.path.join(os.getcwd(), "data", "archive", "OK", "OK *", "*.oc"))

#Gather
filepath_list += glob.glob(os.path.join(os.getcwd(), "data", "raw", "Gather 23-24 Sep-Dec*", "*.oc"))
filepath_list += glob.glob(os.path.join(os.getcwd(), "data", "archive", "Gather", "Gather *", "*.oc"))

#Totem
filepath_list += glob.glob(os.path.join(os.getcwd(), "data", "raw", "Totem 23-24 Sep-Dec*", "*.oc"))
filepath_list += glob.glob(os.path.join(os.getcwd(), "data", "archive", "Feast", "Feast *", "*.oc"))

filepath_list
# Out:
# ['/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/raw/OK 23-24 Sep-Dec/OK_ALL_prods_July29_2023.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_GRILL_PM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_SQUARE.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_GRILL_AM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_FORNO.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_VEG_PM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_Missing_items_1.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_VEG_AM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_CST_GLB_BOWL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_Missing_items_3.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_Missing_items_2.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 22-23 Jan-Apr/IPR_Export_SAND_SALAD_SOUP.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_0938.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_0918.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_0918.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_1141.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_1001.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_1155.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_0927.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_0956.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_1202.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_1111.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_1150.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_0951.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_1033.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_1007.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_0944.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/OK Oct 22 Request.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06182021_1026.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22/IPR_Export_06232021_0944.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_0909.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1020.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1150.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1010.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1134.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1141.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_0936.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1103.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_0950.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_0924.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 19-20/IPR_Export_07212021_1112.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Sep-Dec/OK Al Forno_Custom Kitchen_Dim Sum_Global.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Sep-Dec/OK Square Meal.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Sep-Dec/OK Sandwich Kitchen_Sides_Soup.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Sep-Dec/OK Grill Kitchen Break_Grill Kitchen Day_Grill Kitchen Features.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Jan-Apr/SQR_TRUCK_GRL_SIDE.oc.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Jan-Apr/GRL.oc.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Jan-Apr/ALF_VEG_GLB.oc.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/OK/OK 21-22 Jan-Apr/OK 21-22 New-2.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/raw/Gather 23-24 Sep-Dec/Gather_ALL_prods_July31_2023.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather FLX A.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather CAL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather Grab&Go C.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather DOD.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather GRL B.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather SPECIALS A.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather FRUIT.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather Grab&Go B.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather FF.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather GRL A.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather SPECIALS B.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather GZA.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather FLX C.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather Grab&Go A.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather FLX B.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather DIM SUM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather Grab&Go D.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather ADD ONS.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather SL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather SAND.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 19-20/Gather DEL DES.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Gyaza & Simply Local.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Flex Bao & Global Bowl.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/CAL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Dim Sum & Flex Asian Noodle.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Grill Day & Feature.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Fresh Fare Breakfast & Day.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Sandwich & Production Foodl.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Flex BC.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/ADD Ons.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/Specials.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Caliente.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/DEL_FF.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GRL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GVGrill Breakfast.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/FLX.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GV Delish & Dessert.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 21-22/GZA_SL.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_GRILL_PM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_GRILL_AM.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_Fresh_Fare.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_HC_SL1.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_Del_Sand_Bev.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Gather/Gather 22-23 Jan-Apr/IPR_Export_Caliente_Gyaza.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Dim Sum.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grab & Go B.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grill Day.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Bueno and Desserts.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/FT Sticks and spoons.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grab & Go C.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Hot and Bakery.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Feast.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/FT Oasis Chaat.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/FT Mercante.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Production food.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Add Ons.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Specials.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grill Features.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/FT Sides Soup.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grill Breakfast.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Grab & Go A.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/FT SweetGreen Ucare Boxes.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 19-20/Home Skillet.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 22-23 Jan-Apr/IPR_Export_CLOVE_SNACK.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 22-23 Jan-Apr/IPR_Export_HS_CLOVE.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 22-23 Jan-Apr/IPR_Export_DNR_FORNO_GR.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 22-23 Jan-Apr/IPR_Export_PB_ROOTS.oc',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/Feast/Feast 22-23 Jan-Apr/IPR_Export_BUENO.oc']

# %%
# Read items.xml files in the filepath_list and construct a dataframe
Items = []
ItemId = []
Description = []
CaseQty = []
CaseUOM = []
PakQty = []
PakUOM = []
InventoryGroup = []
# from the items xml file, findtext of CaseQty, CaseUOM, PakQty, PakUOM, and InventoryGroup
# then append it on the lists above
for filepath in filepath_list:
    path = filepath + '/items.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for item in xtree.iterfind('Item'):
            ItemId.append(item.attrib['id'])
            Description.append(item.findtext('Description'))
            CaseQty.append(item.findtext('CaseQty'))
            CaseUOM.append(item.findtext('CaseUOM'))
            PakQty.append(item.findtext('PakQty'))
            PakUOM.append(item.findtext('PakUOM'))
            InventoryGroup.append(item.findtext('InventoryGroup'))

            
# Create a dataframe from the lists created above.
Items = pd.DataFrame({'ItemId': ItemId, 'Description': Description, 'CaseQty': CaseQty, 
                      'CaseUOM': CaseUOM, 'PakQty': PakQty, 'PakUOM': PakUOM, 'InventoryGroup': InventoryGroup}
                    )

Items.drop_duplicates(inplace=True)

Items.reset_index(drop=True, inplace=True)

# %%
Items
# Out:
#        ItemId                     Description   CaseQty CaseUOM   PakQty  \
# 0      I-7631                  5 SPICE POWDER     1.000      ea    1.000
# 1      I-2353   9"X6" 2-COMPARTMENT CLAMSHELL   200.000      CT    1.000
# 2     I-43239                AGAR AGAR POWDER   500.000       g    1.000
# 3     I-57481     AHA WATER SP BLUEB POM PET     24.000    each    1.000
# 4     I-57484  AHA WATER SP PEACH HONEY PET      24.000    each    1.000
# ...       ...                             ...       ...     ...      ...
# 2783   I-3581                PEPPER LEMON TFC    12.000      ea  825.000
# 2784  I-54355                   SAUCE HOISIN      1.000    5LBS    5.000
# 2785  I-19561                         EPAZOTE  1000.000       g    1.000
# 2786   I-2208           MILK BUTTERMILK 3.25%     1.000       L    1.000
# 2787  I-17610      SHRIMPMT MP 250/350 O/WISE     1.000      lb    1.000
#
#      PakUOM  InventoryGroup
# 0        lb          SPICES
# 1        CT     DISPOSABLES
# 2         g          SPICES
# 3      each        BEVERAGE
# 4      each        BEVERAGE
# ...     ...             ...
# 2783      g          SPICES
# 2784     lb  FOOD - GROCERY
# 2785     Kg         PRODUCE
# 2786      L           DAIRY
# 2787     lb         SEAFOOD
#
# [2788 rows x 7 columns]

# %%
filepath = glob.glob(os.path.join(os.getcwd(), "data", "cleaning", "update", "Conv_UpdateConv.csv"))
filepath
# Out:
# ['/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/cleaning/update/Conv_UpdateConv.csv']

# %%
Conversions = pd.read_csv(filepath[0])
Conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0        I-67659    0.008818             1.0           each       113.398
# 1        I-28697    0.005181             1.0             ea       193.000
# 2        I-47441    0.005181             1.0             ea       193.000
# 3         I-1905    0.012500             1.0             CT        80.000
# 4        I-47440    0.005051             1.0             ea       198.000
# ..           ...         ...             ...            ...           ...
# 436      I-61562    0.010000             1.0            BAR       100.000
# 437      I-34478    0.010000             1.0            BAR       100.000
# 438      I-25211    0.010000             1.0            BAR       100.000
# 439       I-3823    0.009009             1.0            BAR       111.000
# 440       I-3830    0.010000             1.0            BAR       100.000
#
#     ConvertToUom
# 0              g
# 1              g
# 2              g
# 3              g
# 4              g
# ..           ...
# 436           ml
# 437           ml
# 438           ml
# 439           ml
# 440           ml
#
# [441 rows x 6 columns]

# %%
for index,row in Items.iterrows():
    Conversions.loc[Conversions['ConversionId'] == row['ItemId'], 'Description'] = row['Description']
Conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0        I-67659    0.008818             1.0           each       113.398
# 1        I-28697    0.005181             1.0             ea       193.000
# 2        I-47441    0.005181             1.0             ea       193.000
# 3         I-1905    0.012500             1.0             CT        80.000
# 4        I-47440    0.005051             1.0             ea       198.000
# ..           ...         ...             ...            ...           ...
# 436      I-61562    0.010000             1.0            BAR       100.000
# 437      I-34478    0.010000             1.0            BAR       100.000
# 438      I-25211    0.010000             1.0            BAR       100.000
# 439       I-3823    0.009009             1.0            BAR       111.000
# 440       I-3830    0.010000             1.0            BAR       100.000
#
#     ConvertToUom                  Description
# 0              g             BURGER 50/50 4oz
# 1              g            BURGER QUINOA YAM
# 2              g         JAMAICAN PATTY SPICY
# 3              g      BEEF JERKY PEPPERED 80G
# 4              g          JAMAICAN PATTY MILD
# ..           ...                          ...
# 436           ml                          NaN
# 437           ml      MAGNUM DOUBLE RASPBERRY
# 438           ml                          NaN
# 439           ml  KLONDIKE CONE CHOC/VAN KING
# 440           ml        MAGNUM DOUBLE CARAMEL
#
# [441 rows x 7 columns]

# %%
Conversions[Conversions["Description"].isna()]
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 129      I-31464    0.000926             1.0             ea       1079.55
# 130      I-63692    0.001333             1.0             ea        750.00
# 134      I-10503    1.000000           192.0              g        192.00
# 136      I-33072    0.006667             1.0             ea        150.00
# 137      I-70004    1.000000          2210.0              g       2210.00
# ..           ...         ...             ...            ...           ...
# 421      I-65519    0.014286             1.0           each         70.00
# 422      I-42798    0.016667             1.0            BAR         60.00
# 427      I-65518    0.014286             1.0           each         70.00
# 436      I-61562    0.010000             1.0            BAR        100.00
# 438      I-25211    0.010000             1.0            BAR        100.00
#
#     ConvertToUom Description
# 129            g         NaN
# 130            g         NaN
# 134            g         NaN
# 136            g         NaN
# 137            g         NaN
# ..           ...         ...
# 421           ml         NaN
# 422           ml         NaN
# 427           ml         NaN
# 436           ml         NaN
# 438           ml         NaN
#
# [77 rows x 7 columns]
