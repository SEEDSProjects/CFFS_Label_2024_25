# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ***
#
# ## Part III: Update Information and Mapping

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  os
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
from datetime import datetime

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
# ## Import Preprocessed Datasets

# %%
# Creates a DataFrame from reading a csv file 
Preps = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_Unit_Cleaned.csv"))
Preps.head()
# Out:
#     PrepId                    Description   PakQty PakUOM InventoryGroup  \
# 0   P-2679             Pro - Tahini Sauce      1.0      L              Y
# 1  P-15427      Pro - Vegan Chipotle Mayo     16.5      L              Y
# 2   P-7912  BCPrep - Baked Eggs for Wraps      4.3     Kg              Y
# 3  P-14403     Prep Cream Cheese - Garlic  11000.0      g              Y
#
#     StdQty StdUom
# 0   1000.0     ml
# 1  16500.0     ml
# 2   4300.0      g
# 3  11000.0      g

# %%
# Creates a DataFrame from reading a csv file 
ghge_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "ghge_factors.csv"))
ghge_factors.head()
# Out:
#    Category ID              Food Category  \
# 0            1        beef & buffalo meat
# 1            2    lamb/mutton & goat meat
# 2            3            pork (pig meat)
# 3            4  poultry (chicken, turkey)
# 4            5                     butter
#
#    Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                            41.3463
# 1                                            41.6211
# 2                                             9.8315
# 3                                             4.3996
# 4                                            11.4316

# %%
# Creates a DataFrame from reading a csv file 
nitro_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "nitrogen_factors.csv"))
nitro_factors.head()
# Out:
#    Category ID              Food Category  g N lost/kg product
# 0            1        beef & buffalo meat               329.50
# 1            2    lamb/mutton & goat meat               231.15
# 2            3            pork (pig meat)               132.80
# 3            4  poultry (chicken, turkey)               116.80
# 4            5                     butter               100.35

# %%
# Creates a DataFrame from reading a csv file 
water_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "water_factors.csv"))
water_factors.head()
# Out:
#    Category ID              Food Category  Freshwater Withdrawals (L/FU)  \
# 0            1        beef & buffalo meat                       1677.200
# 1            2    lamb/mutton & goat meat                        461.200
# 2            3            pork (pig meat)                       1810.300
# 3            4  poultry (chicken, turkey)                        370.300
# 4            5                     butter                       1010.176
#
#    Stress-Weighted Water Use (L/FU)
# 0                         61309.000
# 1                           258.900
# 2                         54242.700
# 3                           333.500
# 4                         50055.168

# %%
# Creates a DataFrame from reading a csv file 
land_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "land_factors.csv"))
land_factors.rename(columns={'km^2 land use/kg product': 'Land Use (m^2)'}, inplace=True)
land_factors['Land Use (m^2)'] *= 1000
land_factors.head()
# Out:
#    Category ID              Food Category  Land Use (m^2)
# 0            1        beef & buffalo meat         0.12645
# 1            2    lamb/mutton & goat meat         0.14320
# 2            3            pork (pig meat)         0.02102
# 3            4  poultry (chicken, turkey)         0.01151
# 4            5                     butter         0.01395

# %%
# Load current Items List with assigned Emission Factors Category ID
Items_Assigned = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Items_List_Assigned.csv"))
Items_Assigned.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup Food Category
# 0              N           NaN
# 1              N           NaN
# 2              N           NaN
# 3              N           NaN
# 4              N           NaN

# %%
# new_items = pd.read_csv("data/mapping/new items added/New_Items_Added_11.csv")
# new_items = pd.read_csv("data/mapping/new items added/New_Items_2023/New_Items_Added_2023_08_01.csv")
# CHECK FOR CHANGES REQUIRES

# # COMMENTED OUT LINES BELOW, commented it out this time because no new items were added

new_items = pd.read_csv("data/mapping/AMS_data/new items/2024-08-01_New_Items.csv")
new_items.head()
# Out:
#     ItemId  CategoryID                     Description  CaseQty  CaseUOM  \
# 0  I-16857         NaN               ITEM SAUCE BURGER      2.0  oz (fl)
# 1  I-16858         NaN          DRESSING Ranch BtrMilk      2.0  oz (fl)
# 2  I-16859         NaN          Lemon Pepper Seasoning     10.0        g
# 3  I-16861         NaN  ITEM G21- MANGO HABANERO SAUCE      2.0  oz (fl)
# 4  I-16862         NaN             Fries Sweet Potato     400.0        g
#
#    PakQty  PakUOM InventoryGroup
# 0     NaN     NaN              Y
# 1     NaN     NaN              Y
# 2     NaN     NaN              Y
# 3     NaN     NaN              Y
# 4     NaN     NaN              Y

# %%
item_nonstd = pd.read_csv("data/cleaning/AMS_data/Items_Nonstd.csv")
item_nonstd
# Out:
#     IngredientId   Qty    Uom   Recipe                    Description
# 0         I-4109   1.0  bunch   P-2679                   CILANTRO 3ct
# 1         I-4114  10.0     ea   P-2424  TORTILLA 10" FLOUR PRESSED TF
# 2         I-2992   2.0  slice  P-10674         Bacon Pre-Ckd 30-34 ct
# 3         I-4122   2.0   2 KG   P-7912     EGG LIQ WHL CAGE FREE FRSH
# 4         I-4126   2.0  slice   P-1488           MULTIGRAIN CLUBHOUSE
# ..           ...   ...    ...      ...                            ...
# 105       I-4323   1.0     ea   R-2588                   VEGAN COOKIE
# 106       I-4324   1.0     ea   R-8062                 VEGAN DATE BAR
# 107       I-4325   1.0     ea   R-7939                    CHICK SALAD
# 108       I-4326   1.0     ea   R-8651                      EGG SALAD
# 109       I-4328   1.0     ea   R-5563                  MUFF - BANANA
#
# [110 rows x 5 columns]

# %%
preps_nonstd = pd.read_csv("data/cleaning/AMS_data/Preps_NonstdUom.csv")
preps_nonstd
# Out:
#      PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0    P-2824             BC - Tomato Focacia    14.0     ea              Y
# 1    P-5012    Catr- Roasted Chicken Breast     1.0     ea              Y
# 2    P-9935       Baking - Focacia Baguette    14.0     ea              Y
# 3    P-2424      BCPrep - Asian Sesame Wrap    10.0     ea              Y
# 4   P-10674             BCPrep - BACON WRAP     1.0     ea              Y
# 5    P-1520    BCPrep - Chicken Quinoa Wrap    10.0     ea              Y
# 6    P-1488          BCPrep - Chicken Salad     1.0     ea              Y
# 7    P-2535              BCPrep - Egg Salad     1.0     ea              Y
# 8    P-4582  BCPrep - Ham & Swiss Croissant     1.0     ea              Y
# 9    P-4811     BCPrep - Mediterranean Wrap    10.0     ea              Y
# 10   P-9279             BCPrep - Salsa Wrap     1.0     ea              Y
# 11  P-10863          BCPrep - T-Bird Muffin     1.0     ea              Y
# 12   P-1434       BCPrep - Turkey & Cheddar     1.0     ea              Y
# 13  P-10195       BCPrep - Vegan Egg Muffin    10.0     ea              Y
# 14   P-4257                 SGL Chunky Prep     1.0     ea              Y
# 15   P-9928                   SGL JAVA prep     1.0     ea              Y
# 16   P-7873              SGL MARBELOUS prep     1.0     ea              Y
# 17   P-4611                SGL SMARTIE prep     1.0     ea              Y
# 18   P-8359       Vegan Golden Falafel Wrap    10.0     ea              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN

# %%
conv_updatecov = pd.read_csv("data/cleaning/update/AMS_data/Conv_UpdateConv.csv")
conv_updatecov
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0         I-1971    0.003731            0.25             ea         16.75
# 1        I-15803    0.004000            1.00            can        250.00
# 2         I-5505    0.001263            0.25           HEAD         49.50
# 3        I-11706    0.008547            1.00             ea        117.00
# 4        I-13308    0.024540            1.00             ea         40.75
# ..           ...         ...             ...            ...           ...
# 190       I-3810    0.010000            1.00             ea        100.00
# 191       I-3815    0.010000            0.25             ea         25.00
# 192       I-3816    0.010000            0.25             ea         25.00
# 193       I-3817    0.010000            0.25             ea         25.00
# 194       I-3820    0.013333            1.00             ea         75.00
#
#     ConvertToUom
# 0              g
# 1             ml
# 2              g
# 3              g
# 4              g
# ..           ...
# 190            g
# 191            g
# 192            g
# 193            g
# 194            g
#
# [195 rows x 6 columns]

# %% [markdown]
# # Update Conversion_Added.csv

# %%
conversions_added = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "update", "AMS_data", "Conversions_Added.csv"))
conversions_added
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
# Concatenate the DataFrames
combined_df = pd.concat([conv_updatecov, conversions_added], ignore_index=True)
combined_df
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_58268/3857027628.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([conv_updatecov, conversions_added], ignore_index=True)
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0         I-1971    0.003731            0.25             ea         16.75
# 1        I-15803    0.004000            1.00            can        250.00
# 2         I-5505    0.001263            0.25           HEAD         49.50
# 3        I-11706    0.008547            1.00             ea        117.00
# 4        I-13308    0.024540            1.00             ea         40.75
# ..           ...         ...             ...            ...           ...
# 190       I-3810    0.010000            1.00             ea        100.00
# 191       I-3815    0.010000            0.25             ea         25.00
# 192       I-3816    0.010000            0.25             ea         25.00
# 193       I-3817    0.010000            0.25             ea         25.00
# 194       I-3820    0.013333            1.00             ea         75.00
#
#     ConvertToUom
# 0              g
# 1             ml
# 2              g
# 3              g
# 4              g
# ..           ...
# 190            g
# 191            g
# 192            g
# 193            g
# 194            g
#
# [195 rows x 6 columns]

# %%
# Add the conv_updatecov file to the masterfile, Conversions_Added
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Conversions_Added.csv")
combined_df.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Import Update Info

# %%
# Import list of prep that need convert uom to standard uom manually
Manual_PrepU = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "update", "AMS_data", "Preps_UpdateUom.csv"))
# Here we can see that UOM examples are: each, ea, slice
Manual_PrepU.head()
# Out:
#     PrepId                    Description  PakQty PakUOM InventoryGroup  \
# 0  P-14356               [PREP KAPPA MAKI     6.0   PORT              N
# 1  P-14560  2023 Chicken Caesar wrap Prep     1.0     ea              Y
# 2   P-9003       2022 Gallery Burger prep     1.0     ea              N
# 3  P-17358              2023 Poutine Prep     1.0     ea              N
# 4  P-15006    2023 Power Punch Salad Prep     1.0     ea              N
#
#     StdQty StdUom
# 0  1511.82      g
# 1   433.59      g
# 2   501.82      g
# 3   705.80      g
# 4   416.73      g

# %%
# The row of the DatFrame that contains the PrepId == P-15006
Manual_PrepU.loc[Manual_PrepU["PrepId"] == "P-15006"]
# Out:
#     PrepId                  Description  PakQty PakUOM InventoryGroup  StdQty  \
# 4  P-15006  2023 Power Punch Salad Prep     1.0     ea              N  416.73
#
#   StdUom
# 4      g

# %%
# Select the file path for new items list with category id
# New_Items_Added = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "new items added", "New_Items_Added_10.csv"))
# New_Items_Added.tail(15)

# CHECK FOR CHANGES REQUIRES


# # COMMENTED OUT LINES BELOW, commented it out this time because no new items were added

New_Items_Added = pd.read_csv("data/mapping/new items added/AMS_data/New_items_2024/2024-09-10_New_Items_assigned.csv")
New_Items_Added
# Out:
#     ItemId  CategoryID                    Description  CaseQty  CaseUOM  \
# 0   I-4104           4    CHICKEN BRST 6Z B/S 19% IQF     6.00  oz (wt)
# 1   I-4110          58                ITEM MAYO VEGAN    16.00        L
# 2   I-4111          24                MIX - FOCCACHIA    12.00        g
# 3   I-4112          37       TOMATO - SUNDRD JULIENNE   135.00        g
# 4   I-4113          24              YEAST BAKERS FRSH   130.00        g
# 5   I-4114          24  TORTILLA 10" FLOUR PRESSED TF    10.00       ea
# 6   I-4115          16          ITEM SLICED RED ONION    50.00        g
# 7   I-4116          16       ITEM SHAVED HERL CARROTS   150.00        g
# 8   I-4117          20               ITEM SESAME TOFU     2.00       Kg
# 9   I-4120          58            ITEM AIOLI CHIPOLTE    10.00       ml
# 10  I-4122          11     EGG LIQ WHL CAGE FREE FRSH     2.00     2 KG
# 11  I-4126          24           MULTIGRAIN CLUBHOUSE     2.00    slice
# 12  I-4136          17      ITEM - Black Olive Hummus     0.50        L
# 13  I-4137          24    TORTILLA 10" TOMATO PRESSED     1.00       ea
# 14  I-4138           4             ITEM SLICED TURKEY    25.00        g
# 15  I-4142          24   Bread Loaf Sourdgh Cranb T/S     2.00    slice
# 16  I-4143          20        EGG Vegan Cooked Folded    10.00       ea
# 17  I-4144           8   CHEESE CREAM PLAIN SOFT 10KG    10.00       Kg
# 18  I-3805          24   ITEM BAGEL JALAPENO & CHEESE     1.00       ea
# 19  I-3806          16         bean green pickled bar     2.00       ea
# 20  I-3807          24               ITEM BAGEL PLAIN     1.00       ea
# 21  I-3808          16          ITEM RED ONION RELISH    30.00       ml
# 22  I-3809          12     Salmon Smk Sockeye-Calypso    60.00        g
# 23  I-3810          24          ITEM BAGEL EVERYTHING     1.00       ea
# 24  I-3811           6          CHEESE SHREDDED MOZZA    20.00        g
# 25  I-3812           6    CHEESE CREAM LT SPREADABLE     50.00        g
# 26  I-3813          12                ITEM SALAD TUNA   120.00        g
# 27  I-3814          19          PEANUT BUTTER CREAMY     50.00        g
# 28  I-3815          24             Bagel - Everything     0.25       ea
# 29  I-3816          24               Bagel - Rosemary     0.25       ea
# 30  I-3817          24       Bagel - Jalapeno Cheddar     0.25       ea
# 31  I-3818          27           ALMOND MILK Barista     14.00  oz (fl)
# 32  I-3819          28         Oat Milk Barista Blend    14.00  oz (fl)
# 33  I-3820          11                      EGG SALAD     1.00       ea
#
#      PakQty PakUOM InventoryGroup
# 0       1.0     ea              Y
# 1      16.5      L              Y
# 2      14.0     ea              Y
# 3      14.0     ea              Y
# 4      14.0     ea              Y
# 5      10.0     ea              Y
# 6      10.0     ea              Y
# 7      10.0     ea              Y
# 8      10.0     ea              Y
# 9       1.0     ea              Y
# 10      4.3     Kg              Y
# 11      1.0     ea              Y
# 12     10.0     ea              Y
# 13      1.0     ea              Y
# 14      1.0     ea              Y
# 15      1.0     ea              Y
# 16     10.0     ea              Y
# 17  11000.0      g              Y
# 18      NaN    NaN              Y
# 19      NaN    NaN              Y
# 20      NaN    NaN              Y
# 21      NaN    NaN              Y
# 22      NaN    NaN              Y
# 23      NaN    NaN              Y
# 24      NaN    NaN              Y
# 25      NaN    NaN              Y
# 26      NaN    NaN              Y
# 27      NaN    NaN              Y
# 28      NaN    NaN              Y
# 29      NaN    NaN              Y
# 30      NaN    NaN              Y
# 31      NaN    NaN              Y
# 32      NaN    NaN              Y
# 33      NaN    NaN              Y

# %%
manual_adjust_items = New_Items_Added[New_Items_Added["CategoryID"] == 59]
display(manual_adjust_items)
manual_adjust_items.to_csv("data/mapping/AMS_data/Manual_Adjust_Items.csv", index=False)
# Out:
# Empty DataFrame
# Columns: [ItemId, CategoryID, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
# # Import list of items that adjusted GHGe factor manually
Manual_Factor = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping","AMS_data", "Manual_Adjust_Items.csv"))
Manual_Factor['Land Use (m^2)'] = 0
Manual_Factor['Active Total Supply Chain Emissions (kg CO2 / kg food)'] = 0
Manual_Factor['g N lost/kg product,Freshwater Withdrawals (L/FU)'] = 0
Manual_Factor["Stress-Weighted Water Use (L/FU)"] = 0
Manual_Factor.head()
# Out:
# Empty DataFrame
# Columns: [ItemId, CategoryID, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup, Land Use (m^2), Active Total Supply Chain Emissions (kg CO2 / kg food), g N lost/kg product,Freshwater Withdrawals (L/FU), Stress-Weighted Water Use (L/FU)]
# Index: []

# %% [markdown]
# ### Update Correct Uom for Preps

# %%
# Update prep list with manually adjusted uom
for index, row in Manual_PrepU.iterrows():
    PrepId = Manual_PrepU.loc[index, 'PrepId']
    qty = Manual_PrepU.loc[index, 'StdQty']
    uom = Manual_PrepU.loc[index, 'StdUom']
    Preps.loc[Preps['PrepId'] == PrepId, 'StdQty'] = qty
    Preps.loc[Preps['PrepId'] == PrepId, 'StdUom'] = uom

# %%
Preps.drop_duplicates(subset=['PrepId'], inplace=True,)

# %%
Preps.head()
# Out:
#     PrepId                    Description   PakQty PakUOM InventoryGroup  \
# 0   P-2679             Pro - Tahini Sauce      1.0      L              Y
# 1  P-15427      Pro - Vegan Chipotle Mayo     16.5      L              Y
# 2   P-7912  BCPrep - Baked Eggs for Wraps      4.3     Kg              Y
# 3  P-14403     Prep Cream Cheese - Garlic  11000.0      g              Y
#
#     StdQty StdUom
# 0   1000.0     ml
# 1  16500.0     ml
# 2   4300.0      g
# 3    450.0      g

# %%
Preps.shape
# Out:
# (4, 7)

# %%
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_List_Cleaned.csv")
Preps.to_csv(path, index = False, header = True)

# %%
Items_Assigned.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup Food Category
# 0              N           NaN
# 1              N           NaN
# 2              N           NaN
# 3              N           NaN
# 4              N           NaN

# %%
New_Items_Added.head()
# Out:
#    ItemId  CategoryID                  Description  CaseQty  CaseUOM  PakQty  \
# 0  I-4104           4  CHICKEN BRST 6Z B/S 19% IQF      6.0  oz (wt)     1.0
# 1  I-4110          58              ITEM MAYO VEGAN     16.0        L    16.5
# 2  I-4111          24              MIX - FOCCACHIA     12.0        g    14.0
# 3  I-4112          37     TOMATO - SUNDRD JULIENNE    135.0        g    14.0
# 4  I-4113          24            YEAST BAKERS FRSH    130.0        g    14.0
#
#   PakUOM InventoryGroup
# 0     ea              Y
# 1      L              Y
# 2     ea              Y
# 3     ea              Y
# 4     ea              Y

# %% [markdown]
# ### Import List of New Items with Emission Factors Category ID Assigned

# %%
# REMOVED New_Items_Added from frame right now because no new items added. Change this when adding new items (Feb 1 2024)
frames = [Items_Assigned, New_Items_Added]
Items_Assigned_Updated = pd.concat(frames).reset_index(drop=True, inplace=False).drop_duplicates()
# Items_Assigned_Updated.head()

Items_Assigned_Updated.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup Food Category
# 0              N           NaN
# 1              N           NaN
# 2              N           NaN
# 3              N           NaN
# 4              N           NaN

# %%
Items_Assigned_Updated[Items_Assigned_Updated["ItemId"] == "I-4152"]
# Out:
#      ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 479  I-4152          31  PEPPERS RED 5LB BAG    400.0       g     2.0     Kg
#
#     InventoryGroup Food Category
# 479              Y  other fruits

# %%
Items_Assigned_Updated[Items_Assigned_Updated["CategoryID"] == 63]
# Out:
# Empty DataFrame
# Columns: [ItemId, CategoryID, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup, Food Category]
# Index: []

# %%
Items_Assigned_Updated.shape
# Out:
# (568, 9)

# %%
# Double brackets used to specify the column as a dataframe and not a series
# converting the 'CategoryID' column in the Items_Assigned_Updated dataframe to numeric data type using the pd.to_numeric()
# use the apply column to apply the coversion to the entire column
Items_Assigned_Updated[['CategoryID']] = Items_Assigned_Updated[['CategoryID']].apply(pd.to_numeric)

# %%
Items_Assigned_Updated.to_csv("yo.csv")

# %%
path = os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Items_List_Assigned.csv")
Items_Assigned_Updated.to_csv(path, index = False, header = True)

# %% [markdown]
# ## Mapping Items to Footprint Factors

# %%
# DEFINITION OF MAPPING: assigning certain attributes to data points based on criteria or predefined rules.

# Map GHG footprint factors
# merges two data frames Items_Assigned_Updated and ghge_factors on the columns CategoryID and Category ID, respectively. The 
# resulting data frame is stored in mapping.

# how='left' specifies that a left join is done between Items_Assigned_Updated and ghge_factors.
# left_on='CategoryID' specifies that the join condition for Items_Assigned_Updated should be based on the 'CategoryID' column.
# right_on='Category ID' specifies that the join condition for ghge_factors should be based on the 'Category ID' column.

mapping = pd.merge(Items_Assigned_Updated, ghge_factors.loc[:,['Category ID','Food Category','Active Total Supply Chain Emissions (kg CO2 / kg food)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')
# if row in mapping has CategoryId == NaN then it assigns the value of the column Active Total Supply Chain Emissions (kg CO2 / kg food)
# to zero
for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'Active Total Supply Chain Emissions (kg CO2 / kg food)'] = 0
# drops the columns Category ID and Food Category
mapping = mapping.drop(columns=['Category ID', 'Food Category_x'])
mapping
# Out:
#       ItemId  CategoryID               Description  CaseQty  CaseUOM  PakQty  \
# 0     I-1971          35                     LIMES     0.25       ea     1.0
# 1     I-8228          55          Grey Goose 1.14L     1.00    fl oz     1.0
# 2    I-15803          31       Red Bull Watermelon     1.00      can     1.0
# 3     I-5505          36        Lettuce - Romaine      0.25     HEAD     1.0
# 4     I-8667          58          ITEM GARLIC MAYO     2.00    fl oz     1.0
# ..       ...         ...                       ...      ...      ...     ...
# 563   I-3816          24          Bagel - Rosemary     0.25       ea     NaN
# 564   I-3817          24  Bagel - Jalapeno Cheddar     0.25       ea     NaN
# 565   I-3818          27      ALMOND MILK Barista     14.00  oz (fl)     NaN
# 566   I-3819          28    Oat Milk Barista Blend    14.00  oz (fl)     NaN
# 567   I-3820          11                 EGG SALAD     1.00       ea     NaN
#
#     PakUOM InventoryGroup                          Food Category_y  \
# 0       ea              N                            citrus fruit
# 1    fl oz              N                        water & beverages
# 2      can              N                             other fruits
# 3     HEAD              N  cabbages and other brassicas (broccoli)
# 4       ml              N                           sauces & paste
# ..     ...            ...                                      ...
# 563    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 564    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 565    NaN              Y                              almond milk
# 566    NaN              Y                                 oat milk
# 567    NaN              Y                                     eggs
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                               0.3942
# 1                                               0.0000
# 2                                               0.4306
# 3                                               0.6220
# 4                                               0.0000
# ..                                                 ...
# 563                                             1.5225
# 564                                             1.5225
# 565                                             0.7021
# 566                                             0.9943
# 567                                             3.6615
#
# [568 rows x 10 columns]

# %%
# Map nitrogen footprint factors
mapping = pd.merge(mapping, nitro_factors.loc[:,['Category ID','Food Category','g N lost/kg product']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'CategoryID']):
        mapping.loc[index,'g N lost/kg product'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping
# Out:
#       ItemId  CategoryID               Description  CaseQty  CaseUOM  PakQty  \
# 0     I-1971          35                     LIMES     0.25       ea     1.0
# 1     I-8228          55          Grey Goose 1.14L     1.00    fl oz     1.0
# 2    I-15803          31       Red Bull Watermelon     1.00      can     1.0
# 3     I-5505          36        Lettuce - Romaine      0.25     HEAD     1.0
# 4     I-8667          58          ITEM GARLIC MAYO     2.00    fl oz     1.0
# ..       ...         ...                       ...      ...      ...     ...
# 563   I-3816          24          Bagel - Rosemary     0.25       ea     NaN
# 564   I-3817          24  Bagel - Jalapeno Cheddar     0.25       ea     NaN
# 565   I-3818          27      ALMOND MILK Barista     14.00  oz (fl)     NaN
# 566   I-3819          28    Oat Milk Barista Blend    14.00  oz (fl)     NaN
# 567   I-3820          11                 EGG SALAD     1.00       ea     NaN
#
#     PakUOM InventoryGroup                          Food Category_y  \
# 0       ea              N                            citrus fruit
# 1    fl oz              N                        water & beverages
# 2      can              N                             other fruits
# 3     HEAD              N  cabbages and other brassicas (broccoli)
# 4       ml              N                           sauces & paste
# ..     ...            ...                                      ...
# 563    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 564    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 565    NaN              Y                              almond milk
# 566    NaN              Y                                 oat milk
# 567    NaN              Y                                     eggs
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               0.3942
# 1                                               0.0000
# 2                                               0.4306
# 3                                               0.6220
# 4                                               0.0000
# ..                                                 ...
# 563                                             1.5225
# 564                                             1.5225
# 565                                             0.7021
# 566                                             0.9943
# 567                                             3.6615
#
#      g N lost/kg product
# 0                   2.70
# 1                   0.00
# 2                   2.70
# 3                   7.90
# 4                   6.75
# ..                   ...
# 563                14.80
# 564                14.80
# 565                 3.05
# 566                 0.68
# 567                61.20
#
# [568 rows x 11 columns]

# %%
# Map land footprint factors
mapping = pd.merge(mapping, land_factors.loc[:,['Category ID','Food Category','Land Use (m^2)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'CategoryID']):
        mapping.loc[index,'Land Use (m^2)'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping
# Out:
#       ItemId  CategoryID               Description  CaseQty  CaseUOM  PakQty  \
# 0     I-1971          35                     LIMES     0.25       ea     1.0
# 1     I-8228          55          Grey Goose 1.14L     1.00    fl oz     1.0
# 2    I-15803          31       Red Bull Watermelon     1.00      can     1.0
# 3     I-5505          36        Lettuce - Romaine      0.25     HEAD     1.0
# 4     I-8667          58          ITEM GARLIC MAYO     2.00    fl oz     1.0
# ..       ...         ...                       ...      ...      ...     ...
# 563   I-3816          24          Bagel - Rosemary     0.25       ea     NaN
# 564   I-3817          24  Bagel - Jalapeno Cheddar     0.25       ea     NaN
# 565   I-3818          27      ALMOND MILK Barista     14.00  oz (fl)     NaN
# 566   I-3819          28    Oat Milk Barista Blend    14.00  oz (fl)     NaN
# 567   I-3820          11                 EGG SALAD     1.00       ea     NaN
#
#     PakUOM InventoryGroup                          Food Category_y  \
# 0       ea              N                            citrus fruit
# 1    fl oz              N                        water & beverages
# 2      can              N                             other fruits
# 3     HEAD              N  cabbages and other brassicas (broccoli)
# 4       ml              N                           sauces & paste
# ..     ...            ...                                      ...
# 563    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 564    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 565    NaN              Y                              almond milk
# 566    NaN              Y                                 oat milk
# 567    NaN              Y                                     eggs
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               0.3942
# 1                                               0.0000
# 2                                               0.4306
# 3                                               0.6220
# 4                                               0.0000
# ..                                                 ...
# 563                                             1.5225
# 564                                             1.5225
# 565                                             0.7021
# 566                                             0.9943
# 567                                             3.6615
#
#      g N lost/kg product  Land Use (m^2)
# 0                   2.70         0.00042
# 1                   0.00         0.00000
# 2                   2.70         0.00071
# 3                   7.90         0.00230
# 4                   6.75         0.00000
# ..                   ...             ...
# 563                14.80         0.00489
# 564                14.80         0.00489
# 565                 3.05         0.00050
# 566                 0.68         0.00077
# 567                61.20         0.00684
#
# [568 rows x 12 columns]

# %%
# Map water footprint factors
# mapping: DataFrame that is used to assign sustainability-related factors (greenhouse gas emissions, nitrogen loss, and 
# water footprint) to food items based on their category and other attributes. 
mapping = pd.merge(mapping, water_factors.loc[:,['Category ID','Food Category','Freshwater Withdrawals (L/FU)', 'Stress-Weighted Water Use (L/FU)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'Freshwater Withdrawals (L/FU)'] = 0
        mapping.loc[index,'Stress-Weighted Water Use (L/FU)'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping.drop_duplicates(subset=["ItemId"], inplace=True)
mapping
# Out:
#       ItemId  CategoryID               Description  CaseQty  CaseUOM  PakQty  \
# 0     I-1971          35                     LIMES     0.25       ea     1.0
# 1     I-8228          55          Grey Goose 1.14L     1.00    fl oz     1.0
# 2    I-15803          31       Red Bull Watermelon     1.00      can     1.0
# 3     I-5505          36        Lettuce - Romaine      0.25     HEAD     1.0
# 4     I-8667          58          ITEM GARLIC MAYO     2.00    fl oz     1.0
# ..       ...         ...                       ...      ...      ...     ...
# 563   I-3816          24          Bagel - Rosemary     0.25       ea     NaN
# 564   I-3817          24  Bagel - Jalapeno Cheddar     0.25       ea     NaN
# 565   I-3818          27      ALMOND MILK Barista     14.00  oz (fl)     NaN
# 566   I-3819          28    Oat Milk Barista Blend    14.00  oz (fl)     NaN
# 567   I-3820          11                 EGG SALAD     1.00       ea     NaN
#
#     PakUOM InventoryGroup                          Food Category_y  \
# 0       ea              N                            citrus fruit
# 1    fl oz              N                        water & beverages
# 2      can              N                             other fruits
# 3     HEAD              N  cabbages and other brassicas (broccoli)
# 4       ml              N                           sauces & paste
# ..     ...            ...                                      ...
# 563    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 564    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 565    NaN              Y                              almond milk
# 566    NaN              Y                                 oat milk
# 567    NaN              Y                                     eggs
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               0.3942
# 1                                               0.0000
# 2                                               0.4306
# 3                                               0.6220
# 4                                               0.0000
# ..                                                 ...
# 563                                             1.5225
# 564                                             1.5225
# 565                                             0.7021
# 566                                             0.9943
# 567                                             3.6615
#
#      g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 0                   2.70         0.00042                         37.400
# 1                   0.00         0.00000                          1.000
# 2                   2.70         0.00071                          3.500
# 3                   7.90         0.00230                         54.500
# 4                   6.75         0.00000                         20.225
# ..                   ...             ...                            ...
# 563                14.80         0.00489                        419.200
# 564                14.80         0.00489                        419.200
# 565                 3.05         0.00050                        455.825
# 566                 0.68         0.00077                         67.030
# 567                61.20         0.00684                        632.900
#
#      Stress-Weighted Water Use (L/FU)
# 0                            1345.500
# 1                               1.000
# 2                               4.700
# 3                            2483.400
# 4                            1134.925
# ..                                ...
# 563                         12821.700
# 564                         12821.700
# 565                         32341.075
# 566                          2445.630
# 567                         18621.000
#
# [566 rows x 14 columns]

# %%
mapping[mapping["g N lost/kg product"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ItemId, CategoryID, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup, Food Category_y, Active Total Supply Chain Emissions (kg CO2 / kg food), g N lost/kg product, Land Use (m^2), Freshwater Withdrawals (L/FU), Stress-Weighted Water Use (L/FU)]
# Index: []

# %%
mapping[mapping["ItemId"] == "I-4140"]
# Out:
#      ItemId  CategoryID   Description  CaseQty CaseUOM  PakQty PakUOM  \
# 474  I-4140          40  CILANTRO 3ct      1.0   bunch   400.0     ml
#
#     InventoryGroup   Food Category_y  \
# 474              Y  other vegetables
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 474                                             0.5029
#
#      g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 474                  7.9         0.00119                           81.3
#
#      Stress-Weighted Water Use (L/FU)
# 474                            2939.5

# %%
mapping["CategoryID"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Manully Adjust Footprint Factor for Specific Items

# %%
# # For Manual_Factor: dataframe with items that adjusted GHGe factor manually.
# # It takes the id for Manual_Factor for the index being iterated and if it is equal to item id of mapping dataframe then it sets
# # the values of the columns to the manually adjusted values
# # Note: the values for the columns in mapping DataFrame is adjusted and not Manual_Factor DataFrame
# for index, row in Manual_Factor.iterrows():
#     itemId = Manual_Factor.loc[index, 'ItemId']
#     ghge = Manual_Factor.loc[index, 'Active Total Supply Chain Emissions (kg CO2 / kg food)']
#     nitro = Manual_Factor.loc[index, 'g N lost/kg product']
#     water = Manual_Factor.loc[index, 'Freshwater Withdrawals (L/FU)']
#     land = Manual_Factor.loc[index, 'Land Use (m^2)']
#     str_water = Manual_Factor.loc[index, 'Stress-Weighted Water Use (L/FU)']
#     mapping.loc[mapping['ItemId'] == itemId, 'Active Total Supply Chain Emissions (kg CO2 / kg food)'] = ghge
#     mapping.loc[mapping['ItemId'] == itemId, 'g N lost/kg product'] = nitro
#     mapping.loc[mapping['ItemId'] == itemId, 'Freshwater Withdrawals (L/FU)'] = water
#     mapping.loc[mapping['ItemId'] == itemId, 'Stress-Weighted Water Use (L/FU)'] = str_water
#     mapping.loc[mapping['ItemId'] == itemId, 'Land Use (m^2)'] = land

# %%
mapping.drop_duplicates(subset = ['ItemId'], inplace=True)
mapping.dtypes
# Out:
# ItemId                                                     object
# CategoryID                                                  int64
# Description                                                object
# CaseQty                                                   float64
# CaseUOM                                                    object
# PakQty                                                    float64
# PakUOM                                                     object
# InventoryGroup                                             object
# Food Category_y                                            object
# Active Total Supply Chain Emissions (kg CO2 / kg food)    float64
# g N lost/kg product                                       float64
# Land Use (m^2)                                            float64
# Freshwater Withdrawals (L/FU)                             float64
# Stress-Weighted Water Use (L/FU)                          float64
# dtype: object

# %%
mapping.shape
# Out:
# (566, 14)

# %%
mapping
# Out:
#       ItemId  CategoryID               Description  CaseQty  CaseUOM  PakQty  \
# 0     I-1971          35                     LIMES     0.25       ea     1.0
# 1     I-8228          55          Grey Goose 1.14L     1.00    fl oz     1.0
# 2    I-15803          31       Red Bull Watermelon     1.00      can     1.0
# 3     I-5505          36        Lettuce - Romaine      0.25     HEAD     1.0
# 4     I-8667          58          ITEM GARLIC MAYO     2.00    fl oz     1.0
# ..       ...         ...                       ...      ...      ...     ...
# 563   I-3816          24          Bagel - Rosemary     0.25       ea     NaN
# 564   I-3817          24  Bagel - Jalapeno Cheddar     0.25       ea     NaN
# 565   I-3818          27      ALMOND MILK Barista     14.00  oz (fl)     NaN
# 566   I-3819          28    Oat Milk Barista Blend    14.00  oz (fl)     NaN
# 567   I-3820          11                 EGG SALAD     1.00       ea     NaN
#
#     PakUOM InventoryGroup                          Food Category_y  \
# 0       ea              N                            citrus fruit
# 1    fl oz              N                        water & beverages
# 2      can              N                             other fruits
# 3     HEAD              N  cabbages and other brassicas (broccoli)
# 4       ml              N                           sauces & paste
# ..     ...            ...                                      ...
# 563    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 564    NaN              Y    wheat/rye (bread, pasta, baked goods)
# 565    NaN              Y                              almond milk
# 566    NaN              Y                                 oat milk
# 567    NaN              Y                                     eggs
#
#      Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               0.3942
# 1                                               0.0000
# 2                                               0.4306
# 3                                               0.6220
# 4                                               0.0000
# ..                                                 ...
# 563                                             1.5225
# 564                                             1.5225
# 565                                             0.7021
# 566                                             0.9943
# 567                                             3.6615
#
#      g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 0                   2.70         0.00042                         37.400
# 1                   0.00         0.00000                          1.000
# 2                   2.70         0.00071                          3.500
# 3                   7.90         0.00230                         54.500
# 4                   6.75         0.00000                         20.225
# ..                   ...             ...                            ...
# 563                14.80         0.00489                        419.200
# 564                14.80         0.00489                        419.200
# 565                 3.05         0.00050                        455.825
# 566                 0.68         0.00077                         67.030
# 567                61.20         0.00684                        632.900
#
#      Stress-Weighted Water Use (L/FU)
# 0                            1345.500
# 1                               1.000
# 2                               4.700
# 3                            2483.400
# 4                            1134.925
# ..                                ...
# 563                         12821.700
# 564                         12821.700
# 565                         32341.075
# 566                          2445.630
# 567                         18621.000
#
# [566 rows x 14 columns]

# %%
mapping[mapping["ItemId"] == "I-1874"]
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 16  I-1874          38  GARLIC WHOLE PEELED    200.0       g    30.0     oz
#
#    InventoryGroup  Food Category_y  \
# 16              N  root vegetables
#
#     Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 16                                             0.3062
#
#     g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 16                  7.9         0.00032                            9.9
#
#     Stress-Weighted Water Use (L/FU)
# 16                              37.9

# %%
mapping.to_csv("mapping.csv")

# %%
ingredients = pd.read_csv("data/preprocessed/AMS_data/Ingredients_List.csv")
ingredients
# Out:
#     IngredientId    Qty      Uom  Recipe
# 0         I-4099   60.0       ml  P-2824
# 1         I-2402  300.0        g  P-2824
# 2         P-9935   14.0       ea  P-2824
# 3         I-4104    6.0  oz (wt)  P-5012
# 4         P-5506   50.0        g  P-5012
# ..           ...    ...      ...     ...
# 343       P-1520    1.0       ea  R-9786
# 344       P-9279    1.0       ea  R-8350
# 345       P-4811    1.0       ea  R-3296
# 346       I-4327    9.0        g  R-4006
# 347       I-4328    1.0       ea  R-5563
#
# [348 rows x 4 columns]

# %%
map_list = mapping["ItemId"].unique()
absent_list = []

for item in ingredients["IngredientId"].unique():
    if item not in map_list and not item.startswith("P-"):
        absent_list.append(item)

# absent_list contains the IngredientIds that are not present in mapping but are present in the ingredients DataFrame
print(absent_list)
# Out:
# ['I-4145', 'I-4146', 'I-4150', 'I-4151', 'I-4191', 'I-4214', 'I-4215', 'I-4223', 'I-4230', 'I-4239', 'I-4240', 'I-4241', 'I-4242', 'I-4243', 'I-4244', 'I-4245', 'I-4246', 'I-4247', 'I-4248', 'I-4250', 'I-4251', 'I-4252', 'I-4253', 'I-4254', 'I-4255', 'I-4256', 'I-4258', 'I-4259', 'I-4260', 'I-4261', 'I-4262', 'I-4263', 'I-4264', 'I-4265', 'I-4266', 'I-4267', 'I-4268', 'I-4269', 'I-4270', 'I-4271', 'I-4272', 'I-4273', 'I-4274', 'I-4275', 'I-4276', 'I-4277', 'I-4278', 'I-4279', 'I-4280', 'I-4281', 'I-4282', 'I-4283', 'I-4284', 'I-4285', 'I-4286', 'I-4287', 'I-4288', 'I-4289', 'I-4291', 'I-4292', 'I-4293', 'I-4294', 'I-4295', 'I-4297', 'I-4298', 'I-4299', 'I-4300', 'I-4301', 'I-4302', 'I-4303', 'I-4304', 'I-4305', 'I-4306', 'I-4307', 'I-4308', 'I-4309', 'I-4310', 'I-4311', 'I-4312', 'I-4313', 'I-4314', 'I-4315', 'I-4316', 'I-4317', 'I-4318', 'I-4319', 'I-4320', 'I-4321', 'I-4322', 'I-4323', 'I-4324', 'I-4325', 'I-4326', 'I-4327', 'I-4328']

# %%
for x in absent_list:
    print(ingredients[ingredients["IngredientId"] == x])
# Out:
#     IngredientId  Qty Uom  Recipe
# 88        I-4145  1.0  ea  P-4257
# 163       I-4145  1.0  ea  P-4257
#     IngredientId   Qty Uom  Recipe
# 89        I-4146  10.0   g  P-4257
# 164       I-4146  10.0   g  P-4257
#     IngredientId  Qty Uom  Recipe
# 93        I-4150  1.0  ea  P-7873
# 168       I-4150  1.0  ea  P-7873
#     IngredientId   Qty Uom  Recipe
# 94        I-4151  15.0   g  P-4611
# 169       I-4151  15.0   g  P-4611
#     IngredientId  Qty Uom  Recipe
# 185       I-4191  2.0  ea  R-2796
#     IngredientId   Qty Uom  Recipe
# 187       I-4214  30.0  ml  R-2796
#     IngredientId   Qty Uom  Recipe
# 188       I-4215  60.0   g  R-2796
#     IngredientId  Qty    Uom  Recipe
# 189       I-4223  1.0  slice  R-3504
#     IngredientId  Qty Uom   Recipe
# 191       I-4230  1.0  ea   R-3621
# 202       I-4230  1.0  ea  R-10771
# 213       I-4230  1.0  ea  R-10763
#     IngredientId    Qty Uom   Recipe
# 201       I-4239  120.0   g  R-10771
# 209       I-4239   60.0   g  R-10763
# 301       I-4239   60.0   g   R-4770
#     IngredientId   Qty Uom  Recipe
# 203       I-4240  50.0   g  R-2040
#     IngredientId   Qty Uom  Recipe
# 205       I-4241  0.25  ea  R-7252
#     IngredientId   Qty Uom  Recipe
# 206       I-4242  0.25  ea  R-7252
#     IngredientId   Qty Uom  Recipe
# 207       I-4243  0.25  ea  R-7252
#     IngredientId  Qty Uom  Recipe
# 217       I-4244  1.0  ea  R-9669
# 218       I-4244  3.0  ea  R-5119
#     IngredientId   Qty   Uom   Recipe
# 219       I-4245  1.00  PORT  R-10064
# 256       I-4245  0.13    ea   R-6947
#     IngredientId  Qty Uom  Recipe
# 220       I-4246  1.0  ea  R-1188
#     IngredientId  Qty Uom  Recipe
# 221       I-4247  5.0   g  R-1188
#     IngredientId  Qty Uom  Recipe
# 222       I-4248  1.0  ea  R-2876
# 242       I-4248  1.0  ea  R-9837
#     IngredientId  Qty Uom  Recipe
# 224       I-4250  1.0  ea  R-5371
#     IngredientId  Qty Uom  Recipe
# 225       I-4251  1.0  ea  R-6573
#     IngredientId  Qty Uom  Recipe
# 226       I-4252  1.0  ea  R-2827
#     IngredientId  Qty Uom  Recipe
# 227       I-4253  1.0  ea  R-5808
# 247       I-4253  1.0  ea  R-9005
#     IngredientId   Qty Uom  Recipe
# 229       I-4254  1.00  ea  R-3591
# 252       I-4254  0.13  ea  R-6947
#     IngredientId   Qty Uom  Recipe
# 230       I-4255  1.00  ea  R-8433
# 251       I-4255  0.13  ea  R-6947
#     IngredientId   Qty Uom  Recipe
# 231       I-4256  1.00  ea  R-1053
# 253       I-4256  0.13  ea  R-6947
#     IngredientId   Qty Uom  Recipe
# 232       I-4258  1.00  ea  R-5315
# 250       I-4258  0.13  ea  R-6947
#     IngredientId  Qty Uom  Recipe
# 233       I-4259  1.0  ea  R-9201
#     IngredientId  Qty Uom  Recipe
# 234       I-4260  1.0  ea  R-3927
#     IngredientId  Qty Uom  Recipe
# 235       I-4261  1.0  ea  R-9317
#     IngredientId  Qty   Uom  Recipe
# 236       I-4262  1.0  PORT  R-2743
#     IngredientId   Qty   Uom  Recipe
# 237       I-4263  1.00  PORT  R-5889
# 257       I-4263  0.13    ea  R-6947
#     IngredientId   Qty Uom   Recipe
# 238       I-4264  1.00  ea  R-10977
# 255       I-4264  0.13  ea   R-6947
#     IngredientId   Qty Uom  Recipe
# 239       I-4265  1.00  ea  R-4258
# 254       I-4265  0.13  ea  R-6947
#     IngredientId  Qty Uom   Recipe
# 240       I-4266  1.0  ea   R-7126
# 245       I-4266  1.0  ea  R-10813
#     IngredientId  Qty Uom  Recipe
# 246       I-4267  1.0  ea  R-6310
#     IngredientId  Qty Uom  Recipe
# 248       I-4268  1.0  ea  R-1319
#     IngredientId  Qty Uom  Recipe
# 249       I-4269  1.0  ea  R-2832
#     IngredientId  Qty  Uom  Recipe
# 258       I-4270  1.0  can  R-6038
# 266       I-4270  1.0  can  R-2133
#     IngredientId  Qty  Uom  Recipe
# 259       I-4271  1.0  can  R-4923
# 264       I-4271  1.0  can  R-2403
#     IngredientId  Qty Uom  Recipe
# 260       I-4272  1.0  ea  R-1949
#     IngredientId  Qty  Uom  Recipe
# 261       I-4273  1.0  can  R-4946
#     IngredientId  Qty  Uom   Recipe
# 262       I-4274  1.0  can  R-10295
#     IngredientId  Qty Uom  Recipe
# 263       I-4275  1.0  ea  R-2290
#     IngredientId  Qty  Uom  Recipe
# 265       I-4276  1.0  can  R-8962
#     IngredientId  Qty Uom  Recipe
# 267       I-4277  1.0  ea  R-9727
#     IngredientId  Qty Uom  Recipe
# 268       I-4278  1.0  ea  R-3060
#     IngredientId  Qty Uom   Recipe
# 269       I-4279  1.0  ea   R-3103
# 274       I-4279  1.0  ea  R-10007
#     IngredientId  Qty Uom  Recipe
# 270       I-4280  1.0  ea  R-3103
#     IngredientId  Qty    Uom  Recipe
# 271       I-4281  1.0  slice  R-3103
#     IngredientId  Qty Uom  Recipe
# 272       I-4282  1.0  ea  R-8787
#     IngredientId  Qty    Uom   Recipe
# 273       I-4283  1.0  slice  R-10007
#     IngredientId  Qty Uom  Recipe
# 275       I-4284  1.0  ea  R-3705
#     IngredientId  Qty Uom  Recipe
# 276       I-4285  1.0  ea  R-5342
#     IngredientId  Qty Uom  Recipe
# 277       I-4286  1.0  ea  R-5342
#     IngredientId  Qty    Uom  Recipe
# 278       I-4287  1.0  slice  R-9645
#     IngredientId  Qty Uom   Recipe
# 279       I-4288  1.0  ea  R-10938
#     IngredientId  Qty Uom  Recipe
# 280       I-4289  1.0  ea  R-7932
#     IngredientId  Qty Uom  Recipe
# 283       I-4291  1.0  ea  R-4295
#     IngredientId  Qty Uom  Recipe
# 284       I-4292  1.0  ea  R-6107
# 304       I-4292  6.0  ea  R-1117
#     IngredientId  Qty Uom  Recipe
# 285       I-4293  1.0  ea  R-7537
#     IngredientId  Qty Uom  Recipe
# 287       I-4294  1.0  ea  R-8177
#     IngredientId  Qty Uom  Recipe
# 289       I-4295  1.0  ea  R-8397
#     IngredientId  Qty Uom  Recipe
# 292       I-4297  1.0  ea  R-4681
#     IngredientId   Qty      Uom  Recipe
# 294       I-4298  14.0  oz (fl)  R-2049
#     IngredientId   Qty      Uom  Recipe
# 296       I-4299  14.0  oz (fl)  R-6539
#     IngredientId  Qty      Uom   Recipe
# 299       I-4300  2.0  oz (fl)  R-10638
#     IngredientId  Qty Uom   Recipe
# 302       I-4301  1.0  ea  R-10641
#     IngredientId  Qty Uom  Recipe
# 303       I-4302  1.0  ea  R-4608
# 305       I-4302  1.0  ea  R-1117
# 306       I-4302  1.0  ea  R-2163
# 307       I-4302  1.0  ea  R-1964
#     IngredientId  Qty Uom  Recipe
# 308       I-4303  1.0  ea  R-4750
#     IngredientId  Qty Uom  Recipe
# 309       I-4304  1.0  ea  R-2104
#     IngredientId  Qty Uom  Recipe
# 310       I-4305  1.0  ea  R-1514
#     IngredientId  Qty Uom  Recipe
# 311       I-4306  1.0  ea  R-6413
#     IngredientId  Qty Uom  Recipe
# 312       I-4307  1.0  ea  R-2160
#     IngredientId  Qty Uom  Recipe
# 313       I-4308  1.0  ea  R-9423
#     IngredientId  Qty Uom  Recipe
# 314       I-4309  1.0  ea  R-4899
#     IngredientId  Qty Uom  Recipe
# 315       I-4310  1.0  ea  R-5562
#     IngredientId  Qty Uom  Recipe
# 316       I-4311  1.0  ea  R-8953
#     IngredientId  Qty Uom  Recipe
# 317       I-4312  1.0  ea  R-4510
#     IngredientId  Qty Uom  Recipe
# 318       I-4313  1.0  ea  R-9834
#     IngredientId  Qty Uom  Recipe
# 319       I-4314  1.0  ea  R-3167
#     IngredientId  Qty Uom   Recipe
# 320       I-4315  1.0  ea  R-10355
#     IngredientId  Qty Uom   Recipe
# 321       I-4316  1.0  ea  R-10440
#     IngredientId  Qty Uom  Recipe
# 322       I-4317  1.0  ea  R-8744
#     IngredientId  Qty Uom  Recipe
# 323       I-4318  1.0  ea  R-4981
#     IngredientId  Qty Uom  Recipe
# 324       I-4319  1.0  ea  R-8749
#     IngredientId  Qty Uom  Recipe
# 325       I-4320  1.0  ea  R-7669
#     IngredientId  Qty Uom  Recipe
# 326       I-4321  1.0  ea  R-4119
#     IngredientId  Qty Uom  Recipe
# 327       I-4322  1.0  ea  R-2545
#     IngredientId  Qty Uom  Recipe
# 328       I-4323  1.0  ea  R-2588
#     IngredientId  Qty Uom  Recipe
# 329       I-4324  1.0  ea  R-8062
#     IngredientId  Qty Uom  Recipe
# 331       I-4325  1.0  ea  R-7939
#     IngredientId  Qty Uom  Recipe
# 333       I-4326  1.0  ea  R-8651
#     IngredientId  Qty Uom  Recipe
# 346       I-4327  9.0   g  R-4006
#     IngredientId  Qty Uom  Recipe
# 347       I-4328  1.0  ea  R-5563

# %%
# Converts mapping DataFrame to the Mapping.csv file
path = os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Mapping.csv")
mapping.to_csv(path, index = False, header = True)
