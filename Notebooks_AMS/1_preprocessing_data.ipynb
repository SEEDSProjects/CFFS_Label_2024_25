# %% [markdown]
# ![](ubc_header.png)

# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Part I: Data Preprocessing

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import glob
import os
import random
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
from datetime import datetime
from rapidfuzz import process, fuzz

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ****
#
# ## Load Data Files
#
# ### Set Data File Path

# %%
filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "AMS_Gallery_2024_25","*.csv"))
filepath_list.append(glob.glob(os.path.join(os.getcwd(), "data", "archive", "AMS","AMS_Gallery_Data","Gallery_all_years_test_new.csv"))[0])
filepath_list
# Out:
# ['/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/raw/AMS_Gallery_2024_25/Gallery_2024S_Prep_Recipe_Detail.csv',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/raw/AMS_Gallery_2024_25/Gallery_2024S_Menu_Product_Detail.csv',
#  '/Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024/data/archive/AMS/AMS_Gallery_Data/Gallery_all_years_test_new.csv']

# %%
Preps = pd.read_csv(filepath_list[0], skiprows = 1, header=None)
Preps.columns = ["Empty","category_1","category_2", "item_descrip","batch_yield", "total_cost", "Total Cost", "Shelf_Life", "Shelf Lifr", "recipe_uom","recipe_cost", "recipe_uom_2","recipe_cost_2","line_qty","ingre_cost","item_descrip.1","uom"]
Preps = Preps.drop(columns=["Total Cost","Shelf_Life","Shelf Lifr", "category_1", "Empty","recipe_uom","recipe_cost","recipe_uom_2","recipe_cost_2"])
Preps
# Out:
#                 category_2            item_descrip             batch_yield  \
# 0        Beverages - Juice         Raspberry Puree   Batch  Yield: 2.000 L
# 1        Beverages - Juice         Raspberry Puree   Batch  Yield: 2.000 L
# 2        Beverages - Juice        Strawberry Puree   Batch  Yield: 2.000 L
# 3        Beverages - Juice        Strawberry Puree   Batch  Yield: 2.000 L
# 4         Kitchen Supplies      To Go Cutlery 2023  Batch  Yield: 1.000 ea
# ...                    ...                     ...                     ...
# 1239  Alcohol - White Wine  Sangria White Tab 2023  Batch  Yield: 16.000 L
# 1240  Alcohol - White Wine  Sangria White Tab 2023  Batch  Yield: 16.000 L
# 1241  Alcohol - White Wine  Sangria White Tab 2023  Batch  Yield: 16.000 L
# 1242  Alcohol - White Wine  Sangria White Tab 2023  Batch  Yield: 16.000 L
# 1243  Alcohol - White Wine  Sangria White Tab 2023  Batch  Yield: 16.000 L
#
#      total_cost line_qty ingre_cost                 item_descrip.1 uom
# 0      $14.0160     1.00   $14.0160         Raspberries Frozen IQF  Kg
# 1      $14.0160     1.50    $0.0000                    Water - Tap   L
# 2       $5.5242     1.00    $5.5242           Strawberries IQF FRZ  Kg
# 3       $5.5242     1.50    $0.0000                    Water - Tap   L
# 4       $0.6308     1.00    $0.0214          CUP PORT PAPER WHT 2Z  ea
# ...         ...      ...        ...                            ...  ..
# 1239  $109.2348   200.00    $4.7647        Bacardi Light Rum 750mL  ml
# 1240  $109.2348   200.00    $5.0881           Meagher's Triple Sec  ml
# 1241  $109.2348     3.00    $6.0833        JUICE orange 100% tetra   L
# 1242  $109.2348   375.00    $9.6546                   Malibu 1.14L  ml
# 1243  $109.2348   375.00    $7.4452  Abstract Apricot Brandy 750mL  ml
#
# [1244 rows x 8 columns]

# %%
Items = pd.read_csv(filepath_list[1], skiprows = 1, header=None)
Items.columns = ["Empty","category_1","category_2","Warning","Warning.1", "item_descrip","Empty.1", "drop","drop.1","drop.2","drop.3","drop.4","drop.5","PLU","drop.6","uom","item_descrip.1"]
Items = Items.drop(columns=["category_1","category_2","Warning","Warning.1","Empty","Empty.1","drop","drop.1","drop.2","drop.3","drop.4","drop.5","drop.6"])
Items
# Out:
#                     item_descrip   PLU      uom               item_descrip.1
# 0                Lone Tree Cider   1.0      can          Lone Tree Cider Can
# 1       160z Twin Sails IPA 2023  16.0  oz (fl)  Twin Sails Juice Plus Citra
# 2    16oz 33 Acers French B 2023  16.0  oz (fl)      33 Acres French Blanche
# 3    16oz Beer League lager 2023  16.0  oz (fl)           Central City Lager
# 4    16oz Fuggles Plum Sour 2023  16.0  oz (fl)            Fuggles Plum Sour
# ..                           ...   ...      ...                          ...
# 891       6oz Antares White 2023   6.0  oz (fl)      Antares Sauvignon Blanc
# 892      Bottle Antares Red 2023   1.0    750ml            Antares Carmenere
# 893    Bottle Antares White 2023   1.0    750ml      Antares Sauvignon Blanc
# 894       HH House wine Red 2024   6.0  oz (fl)            Antares Carmenere
# 895     HH House wine white 2024   6.0  oz (fl)      Antares Sauvignon Blanc
#
# [896 rows x 4 columns]

# %%
Products = Items[Items["item_descrip"].str.contains("2024S")]
Products = Products.reset_index(drop=True)
Products
# Out:
#                        item_descrip   PLU    uom  \
# 0                 2024S Beets Salad   1.0     ea
# 1                 2024S Beets Salad   1.0     ea
# 2    2024S Blackend Chick Carbonara   1.0     ea
# 3    2024S Blackend Chick Carbonara   2.0   Tbsp
# 4    2024S Blackend Chick Carbonara   1.0     ea
# ..                              ...   ...    ...
# 136         2024S Wing Honey Garlic  20.0      g
# 137         2024S Wing Honey Garlic  30.0      g
# 138         2024S Wing Honey Garlic   1.0      g
# 139         2024S Wing Honey Garlic   0.1  bunch
# 140         2024S Wing Honey Garlic   1.0     ea
#
#                     item_descrip.1
# 0            2023 Beets Salad Prep
# 1                      Misc Extras
# 2    2023 Blackened Carbonara Prep
# 3                    2023 Herb oil
# 4                      Misc Extras
# ..                             ...
# 136              BUTTER REG SALTED
# 137       HONEY LIQUID SQUEEZE CAN
# 138             SALT KOSHER COARSE
# 139                       PARSLEY
# 140                    Misc Extras
#
# [141 rows x 4 columns]

# %%
# Get unique values from the 'item_descrip.2' column in Products
prods = Products["item_descrip.1"].unique()

# Get unique values from the 'item_descrip.1' column in Preps
preps_unique = Preps["item_descrip.1"].unique()

# Filter Preps DataFrame to keep only rows where 'item_descrip' is in 'prods' or 'preps_unique'
Preps = Preps[Preps["item_descrip"].isin(prods) | Preps["item_descrip"].isin(preps_unique)]

# Reset index of Preps DataFrame
Preps = Preps.reset_index(drop=True)
Preps
# Out:
#            category_2        item_descrip               batch_yield  \
# 0    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 1    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 2    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 3    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 4    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# ..                ...                 ...                       ...
# 715        Bar Supply   Simple Syrup 2023  Batch  Yield: 700.000 ml
# 716              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 717              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 718              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 719              Misc         Misc Extras    Batch  Yield: 1.000 ea
#
#     total_cost line_qty ingre_cost                  item_descrip.1 uom
# 0      $0.6308     1.00    $0.0214           CUP PORT PAPER WHT 2Z  ea
# 1      $0.6308     1.00    $0.1447         LID Foil Board 6x8.5 SO  ea
# 2      $0.6308     1.00    $0.0169           Napkin Bev 2ply White  ea
# 3      $0.6308     1.00    $0.0471          CUTLERY FORK WOOD bulk  ea
# 4      $0.6308     1.00    $0.0471         CUTLERY SPOON WOOD soup  ea
# ..         ...      ...        ...                             ...  ..
# 715    $1.1568   440.00    $1.1568           SUGAR GRANULATED FINE   g
# 716    $0.3051     1.00    $0.1648  ECO 9x6 Kraft Hinged Container  ea
# 717    $0.3051     1.00    $0.0480        CUTLERY FORK WOODEN ECO   ea
# 718    $0.3051     1.00    $0.0463       CUTLERY SPOON WOODEN ECO   ea
# 719    $0.3051     1.00    $0.0461        CUTLERY KNIFE WOODEN ECO  ea
#
# [720 rows x 8 columns]

# %%
old_items = pd.read_csv(filepath_list[-1])
old_items = old_items.drop(columns=['item_num.2', 'item_num.1'])
old_items
# Out:
#       item_num                   item_descrip  pak_physical_yield pak_uom  \
# 0        17284   2022 goose & Watermelon bull                 1.0    PORT
# 1        17284   2022 goose & Watermelon bull                 1.0    PORT
# 2        17284   2022 goose & Watermelon bull                 1.0    PORT
# 3        18292         Vegan Caesar wrap 2022                 1.0      ea
# 4        18292         Vegan Caesar wrap 2022                 1.0      ea
# ...        ...                            ...                 ...     ...
# 2153     18049    Yellow Curry Prep Gall.2023                 1.0    PORT
# 2154     18049    Yellow Curry Prep Gall.2023                 1.0    PORT
# 2155     18049    Yellow Curry Prep Gall.2023                 1.0    PORT
# 2156     18049    Yellow Curry Prep Gall.2023                 1.0    PORT
# 2157     18049    Yellow Curry Prep Gall.2023                 1.0    PORT
#
#      pak_uom.1  pak_factored_cost  line_item_num  line_qty items_comments  \
# 0           ea           0.559100           1971      0.25            NaN
# 1        fl oz           1.553600           8228      1.00            NaN
# 2          can           1.920800          15803      1.00            NaN
# 3         HEAD           2.466700           5505      0.25            NaN
# 4           ml           0.189270           8667      2.00            NaN
# ...        ...                ...            ...       ...            ...
# 2153         g           0.005200           2262      1.00            NaN
# 2154        oz           0.003968          14434     80.00            NaN
# 2155      PORT           0.200000          15477      1.00            NaN
# 2156         g           0.005300          15637     20.00            NaN
# 2157         L           0.157331          17941      8.00            NaN
#
#                  item_descrip.1 inv_flag    uom
# 0                         LIMES        N     ea
# 1              Grey Goose 1.14L        N  fl oz
# 2           Red Bull Watermelon        N    can
# 3            Lettuce - Romaine         N   HEAD
# 4              ITEM GARLIC MAYO        N  fl oz
# ...                         ...      ...    ...
# 2153               SESAME SEEDS        Y      g
# 2154  Potato yellow Med 5lb bag        Y      g
# 2155           2022 Jasmin rice        Y   PORT
# 2156      Whole Green Beans IQF        Y      g
# 2157       Porch - Yellow Curry        Y  fl oz
#
# [2158 rows x 12 columns]

# %%
used_ids = []
def assign_ids(df):
    # Preprocessing function
    def preprocess(description):
        description = description.lower()
        description = re.sub(r'\s+', ' ', description).strip()
        description = re.sub(r'[^\w\s]', '', description)
        return description

    # Apply preprocessing
    old_items['Normalized_Description'] = old_items['item_descrip'].apply(preprocess)
    df['Normalized_Description'] = df['item_descrip'].apply(preprocess)

    # Create a mapping from normalized description to item_num
    desc_to_item_num = {row['Normalized_Description']: row['item_num'] for idx, row in old_items.iterrows()}

    # Exact match
    df['item_num'] = df['Normalized_Description'].apply(lambda x: desc_to_item_num.get(x))

    # Fuzzy matching function
    def get_all_matches(description, choices, threshold=80):
        matches = process.extract(description, choices, scorer=fuzz.token_sort_ratio)
        return [match for match in matches if match[1] >= threshold]

    # Apply fuzzy matching where exact match failed
    df['Potential_Matches'] = df['Normalized_Description'].apply(lambda x: get_all_matches(x, desc_to_item_num.keys()))

    # Assign item_num directly if there is exactly one potential match
    def assign_item_num_or_matches(row):
        potential_matches = row['Potential_Matches']
        if potential_matches and len(potential_matches) == 1:
            # Assign the item_num of the single potential match
            return desc_to_item_num.get(potential_matches[0][0])
        else:
            # Keep as None if no match or multiple matches
            return None

    # Apply the function to assign item_num
    df['item_num'] = df.apply(lambda row: assign_item_num_or_matches(row), axis=1)

    # Add the best potential match item_num to Items
    def add_best_potential_match_item_num(row):
        potential_matches = row['Potential_Matches']
        if len(potential_matches) > 1:
            best_match = max(potential_matches, key=lambda x: x[1])
            return desc_to_item_num.get(best_match[0])
        return row['item_num']

    # Update Items to include best potential match item_num if exact match fails
    df['item_num'] = df.apply(lambda row: add_best_potential_match_item_num(row), axis=1)

    # Function to generate unique random item_num
    def generate_unique_random_item_num(existing_nums, start=1000):
        random.seed(42) #DO NOT CHANGE
        while True:
            num = random.randint(start, start + 10000)
            if num not in existing_nums and num not in used_ids:
                used_ids.append(num)
                return num

    # Get the set of used item_nums
    used_item_nums = set(old_items['item_num']).union(set(df['item_num'].dropna()))

    # Assign random item_num for rows without one, ensuring same item_descrip gets same item_num
    unassigned = df[df['item_num'].isna()]
    unique_descriptions = unassigned['Normalized_Description'].unique()

    for desc in unique_descriptions:
        random_num = generate_unique_random_item_num(used_item_nums)
        used_item_nums.add(random_num)
        df.loc[df['Normalized_Description'] == desc, 'item_num'] = random_num

    df["item_num"] = df["item_num"].astype(int)
    df.to_csv("df.csv")
    # Optionally, remove the Potential_Matches column if no longer needed
    df.drop(columns=['Potential_Matches',"Normalized_Description"], inplace=True)
    # Print the result
    return df

# %%
Preps = assign_ids(Preps)
Products = assign_ids(Products)

# %%
#Ensure 'line_item_num' column exists in Items
Preps['line_item_num'] = 0

# Create a dictionary for quick lookup from old_items
old_items_dict = old_items.set_index('item_descrip.1')['line_item_num'].to_dict()
old_ids = list(set(old_items["line_item_num"].unique()))
ID = old_ids[0]

# Iterate through Items and update line_item_num
for index, row in Preps.iterrows():
    description = row['item_descrip.1']
    if description in old_items_dict:
        Preps.at[index, 'line_item_num'] = old_items_dict[description]
    else:
        while ID in old_ids:
            ID += 1
        old_items_dict[description] = ID
        old_ids.append(ID)
        Preps.at[index, "line_item_num"] = ID

# Output the updated DataFrame
display(Preps)
# Out:
#            category_2        item_descrip               batch_yield  \
# 0    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 1    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 2    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 3    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# 4    Kitchen Supplies  To Go Cutlery 2023    Batch  Yield: 1.000 ea
# ..                ...                 ...                       ...
# 715        Bar Supply   Simple Syrup 2023  Batch  Yield: 700.000 ml
# 716              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 717              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 718              Misc         Misc Extras    Batch  Yield: 1.000 ea
# 719              Misc         Misc Extras    Batch  Yield: 1.000 ea
#
#     total_cost line_qty ingre_cost                  item_descrip.1 uom  \
# 0      $0.6308     1.00    $0.0214           CUP PORT PAPER WHT 2Z  ea
# 1      $0.6308     1.00    $0.1447         LID Foil Board 6x8.5 SO  ea
# 2      $0.6308     1.00    $0.0169           Napkin Bev 2ply White  ea
# 3      $0.6308     1.00    $0.0471          CUTLERY FORK WOOD bulk  ea
# 4      $0.6308     1.00    $0.0471         CUTLERY SPOON WOOD soup  ea
# ..         ...      ...        ...                             ...  ..
# 715    $1.1568   440.00    $1.1568           SUGAR GRANULATED FINE   g
# 716    $0.3051     1.00    $0.1648  ECO 9x6 Kraft Hinged Container  ea
# 717    $0.3051     1.00    $0.0480        CUTLERY FORK WOODEN ECO   ea
# 718    $0.3051     1.00    $0.0463       CUTLERY SPOON WOODEN ECO   ea
# 719    $0.3051     1.00    $0.0461        CUTLERY KNIFE WOODEN ECO  ea
#
#      item_num  line_item_num
# 0       17297           4099
# 1       17297           4100
# 2       17297           4101
# 3       17297           4102
# 4       17297           4103
# ..        ...            ...
# 715     16844           2367
# 716      4814           4239
# 717      4814           9601
# 718      4814           9599
# 719      4814           9600
#
# [720 rows x 10 columns]

# %%
def extract_yield_and_uom(batch_yield):
    match = re.search(r'Batch\s*Yield:\s*([\d.]+)\s*(\w+)', batch_yield)
    if match:
        physical_yield = float(match.group(1))
        uom = match.group(2)
        return physical_yield, uom
    else:
        print(f"Error parsing batch_yield '{batch_yield}': pattern not found")
        return None, None

# Apply the function and create new columns
Preps['pak_physical_yield'], Preps['pak_uom'] = zip(*Preps['batch_yield'].apply(extract_yield_and_uom))
Preps = Preps.drop(columns=["batch_yield"])
Preps
# Out:
#            category_2        item_descrip total_cost line_qty ingre_cost  \
# 0    Kitchen Supplies  To Go Cutlery 2023    $0.6308     1.00    $0.0214
# 1    Kitchen Supplies  To Go Cutlery 2023    $0.6308     1.00    $0.1447
# 2    Kitchen Supplies  To Go Cutlery 2023    $0.6308     1.00    $0.0169
# 3    Kitchen Supplies  To Go Cutlery 2023    $0.6308     1.00    $0.0471
# 4    Kitchen Supplies  To Go Cutlery 2023    $0.6308     1.00    $0.0471
# ..                ...                 ...        ...      ...        ...
# 715        Bar Supply   Simple Syrup 2023    $1.1568   440.00    $1.1568
# 716              Misc         Misc Extras    $0.3051     1.00    $0.1648
# 717              Misc         Misc Extras    $0.3051     1.00    $0.0480
# 718              Misc         Misc Extras    $0.3051     1.00    $0.0463
# 719              Misc         Misc Extras    $0.3051     1.00    $0.0461
#
#                      item_descrip.1 uom  item_num  line_item_num  \
# 0             CUP PORT PAPER WHT 2Z  ea     17297           4099
# 1           LID Foil Board 6x8.5 SO  ea     17297           4100
# 2             Napkin Bev 2ply White  ea     17297           4101
# 3            CUTLERY FORK WOOD bulk  ea     17297           4102
# 4           CUTLERY SPOON WOOD soup  ea     17297           4103
# ..                              ...  ..       ...            ...
# 715           SUGAR GRANULATED FINE   g     16844           2367
# 716  ECO 9x6 Kraft Hinged Container  ea      4814           4239
# 717        CUTLERY FORK WOODEN ECO   ea      4814           9601
# 718       CUTLERY SPOON WOODEN ECO   ea      4814           9599
# 719        CUTLERY KNIFE WOODEN ECO  ea      4814           9600
#
#      pak_physical_yield pak_uom
# 0                   1.0      ea
# 1                   1.0      ea
# 2                   1.0      ea
# 3                   1.0      ea
# 4                   1.0      ea
# ..                  ...     ...
# 715               700.0      ml
# 716                 1.0      ea
# 717                 1.0      ea
# 718                 1.0      ea
# 719                 1.0      ea
#
# [720 rows x 11 columns]

# %%
Products["inv_flag"] = "Y"
Preps["inv_flag"] = "Y"

# %%
Preps.to_csv("Preps.csv", index=False)
Products.to_csv("Products.csv", index=False)

# %% [markdown]
# ### Import Items List

# %%
Preps = Preps[(Preps["item_descrip"] != "To Go Cutlery 2023") & (Preps["item_descrip"] != "Misc Extras")]
Preps.reset_index(drop=True, inplace=True)
Preps
# Out:
#        category_2           item_descrip total_cost line_qty ingre_cost  \
# 0      Commissary  Pro - Kansas City BBQ    $5.2557    20.00    $0.1608
# 1      Commissary  Pro - Kansas City BBQ    $5.2557   660.00    $2.1109
# 2      Commissary  Pro - Kansas City BBQ    $5.2557    22.50    $0.7488
# 3      Commissary  Pro - Kansas City BBQ    $5.2557    15.00    $0.1752
# 4      Commissary  Pro - Kansas City BBQ    $5.2557    20.00    $0.3395
# ..            ...                    ...        ...      ...        ...
# 705  Prepared Frz   Pro - Marinara Sauce   $19.9424    60.00    $2.1495
# 706  Prepared Frz   Pro - Marinara Sauce   $19.9424    18.00    $0.3147
# 707  Prepared Frz   Pro - Marinara Sauce   $19.9424   500.00    $2.2223
# 708  Prepared Frz   Pro - Marinara Sauce   $19.9424     1.00    $6.7740
# 709    Bar Supply      Simple Syrup 2023    $1.1568   440.00    $1.1568
#
#                      item_descrip.1 uom  item_num  line_item_num  \
# 0           JALAPENO PEPPER - FRESH   g      6068           1927
# 1                   KETCHUP VOL PAK  ml      6068           1958
# 2                       MUSTARD DRY   g      6068           2025
# 3             SPICE CAYENNE SHAKER   ml      6068           2323
# 4               SPICE CHILI POWDER    g      6068           2324
# ..                              ...  ..       ...            ...
# 705                     BASIL Fresh   g     15368           3005
# 706  SPICE CHILI RED PEPPER CRUSHED   g     15368           3804
# 707              Onion White Peeled   g     15368           6865
# 708       Sawmill Creek - White 16L   L     15368           9117
# 709           SUGAR GRANULATED FINE   g     16844           2367
#
#      pak_physical_yield pak_uom inv_flag
# 0                  1.25       L        Y
# 1                  1.25       L        Y
# 2                  1.25       L        Y
# 3                  1.25       L        Y
# 4                  1.25       L        Y
# ..                  ...     ...      ...
# 705                7.00       L        Y
# 706                7.00       L        Y
# 707                7.00       L        Y
# 708                7.00       L        Y
# 709              700.00      ml        Y
#
# [710 rows x 12 columns]

# %%
# Ensure 'item_num' and 'line_item_num' are strings
Preps = Preps.astype({"item_num": str, "line_item_num": str})

# Get unique descriptions from 'item_descrip'
unique_descriptions = Preps["item_descrip"].unique()

# Iterate over rows to update 'item_num' and 'line_item_num'
for idx, row in Preps.iterrows():
    # Prepend 'P-' if not already present in 'item_num'
    if not row["item_num"].startswith("P-"):
        Preps.at[idx, "item_num"] = "P-" + row["item_num"]
    
for idx, row in Preps.iterrows(): 
    # Update 'line_item_num' based on 'item_descrip'
    if row["item_descrip.1"] in unique_descriptions:
        matching_item_num = Preps.loc[Preps["item_descrip"] == row["item_descrip.1"], "item_num"].values[0]
        print(f"Matching item_num: {matching_item_num}")
        Preps.at[idx, "line_item_num"] = matching_item_num
    else:
        # Prepend 'I-' if not already present in 'line_item_num'
        if not row["line_item_num"].startswith("I-"):
            Preps.at[idx, "line_item_num"] = "I-" + row["line_item_num"]

# Optional: Verify the changes
Preps.head(20)
# Out:
# Matching item_num: P-18052
# Matching item_num: P-6881
# Matching item_num: P-18052
# Matching item_num: P-16778
# Matching item_num: P-18274
# Matching item_num: P-12209
# Matching item_num: P-18349
# Matching item_num: P-17486
# Matching item_num: P-17037
# Matching item_num: P-16856
# Matching item_num: P-17037
# Matching item_num: P-11706
# Matching item_num: P-3286
# Matching item_num: P-2679
# Matching item_num: P-11706
# Matching item_num: P-11125
# Matching item_num: P-16222
# Matching item_num: P-16221
# Matching item_num: P-18334
# Matching item_num: P-12209
# Matching item_num: P-18268
# Matching item_num: P-18336
# Matching item_num: P-16571
# Matching item_num: P-16571
# Matching item_num: P-17360
# Matching item_num: P-2679
# Matching item_num: P-16778
# Matching item_num: P-3547
# Matching item_num: P-15007
# Matching item_num: P-2824
# Matching item_num: P-18349
# Matching item_num: P-18329
# Matching item_num: P-11706
# Matching item_num: P-16855
# Matching item_num: P-16780
# Matching item_num: P-16856
# Matching item_num: P-9279
# Matching item_num: P-4657
# Matching item_num: P-2584
# Matching item_num: P-10459
# Matching item_num: P-2679
# Matching item_num: P-3615
# Matching item_num: P-16855
# Matching item_num: P-4582
# Matching item_num: P-2679
# Matching item_num: P-4657
# Matching item_num: P-5557
# Matching item_num: P-6514
# Matching item_num: P-1520
# Matching item_num: P-8359
# Matching item_num: P-16793
# Matching item_num: P-2679
# Matching item_num: P-16794
# Matching item_num: P-16855
# Matching item_num: P-16860
# Matching item_num: P-3286
# Matching item_num: P-7224
# Matching item_num: P-18380
# Matching item_num: P-9935
# Matching item_num: P-17305
# Matching item_num: P-5333
# Matching item_num: P-3615
# Matching item_num: P-15368
# Matching item_num: P-16855
# Matching item_num: P-15368
# Matching item_num: P-18336
# Matching item_num: P-18268
# Matching item_num: P-4657
# Matching item_num: P-18381
# Matching item_num: P-10891
# Matching item_num: P-13736
# Matching item_num: P-6635
# Matching item_num: P-2139
# Matching item_num: P-1750
# Matching item_num: P-2291
# Matching item_num: P-16575
# Matching item_num: P-8527
# Matching item_num: P-16748
# Matching item_num: P-7201
# Matching item_num: P-6925
# Matching item_num: P-10044
# Matching item_num: P-5741
#     category_2             item_descrip total_cost line_qty ingre_cost  \
# 0   Commissary    Pro - Kansas City BBQ    $5.2557    20.00    $0.1608
# 1   Commissary    Pro - Kansas City BBQ    $5.2557   660.00    $2.1109
# 2   Commissary    Pro - Kansas City BBQ    $5.2557    22.50    $0.7488
# 3   Commissary    Pro - Kansas City BBQ    $5.2557    15.00    $0.1752
# 4   Commissary    Pro - Kansas City BBQ    $5.2557    20.00    $0.3395
# 5   Commissary    Pro - Kansas City BBQ    $5.2557     1.00    $0.0299
# 6   Commissary    Pro - Kansas City BBQ    $5.2557     5.00    $0.1167
# 7   Commissary    Pro - Kansas City BBQ    $5.2557    10.00    $0.3582
# 8   Commissary    Pro - Kansas City BBQ    $5.2557   200.00    $0.4892
# 9   Commissary    Pro - Kansas City BBQ    $5.2557   200.00    $0.0000
# 10  Commissary    Pro - Kansas City BBQ    $5.2557    20.00    $0.1517
# 11  Commissary    Pro - Kansas City BBQ    $5.2557   200.00    $0.4268
# 12  Commissary    Pro - Kansas City BBQ    $5.2557    22.00    $0.0788
# 13  Commissary    Pro - Kansas City BBQ    $5.2557     3.00    $0.0692
# 14        Food  2023 Alfredo Sauce Gal.    $6.6869   300.00    $1.7280
# 15        Food  2023 Alfredo Sauce Gal.    $6.6869    60.00    $0.0577
# 16        Food  2023 Alfredo Sauce Gal.    $6.6869   100.00    $1.3536
# 17        Food  2023 Alfredo Sauce Gal.    $6.6869     5.00    $0.0179
# 18        Food  2023 Alfredo Sauce Gal.    $6.6869     0.50    $3.4211
# 19        Food  2023 Alfredo Sauce Gal.    $6.6869     2.00    $0.1086
#
#                  item_descrip.1  uom item_num line_item_num  \
# 0       JALAPENO PEPPER - FRESH    g   P-6068        I-1927
# 1               KETCHUP VOL PAK   ml   P-6068        I-1958
# 2                   MUSTARD DRY    g   P-6068        I-2025
# 3         SPICE CAYENNE SHAKER    ml   P-6068        I-2323
# 4           SPICE CHILI POWDER     g   P-6068        I-2324
# 5   SPICE CUMIN SEED GROUND BOX    g   P-6068        I-2329
# 6      SPICE GARLIC GRANULATED     g   P-6068        I-4105
# 7      SPICE Pepper Black Grnd     g   P-6068        I-4106
# 8              SUGAR GOLDEN YEL    g   P-6068        I-2366
# 9                   Water - Tap   ml   P-6068        I-2640
# 10                 Ginger Fresh    g   P-6068        I-2958
# 11           Vinegar White Wine   ml   P-6068        I-3180
# 12           SALT KOSHER COARSE    g   P-6068        I-4091
# 13      Onion Granulated powder    g   P-6068        I-5095
# 14           CREAM WHIPPING 33%   ml   P-2824        I-1783
# 15           FLOUR ALL PURPOSE.    g   P-2824       I-13842
# 16            BUTTER REG SALTED    g   P-2824        I-2037
# 17           SALT KOSHER COARSE    g   P-2824        I-4091
# 18            MILK-3.25% 4L jug  gal   P-2824       I-14484
# 19          SPICE Nutmeg ground    g   P-2824        I-4107
#
#     pak_physical_yield pak_uom inv_flag
# 0                 1.25       L        Y
# 1                 1.25       L        Y
# 2                 1.25       L        Y
# 3                 1.25       L        Y
# 4                 1.25       L        Y
# 5                 1.25       L        Y
# 6                 1.25       L        Y
# 7                 1.25       L        Y
# 8                 1.25       L        Y
# 9                 1.25       L        Y
# 10                1.25       L        Y
# 11                1.25       L        Y
# 12                1.25       L        Y
# 13                1.25       L        Y
# 14             2250.00      ml        Y
# 15             2250.00      ml        Y
# 16             2250.00      ml        Y
# 17             2250.00      ml        Y
# 18             2250.00      ml        Y
# 19             2250.00      ml        Y

# %%
Preps.dtypes
# Out:
# category_2             object
# item_descrip           object
# total_cost             object
# line_qty               object
# ingre_cost             object
# item_descrip.1         object
# uom                    object
# item_num               object
# line_item_num          object
# pak_physical_yield    float64
# pak_uom                object
# inv_flag               object
# dtype: object

# %%
Preps.to_csv("Preps.csv", index=False)

# %%
Products = Products[(Products["item_descrip.1"] != "To Go Cutlery 2023") & (Products["item_descrip.1"] != "Misc Extras")]
Products
# Out:
#                        item_descrip   PLU    uom  \
# 0                 2024S Beets Salad   1.0     ea
# 2    2024S Blackend Chick Carbonara   1.0     ea
# 3    2024S Blackend Chick Carbonara   2.0   Tbsp
# 5       2024S Chicken Caesar (Wrap)   1.0     ea
# 7         2024S Chicken Pesto Penne   1.0     ea
# ..                              ...   ...    ...
# 135         2024S Wing Honey Garlic   5.0      g
# 136         2024S Wing Honey Garlic  20.0      g
# 137         2024S Wing Honey Garlic  30.0      g
# 138         2024S Wing Honey Garlic   1.0      g
# 139         2024S Wing Honey Garlic   0.1  bunch
#
#                     item_descrip.1  item_num inv_flag
# 0            2023 Beets Salad Prep      2654        Y
# 2    2023 Blackened Carbonara Prep      7227        Y
# 3                    2023 Herb oil      7227        Y
# 5    2023 Chicken Caesar wrap Prep      8990        Y
# 7               2023 Pesto Chicken      5554        Y
# ..                             ...       ...      ...
# 135            GARLIC WHOLE PEELED      2084        Y
# 136              BUTTER REG SALTED      2084        Y
# 137       HONEY LIQUID SQUEEZE CAN      2084        Y
# 138             SALT KOSHER COARSE      2084        Y
# 139                       PARSLEY       2084        Y
#
# [105 rows x 6 columns]

# %%
#Ensure 'line_item_num' column exists in Items
Products.loc[:,'line_item_num'] = ""

# Create a dictionary for quick lookup from old_items
items_dict = Preps.set_index('item_descrip.1')['line_item_num'].to_dict()
items_dict.update(Preps.set_index('item_descrip')['item_num'].to_dict())

ids = list(set(Preps["line_item_num"].unique()))
ids.extend(Preps["item_num"].unique())
ids = [int(str(id).split("-")[1]) for id in ids]
print(ids)
ID = ids[0]

# Iterate through Items and update line_item_num
for index, row in Products.iterrows():
    description = row['item_descrip.1']
    if description in items_dict:
        Products.at[index, 'line_item_num'] = items_dict[description]
    else:
        while ID in ids:
            ID += 1
        print(row["item_descrip.1"], "not in Preps")
        items_dict[description] = "I-" + str(ID)
        ids.append(ID)
        Products.at[index, "line_item_num"] = "I-" + str(ID)

# Output the updated DataFrame
display(Products)
# Out:
# [4194, 1917, 1859, 4118, 5777, 17946, 4148, 16793, 1655, 1588, 4107, 6881, 4226, 5333, 4204, 2068, 2139, 2323, 4189, 13842, 17486, 4119, 1927, 5008, 16778, 4192, 4202, 4129, 1941, 16748, 3615, 4220, 5505, 1750, 6204, 2329, 4108, 9279, 4232, 4160, 14484, 1874, 2037, 2087, 4140, 18268, 15368, 2436, 4141, 18380, 1660, 4205, 1995, 16575, 4153, 2640, 3354, 4124, 4152, 4158, 3286, 16780, 4236, 4139, 3258, 4109, 15200, 4125, 6514, 4128, 7224, 8975, 3804, 2400, 4186, 16144, 2443, 14126, 1610, 4133, 7775, 6925, 4091, 6461, 2347, 5941, 1635, 2324, 14422, 8851, 14977, 18329, 4127, 7645, 2339, 14556, 4184, 4211, 17360, 4105, 4582, 4166, 12132, 4131, 2183, 18052, 7656, 4172, 4135, 17129, 4235, 5557, 2093, 4171, 14532, 4231, 9117, 14790, 18336, 1789, 4208, 3180, 16855, 13736, 5731, 2378, 5575, 15221, 4162, 17977, 4206, 16699, 4014, 1649, 10834, 13691, 5741, 2153, 18349, 1908, 15007, 11125, 14429, 2679, 2102, 4174, 9935, 4195, 4147, 2366, 16856, 11706, 5126, 14419, 7338, 4229, 4190, 2464, 4188, 1892, 18381, 13308, 4132, 4180, 16571, 13001, 3005, 2066, 16860, 13813, 1924, 4187, 14442, 14127, 5075, 15834, 2446, 12212, 4154, 4201, 2181, 11704, 2291, 5803, 4156, 16221, 7201, 7980, 4219, 1783, 4149, 15554, 5264, 4234, 4222, 10459, 14948, 8527, 4925, 4170, 2958, 17991, 12351, 2086, 1689, 2341, 4134, 14978, 2920, 5773, 4233, 2824, 12764, 18334, 2402, 2121, 10955, 8359, 4237, 14418, 18051, 2967, 17037, 1882, 12173, 5095, 2992, 3498, 4106, 2025, 1894, 4216, 1782, 16794, 4203, 5203, 4212, 1958, 17305, 10044, 10891, 2951, 5220, 4155, 12209, 4161, 14423, 16222, 4193, 6865, 2584, 4173, 2257, 4657, 2119, 2159, 11093, 2203, 6203, 2367, 12361, 1520, 3547, 2243, 5204, 6635, 1695, 2349, 15637, 18274, 16224, 6068, 2824, 1409, 17360, 18275, 5506, 16778, 8990, 14560, 10589, 17366, 18334, 16855, 18349, 16760, 18458, 17378, 11706, 5012, 16794, 17013, 4657, 18274, 18295, 16221, 16222, 16571, 11125, 3286, 17358, 15006, 16793, 18268, 2679, 16860, 9935, 18329, 18451, 18272, 15057, 16780, 16782, 16856, 15013, 2424, 10674, 7912, 1520, 1488, 2535, 4582, 4811, 9279, 10863, 1434, 10195, 4257, 9928, 7873, 18052, 18327, 4611, 18380, 17301, 17305, 8359, 8988, 10654, 5557, 1106, 3615, 7924, 6574, 5552, 3547, 15007, 4527, 6514, 2674, 2519, 18336, 17486, 12209, 17037, 18381, 18470, 18575, 7224, 2584, 6881, 6635, 16748, 10891, 5333, 1711, 13736, 8527, 9785, 3045, 7201, 2291, 10044, 5803, 6925, 16575, 10459, 4150, 2139, 1750, 4733, 5741, 2307, 15368, 16844]
# ITEM SAUCE BURGER not in Preps
# DRESSING Ranch BtrMilk not in Preps
# Lemon Pepper Seasoning not in Preps
# ITEM G21- MANGO HABANERO SAUCE not in Preps
# Fries Sweet Potato  not in Preps
# Belgian Waffle Ind.Wrapped 70g not in Preps
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_70459/3281539405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products.loc[:,'line_item_num'] = ""
#                        item_descrip   PLU    uom  \
# 0                 2024S Beets Salad   1.0     ea
# 2    2024S Blackend Chick Carbonara   1.0     ea
# 3    2024S Blackend Chick Carbonara   2.0   Tbsp
# 5       2024S Chicken Caesar (Wrap)   1.0     ea
# 7         2024S Chicken Pesto Penne   1.0     ea
# ..                              ...   ...    ...
# 135         2024S Wing Honey Garlic   5.0      g
# 136         2024S Wing Honey Garlic  20.0      g
# 137         2024S Wing Honey Garlic  30.0      g
# 138         2024S Wing Honey Garlic   1.0      g
# 139         2024S Wing Honey Garlic   0.1  bunch
#
#                     item_descrip.1  item_num inv_flag line_item_num
# 0            2023 Beets Salad Prep      2654        Y       P-18275
# 2    2023 Blackened Carbonara Prep      7227        Y        P-5506
# 3                    2023 Herb oil      7227        Y       P-17013
# 5    2023 Chicken Caesar wrap Prep      8990        Y       P-14560
# 7               2023 Pesto Chicken      5554        Y       P-18295
# ..                             ...       ...      ...           ...
# 135            GARLIC WHOLE PEELED      2084        Y        I-1874
# 136              BUTTER REG SALTED      2084        Y        I-2037
# 137       HONEY LIQUID SQUEEZE CAN      2084        Y        I-1917
# 138             SALT KOSHER COARSE      2084        Y        I-4091
# 139                       PARSLEY       2084        Y        I-2087
#
# [105 rows x 7 columns]

# %%
Products.to_csv("Products.csv", index=False)

# %% [markdown]
# ### Extracting all Preps

# %%
# Filter the DataFrame to include only rows where 'item_num' starts with 'P-'
Preperations = Preps.copy()

# Select specific columns from the filtered DataFrame
Preperations = Preperations[['item_num', 'item_descrip', 'pak_physical_yield', 'pak_uom', 'inv_flag']]
Preperations.rename(columns={'item_num': 'PrepId', 'item_descrip': 'Description', 'pak_physical_yield': 'PakQty', 'pak_uom': 'PakUOM', 'inv_flag': 'InventoryGroup'}, inplace=True)
Preperations.drop_duplicates(subset=["PrepId"], inplace=True)
Preperations.reset_index(drop=True, inplace=True)
Preperations
# Out:
#       PrepId              Description   PakQty PakUOM InventoryGroup
# 0     P-6068    Pro - Kansas City BBQ     1.25      L              Y
# 1     P-2824  2023 Alfredo Sauce Gal.  2250.00     ml              Y
# 2     P-1409        2023 Basmati Prep     2.00     Kg              Y
# 3    P-17360   2023 Beef Gravy (prep)     4.50      L              Y
# 4    P-18275    2023 Beets Salad Prep     1.00     ea              Y
# ..       ...                      ...      ...    ...            ...
# 109   P-4733                 Tzatziki     4.00     Kg              Y
# 110   P-5741             Veggie Stock     6.00     Kg              Y
# 111   P-2307                  Waffles    55.00     ea              Y
# 112  P-15368     Pro - Marinara Sauce     7.00      L              Y
# 113  P-16844        Simple Syrup 2023   700.00     ml              Y
#
# [114 rows x 5 columns]

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Preps_List.csv")
Preperations.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Extracting all Items

# %%
Preps
# Out:
#        category_2           item_descrip total_cost line_qty ingre_cost  \
# 0      Commissary  Pro - Kansas City BBQ    $5.2557    20.00    $0.1608
# 1      Commissary  Pro - Kansas City BBQ    $5.2557   660.00    $2.1109
# 2      Commissary  Pro - Kansas City BBQ    $5.2557    22.50    $0.7488
# 3      Commissary  Pro - Kansas City BBQ    $5.2557    15.00    $0.1752
# 4      Commissary  Pro - Kansas City BBQ    $5.2557    20.00    $0.3395
# ..            ...                    ...        ...      ...        ...
# 705  Prepared Frz   Pro - Marinara Sauce   $19.9424    60.00    $2.1495
# 706  Prepared Frz   Pro - Marinara Sauce   $19.9424    18.00    $0.3147
# 707  Prepared Frz   Pro - Marinara Sauce   $19.9424   500.00    $2.2223
# 708  Prepared Frz   Pro - Marinara Sauce   $19.9424     1.00    $6.7740
# 709    Bar Supply      Simple Syrup 2023    $1.1568   440.00    $1.1568
#
#                      item_descrip.1 uom item_num line_item_num  \
# 0           JALAPENO PEPPER - FRESH   g   P-6068        I-1927
# 1                   KETCHUP VOL PAK  ml   P-6068        I-1958
# 2                       MUSTARD DRY   g   P-6068        I-2025
# 3             SPICE CAYENNE SHAKER   ml   P-6068        I-2323
# 4               SPICE CHILI POWDER    g   P-6068        I-2324
# ..                              ...  ..      ...           ...
# 705                     BASIL Fresh   g  P-15368        I-3005
# 706  SPICE CHILI RED PEPPER CRUSHED   g  P-15368        I-3804
# 707              Onion White Peeled   g  P-15368        I-6865
# 708       Sawmill Creek - White 16L   L  P-15368        I-9117
# 709           SUGAR GRANULATED FINE   g  P-16844        I-2367
#
#      pak_physical_yield pak_uom inv_flag
# 0                  1.25       L        Y
# 1                  1.25       L        Y
# 2                  1.25       L        Y
# 3                  1.25       L        Y
# 4                  1.25       L        Y
# ..                  ...     ...      ...
# 705                7.00       L        Y
# 706                7.00       L        Y
# 707                7.00       L        Y
# 708                7.00       L        Y
# 709              700.00      ml        Y
#
# [710 rows x 12 columns]

# %%
Products[~Products['line_item_num'].str.startswith('P-')].head()
# Out:
#     item_descrip    PLU    uom                  item_descrip.1  item_num  \
# 18  2024S Hummus   1.00     ea               PITA POCKETS THIN     14296
# 19  2024S Hummus   1.00     ea                   PITA THICK 5"     14296
# 20  2024S Hummus   0.01  bunch                        PARSLEY      14296
# 21  2024S Hummus   5.00      g  Olive Kalamata Superior Pitted     14296
# 22  2024S Hummus  15.00     ml         Olive Oil Extra virgin      14296
#
#    inv_flag line_item_num
# 18        Y       I-14127
# 19        Y       I-14126
# 20        Y        I-2087
# 21        Y        I-5731
# 22        Y       I-14790

# %%
# Filter out rows where 'line_item_num' does not start with 'P-'
temp1 = Preps[~Preps['line_item_num'].str.startswith('P-')]

# Select relevant columns
temp1 = temp1[['line_item_num', 'item_descrip.1', 'line_qty', 'uom', 'pak_physical_yield', 'pak_uom', 'inv_flag']]

temp2 = Products[~Products['line_item_num'].str.startswith('P-')]

temp2 = temp2[['line_item_num', 'item_descrip.1', 'PLU', 'uom', 'inv_flag']]
temp2.rename(columns={'PLU': 'line_qty'}, inplace=True)

items = pd.concat([temp1, temp2], ignore_index=True)

# Rename columns for clarity
items.rename(columns={
    'line_item_num': 'ItemId',
    'item_descrip.1': 'Description',
    'line_qty': 'CaseQty',
    'uom': 'CaseUOM',
    'pak_physical_yield': 'PakQty',
    'pak_uom': 'PakUOM',
    'inv_flag': 'InventoryGroup'
}, inplace=True)

# Define a function to deal with commas in numeric fields
def dealWithComma(x):
    if isinstance(x, str):
        return x.replace(",", "")
    return x

# Apply the function to the 'CaseQty' column
items['CaseQty'] = items['CaseQty'].apply(dealWithComma)

# Convert 'CaseQty' to float
items = items.astype({"CaseQty": float})

# Remove duplicates based on 'ItemId'
items.drop_duplicates(subset=["ItemId"], inplace=True)

# Reset index for the final DataFrame
items.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
items
# Out:
#      ItemId                     Description  CaseQty  CaseUOM  PakQty PakUOM  \
# 0    I-1927         JALAPENO PEPPER - FRESH     20.0        g    1.25      L
# 1    I-1958                 KETCHUP VOL PAK    660.0       ml    1.25      L
# 2    I-2025                     MUSTARD DRY     22.5        g    1.25      L
# 3    I-2323           SPICE CAYENNE SHAKER      15.0       ml    1.25      L
# 4    I-2324             SPICE CHILI POWDER      20.0        g    1.25      L
# ..      ...                             ...      ...      ...     ...    ...
# 213  I-4197          DRESSING Ranch BtrMilk      2.0  oz (fl)     NaN    NaN
# 214  I-4198          Lemon Pepper Seasoning     10.0        g     NaN    NaN
# 215  I-4199  ITEM G21- MANGO HABANERO SAUCE      2.0  oz (fl)     NaN    NaN
# 216  I-4200             Fries Sweet Potato     400.0        g     NaN    NaN
# 217  I-4207  Belgian Waffle Ind.Wrapped 70g      1.0       ea     NaN    NaN
#
#     InventoryGroup
# 0                Y
# 1                Y
# 2                Y
# 3                Y
# 4                Y
# ..             ...
# 213              Y
# 214              Y
# 215              Y
# 216              Y
# 217              Y
#
# [218 rows x 7 columns]

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Items_List.csv")
items.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Extracting all Ingredients

# %%
# Ensure 'item_num' and 'line_item_num' columns are strings
Products = Products.astype({"item_num": str, "line_item_num": str})

# Prepend "R-" to 'item_num' column
Products['item_num'] = "R-" + Products['item_num']

# Display the modified DataFrame
Products
# Out:
#                        item_descrip   PLU    uom  \
# 0                 2024S Beets Salad   1.0     ea
# 2    2024S Blackend Chick Carbonara   1.0     ea
# 3    2024S Blackend Chick Carbonara   2.0   Tbsp
# 5       2024S Chicken Caesar (Wrap)   1.0     ea
# 7         2024S Chicken Pesto Penne   1.0     ea
# ..                              ...   ...    ...
# 135         2024S Wing Honey Garlic   5.0      g
# 136         2024S Wing Honey Garlic  20.0      g
# 137         2024S Wing Honey Garlic  30.0      g
# 138         2024S Wing Honey Garlic   1.0      g
# 139         2024S Wing Honey Garlic   0.1  bunch
#
#                     item_descrip.1 item_num inv_flag line_item_num
# 0            2023 Beets Salad Prep   R-2654        Y       P-18275
# 2    2023 Blackened Carbonara Prep   R-7227        Y        P-5506
# 3                    2023 Herb oil   R-7227        Y       P-17013
# 5    2023 Chicken Caesar wrap Prep   R-8990        Y       P-14560
# 7               2023 Pesto Chicken   R-5554        Y       P-18295
# ..                             ...      ...      ...           ...
# 135            GARLIC WHOLE PEELED   R-2084        Y        I-1874
# 136              BUTTER REG SALTED   R-2084        Y        I-2037
# 137       HONEY LIQUID SQUEEZE CAN   R-2084        Y        I-1917
# 138             SALT KOSHER COARSE   R-2084        Y        I-4091
# 139                       PARSLEY    R-2084        Y        I-2087
#
# [105 rows x 7 columns]

# %%
Ingredients = Products[['line_item_num', 'PLU', 'uom', 'item_num']].copy()

Ingredients.rename(columns={'line_item_num': 'IngredientId', 'PLU': 'Qty', 'uom': 'Uom', 'item_num': 'Recipe'}, inplace=True)

Ingredients.drop_duplicates(subset=["IngredientId", "Recipe"], inplace=True)

Ingredients.reset_index(drop=True, inplace=True)
Ingredients
# Out:
#     IngredientId   Qty    Uom  Recipe
# 0        P-18275   1.0     ea  R-2654
# 1         P-5506   1.0     ea  R-7227
# 2        P-17013   2.0   Tbsp  R-7227
# 3        P-14560   1.0     ea  R-8990
# 4        P-18295   1.0     ea  R-5554
# ..           ...   ...    ...     ...
# 100       I-1874   5.0      g  R-2084
# 101       I-2037  20.0      g  R-2084
# 102       I-1917  30.0      g  R-2084
# 103       I-4091   1.0      g  R-2084
# 104       I-2087   0.1  bunch  R-2084
#
# [105 rows x 4 columns]

# %%
temp = Preps[['line_item_num', 'item_num', 'line_qty', 'uom']].copy()
temp.rename(columns={'line_item_num': 'IngredientId', 'item_num': 'Recipe', 'line_qty': 'Qty', 'uom': 'Uom'}, inplace=True)
temp.drop_duplicates(subset=["IngredientId", "Recipe"], inplace=True)
temp.reset_index(drop=True, inplace=True)
temp
# Out:
#     IngredientId   Recipe     Qty Uom
# 0         I-1927   P-6068   20.00   g
# 1         I-1958   P-6068  660.00  ml
# 2         I-2025   P-6068   22.50   g
# 3         I-2323   P-6068   15.00  ml
# 4         I-2324   P-6068   20.00   g
# ..           ...      ...     ...  ..
# 695       I-3005  P-15368   60.00   g
# 696       I-3804  P-15368   18.00   g
# 697       I-6865  P-15368  500.00   g
# 698       I-9117  P-15368    1.00   L
# 699       I-2367  P-16844  440.00   g
#
# [700 rows x 4 columns]

# %%
df = [Ingredients, temp]
Ingredients = pd.concat(df)

Ingredients["Qty"] = Ingredients["Qty"].apply(dealWithComma)

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Ingredients_List.csv")
Ingredients.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Extracting Products List

# %%
Products = Products[['item_num', 'item_descrip', 'inv_flag']]

Products.rename(columns={'item_num': 'ProdId', 'item_descrip': 'Description', 'inv_flag': 'SalesGroup'}, inplace=True)
Products.drop_duplicates(inplace=True)
Products.reset_index(drop=True, inplace=True)
Products
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_70459/4244662357.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products.rename(columns={'item_num': 'ProdId', 'item_descrip': 'Description', 'inv_flag': 'SalesGroup'}, inplace=True)
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_70459/4244662357.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products.drop_duplicates(inplace=True)
#      ProdId                     Description SalesGroup
# 0    R-2654               2024S Beets Salad          Y
# 1    R-7227  2024S Blackend Chick Carbonara          Y
# 2    R-8990     2024S Chicken Caesar (Wrap)          Y
# 3    R-5554       2024S Chicken Pesto Penne          Y
# 4   R-10589            2024S Chicken Po'Boy          Y
# 5   R-14525            2024S Gallery Nachos          Y
# 6    R-8428    2024S Grilled Caesar (Salad)          Y
# 7   R-14296                    2024S Hummus          Y
# 8    R-6977                   2024S Poutine          Y
# 9    R-3664               2024S Power Punch          Y
# 10   R-7065            2024S Smashed Burger          Y
# 11  R-14987             2024S Truffle Fries          Y
# 12  R-18272    2024S Truffle Mushroom Pasta          Y
# 13   R-6820              2024S Tuscan penne          Y
# 14  R-15057              2024S Vegan Burger          Y
# 15  R-16782      2024S Vegan Caesar (Salad)          Y
# 16   R-4432           2024S Wings El Diablo          Y
# 17  R-18575           2024S Wings Hot Sauce          Y
# 18   R-5374      2024S Wings Lemon N Pepper          Y
# 19   R-2169      2024S Wings Mango Habanero          Y
# 20  R-10980             2024S Wings Memphis          Y
# 21   R-3803       2024S Wings Salt N Pepper          Y
# 22   R-9751            2024S X-Treme Nachos          Y
# 23   R-5010                 2024S Yam Fries          Y
# 24   R-3677      2024S Yellow Thai (Tempeh)          Y
# 25   R-8573  2024S Yellow Thai Curry (Chkn)          Y
# 26   R-7216          2024S Aloo Tiki burger          Y
# 27   R-5422                2024S Bruschetta          Y
# 28  R-10125             2024S Caprese Salad          Y
# 29   R-4598     2024S Cheesy potato croquet          Y
# 30   R-6313             2024S Chicken katsu          Y
# 31   R-1916         2024S Chicken N  Waffle          Y
# 32   R-4752            2024S Cuban Sandwich          Y
# 33   R-1525        2024S Happy Appy Platter          Y
# 34   R-6168           2024S harissa chicken          Y
# 35   R-7572                    2024S Mussel          Y
# 36   R-5386    2024S Roasted red pepper dip          Y
# 37   R-2084         2024S Wing Honey Garlic          Y

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Products_List.csv")
Products.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Import Conversions List

# %%
# Read conventions.xml files in the filepath_list and construct a dataframe
ConversionId = []
Multiplier = []
ConvertFromQty = []
ConvertFromUom = []
ConvertToQty = []
ConvertToUom = []

# From the XML file for Conversions append the id into ConversionId, multiplier into Multiplier, ConvertFrom->qty into 
# ConvertFromQty,ConvertFrom->uom into ConvertFromUom, ConvertTo->qty into ConvertToQty and and ConvertTo->uom into the
# CovertToUom list. 
# Make a dataframe out of the 3 lists
# Then also drop the duplicates in the Products dataframe

filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "OK 23-24 Sep-Dec*", "*.oc"))
for filepath in filepath_list:
    path = filepath + '/Conversions.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for x in xtree.iterfind('Conversion'):
            ConversionId.append(x.attrib['id'])
            Multiplier.append(x.attrib['multiplier'])
            ConvertFromQty.append(x.find('ConvertFrom').attrib['qty'])
            ConvertFromUom.append(x.find('ConvertFrom').attrib['uom'])
            ConvertToQty.append(x.find('ConvertTo').attrib['qty'])
            ConvertToUom.append(x.find('ConvertTo').attrib['uom'])
    
    
Conversions = pd.DataFrame({'ConversionId': ConversionId, 'Multiplier': Multiplier, 'ConvertFromQty': ConvertFromQty,
                           'ConvertFromUom': ConvertFromUom, 'ConvertToQty': ConvertToQty, 'ConvertToUom': ConvertToUom}
                          ).drop_duplicates()

Conversions.reset_index(drop=True, inplace=True)

# %%
Conversions.loc[Conversions["ConversionId"] == "I-29389"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
# all_id_list = Items["ItemId"].unique()
all_id_set = set(Preps["item_num"].unique())
all_conv_set = set(Conversions["ConversionId"].unique())

missing_conv_id = all_id_set - all_conv_set
n = len(missing_conv_id)
print(f"{n} Items in Items dataframe but not in Conversions Dataframe:\n",)
print(missing_conv_id)
# Out:
# 114 Items in Items dataframe but not in Conversions Dataframe:
#
# {'P-2424', 'P-1488', 'P-17378', 'P-16793', 'P-6881', 'P-5333', 'P-15057', 'P-6068', 'P-17013', 'P-4257', 'P-9785', 'P-5506', 'P-2139', 'P-17486', 'P-4611', 'P-16778', 'P-18295', 'P-16748', 'P-10654', 'P-3615', 'P-16782', 'P-4527', 'P-1750', 'P-1106', 'P-9279', 'P-10195', 'P-18451', 'P-18268', 'P-15368', 'P-17366', 'P-7924', 'P-10674', 'P-18380', 'P-6574', 'P-16760', 'P-2535', 'P-16575', 'P-8988', 'P-16780', 'P-3286', 'P-17358', 'P-14560', 'P-15013', 'P-6514', 'P-1409', 'P-7224', 'P-6925', 'P-18458', 'P-18272', 'P-18329', 'P-5012', 'P-17360', 'P-18275', 'P-4582', 'P-10863', 'P-18052', 'P-4811', 'P-5557', 'P-5552', 'P-7912', 'P-18336', 'P-13736', 'P-16855', 'P-5741', 'P-18349', 'P-15007', 'P-9935', 'P-11125', 'P-2679', 'P-16856', 'P-11706', 'P-18381', 'P-9928', 'P-16844', 'P-16571', 'P-16860', 'P-4733', 'P-2307', 'P-17301', 'P-1711', 'P-16221', 'P-7201', 'P-3045', 'P-7873', 'P-4150', 'P-10459', 'P-8527', 'P-2291', 'P-5803', 'P-2824', 'P-18334', 'P-8359', 'P-18470', 'P-2519', 'P-15006', 'P-17037', 'P-1434', 'P-16794', 'P-17305', 'P-10044', 'P-10891', 'P-8990', 'P-12209', 'P-16222', 'P-2674', 'P-18327', 'P-2584', 'P-4657', 'P-1520', 'P-3547', 'P-6635', 'P-10589', 'P-18575', 'P-18274'}

# %%
Conversions.shape
# Out:
# (444, 6)

# %%
Conversions.dtypes
# Out:
# ConversionId      object
# Multiplier        object
# ConvertFromQty    object
# ConvertFromUom    object
# ConvertToQty      object
# ConvertToUom      object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Conversions_List.csv")
Conversions.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Data Summary

# %%
# Summary of raw data imported for evaluation
# Here we have a summary of the number of items, preps, ingredients, products, conversions

datasum = pd.DataFrame([items.shape, Preperations.shape, Ingredients.shape, Products.shape, Conversions.shape],
                       columns = ['count', 'columns'], 
                       index = ['Items', 'Preps', 'Ingredients', 'Products', 'Conversions'])
datasum
# Out:
#              count  columns
# Items          218        7
# Preps          114        5
# Ingredients    805        4
# Products        38        3
# Conversions    444        6
