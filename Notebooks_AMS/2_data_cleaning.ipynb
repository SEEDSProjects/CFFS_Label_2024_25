# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Part II: Data Cleaning

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
from datetime import datetime

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
#
# ## Import Preprocessed Datasets

# %%
"""
INPUT: a Dataframe
OUPUT: NONE
Description: Prints a description of the datasets
"""
def DescribeDataset(df):
    print(df.dtypes)
    print("\nShape: ", df.shape)
    display(df.head())

# %%
# Reading csv file: data/preprocessed/AMS_data/Items_List.csv
Items = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Items_List.csv"))
DescribeDataset(Items)
# Out:
# ItemId             object
# Description        object
# CaseQty           float64
# CaseUOM            object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (169, 7)
#    ItemId                  Description  CaseQty  CaseUOM  PakQty PakUOM  \
# 0  I-4099            Olive Oil 100 Pct     60.0       ml    14.0     ea
# 1  I-2402           TOMATO - 6 X 7 MED    300.0        g    14.0     ea
# 2  I-1874          GARLIC WHOLE PEELED     15.0        g  1031.0      g
# 3  I-4091           SALT KOSHER COARSE     15.0        g  1031.0      g
# 4  I-4104  CHICKEN BRST 6Z B/S 19% IQF      6.0  oz (wt)     1.0     ea
#
#   InventoryGroup
# 0              Y
# 1              Y
# 2              Y
# 3              Y
# 4              Y

# %%
# Read Ingredients_List.csv
Ingredients = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Ingredients_List.csv"))
DescribeDataset(Ingredients)
# Out:
# IngredientId     object
# Qty             float64
# Uom              object
# Recipe           object
# dtype: object
#
# Shape:  (348, 4)
#   IngredientId    Qty      Uom  Recipe
# 0       I-4099   60.0       ml  P-2824
# 1       I-2402  300.0        g  P-2824
# 2       P-9935   14.0       ea  P-2824
# 3       I-4104    6.0  oz (wt)  P-5012
# 4       P-5506   50.0        g  P-5012

# %%
# Read Preps_List.csv
Preps = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Preps_List.csv"))
DescribeDataset(Preps)
# Out:
# PrepId             object
# Description        object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (23, 5)
#     PrepId                   Description  PakQty PakUOM InventoryGroup
# 0   P-2824           BC - Tomato Focacia    14.0     ea              Y
# 1   P-5012  Catr- Roasted Chicken Breast     1.0     ea              Y
# 2   P-2679            Pro - Tahini Sauce     1.0      L              Y
# 3  P-15427     Pro - Vegan Chipotle Mayo    16.5      L              Y
# 4   P-9935     Baking - Focacia Baguette    14.0     ea              Y

# %%
# Read Product_List.csv that was created from 1_data preprocessing
Products = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Products_List.csv"))
DescribeDataset(Products)
# Out:
# ProdId         object
# Description    object
# SalesGroup     object
# dtype: object
#
# Shape:  (131, 3)
#    ProdId      Description SalesGroup
# 0  R-4593  $garlic & onion          Y
# 1  R-3266    CHEDDAR SLICE          Y
# 2  R-9348         Cucumber          Y
# 3  R-9085          Lettuce          Y
# 4  R-2489           Tomato          Y

# %% [markdown]
# ***
# ## Converter

# %% [markdown]
# ### Create Unit Converter

# %%
# Import standard unit conversion information and construct a dataframe
Std_Unit = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "standard_conversions.csv"))
Std_Unit.head()
# Out:
#    Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty ConvertToUom
# 0     4.92890               1            tsp       4.92890           ml
# 1    14.78700               1           Tbsp      14.78700           ml
# 2   946.35000               1             qt     946.35000           ml
# 3   473.17625               1             pt     473.17625           ml
# 4    28.34950               1             oz      28.34950            g

# %%
# Seperate uoms that converted to 'ml' or 'g'
# Below we create 2 lists. 
# list_unit contains list of unit of measurements that are being converted to milliliters 
# solid_unit contains a list of unit of measurements that are being converted to grams
# tolist() converts a Pandas Series or an array to a python list. 

liquid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'ml', 'ConvertFromUom'].tolist()
solid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'g', 'ConvertFromUom'].tolist()

# %%
# Construct a standard unit converter
def std_converter(qty, uom):
    if uom in Std_Unit['ConvertFromUom'].tolist():
        multiplier = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'Multiplier']
        Qty = float(qty)*float(multiplier)
        Uom = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'ConvertToUom'].values[0]
    else:
        Qty = qty
        Uom = uom
    return (Qty, Uom)

# %% [markdown]
# ***
# ## Items with Non-standard Units

# %%
Ingredients
# Out:
#     IngredientId    Qty      Uom  Recipe
# 0         I-4099   60.0       ml  P-2824
# 1         I-2402  300.0        g  P-2824
# 2         P-9935   14.0       ea  P-2824
# 3         I-4104    6.0  oz (wt)  P-5012
# 4         P-5506   50.0        g  P-5012
# ..           ...    ...      ...     ...
# 343       P-1520    1.0       ea  R-9786
# 344       P-9279    1.0       ea  R-8350
# 345       P-4811    1.0       ea  R-3296
# 346       I-4327    9.0        g  R-4006
# 347       I-4328    1.0       ea  R-5563
#
# [348 rows x 4 columns]

# %%
Items
# Out:
#      ItemId                   Description  CaseQty  CaseUOM  PakQty PakUOM  \
# 0    I-4099             Olive Oil 100 Pct     60.0       ml    14.0     ea
# 1    I-2402            TOMATO - 6 X 7 MED    300.0        g    14.0     ea
# 2    I-1874           GARLIC WHOLE PEELED     15.0        g  1031.0      g
# 3    I-4091            SALT KOSHER COARSE     15.0        g  1031.0      g
# 4    I-4104   CHICKEN BRST 6Z B/S 19% IQF      6.0  oz (wt)     1.0     ea
# ..      ...                           ...      ...      ...     ...    ...
# 164  I-4324                VEGAN DATE BAR      1.0       ea     NaN    NaN
# 165  I-4325                   CHICK SALAD      1.0       ea     NaN    NaN
# 166  I-4326                     EGG SALAD      1.0       ea     NaN    NaN
# 167  I-4327  Spirit Bear Raven - Espresso      9.0        g     NaN    NaN
# 168  I-4328                 MUFF - BANANA      1.0       ea     NaN    NaN
#
#     InventoryGroup
# 0                Y
# 1                Y
# 2                Y
# 3                Y
# 4                Y
# ..             ...
# 164              Y
# 165              Y
# 166              Y
# 167              Y
# 168              Y
#
# [169 rows x 7 columns]

# %%
# Filter out the items whose unit information is unknown 
# We find the column names
col_names = list(Ingredients.columns.values)

# Create a Items_Nonstd list
Items_Nonstd = []

# If the unit of measurement is not grams or ml and ingredient id starts with I and the ingredient is not in ConversionId column of Conversions 
# then we add it to Items_Nonstd list
for index, row in Ingredients.iterrows():
    Ingre = Ingredients.loc[index,'IngredientId']
    Uom = Ingredients.loc[index,'Uom']
    if Uom not in ['g', 'ml'] and Uom not in liquid_unit + solid_unit and Ingre.startswith('I'):
        Dict = {}
        Dict.update(dict(row))
        Items_Nonstd.append(Dict)

# Create a DataFrame from Items_Nonstd list
Items_Nonstd = pd.DataFrame(Items_Nonstd, columns = col_names)
# Remove duplicate ingredients of the same properties so that Items_Nonstd has only unique rows. 
Items_Nonstd.drop_duplicates(subset=['IngredientId'], inplace=True,)
Items_Nonstd
# Out:
#     IngredientId   Qty    Uom   Recipe
# 0         I-4109   1.0  bunch   P-2679
# 2         I-4114  10.0     ea   P-2424
# 3         I-2992   2.0  slice  P-10674
# 5         I-4122   2.0   2 KG   P-7912
# 7         I-4126   2.0  slice   P-1488
# ..           ...   ...    ...      ...
# 161       I-4323   1.0     ea   R-2588
# 162       I-4324   1.0     ea   R-8062
# 163       I-4325   1.0     ea   R-7939
# 164       I-4326   1.0     ea   R-8651
# 165       I-4328   1.0     ea   R-5563
#
# [110 rows x 4 columns]

# %%
# Assigning a Description column to the Items_Nonstd    
for index, row in Items_Nonstd.iterrows():
    idx = row['IngredientId']
    filtered_items = Items.loc[Items['ItemId'] == idx, 'Description']
    if not filtered_items.empty:
        descrp = filtered_items.values[0]
        Items_Nonstd.loc[index, 'Description'] = descrp
    else:
        # Handle the case when there is no matching item for the given 'IngredientId'
        Items_Nonstd.loc[index, 'Description'] = 'Not Found'
        pass

# %%
Items_Nonstd.head()
# Out:
#   IngredientId   Qty    Uom   Recipe                    Description
# 0       I-4109   1.0  bunch   P-2679                   CILANTRO 3ct
# 2       I-4114  10.0     ea   P-2424  TORTILLA 10" FLOUR PRESSED TF
# 3       I-2992   2.0  slice  P-10674         Bacon Pre-Ckd 30-34 ct
# 5       I-4122   2.0   2 KG   P-7912     EGG LIQ WHL CAGE FREE FRSH
# 7       I-4126   2.0  slice   P-1488           MULTIGRAIN CLUBHOUSE

# %%
# Convert the Items_Nonstd DataFrame to a csv file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Items_Nonstd.csv")
Items_Nonstd.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Clean Preps Units

# %%
Preps
# Out:
#      PrepId                     Description   PakQty PakUOM InventoryGroup
# 0    P-2824             BC - Tomato Focacia     14.0     ea              Y
# 1    P-5012    Catr- Roasted Chicken Breast      1.0     ea              Y
# 2    P-2679              Pro - Tahini Sauce      1.0      L              Y
# 3   P-15427       Pro - Vegan Chipotle Mayo     16.5      L              Y
# 4    P-9935       Baking - Focacia Baguette     14.0     ea              Y
# 5    P-2424      BCPrep - Asian Sesame Wrap     10.0     ea              Y
# 6   P-10674             BCPrep - BACON WRAP      1.0     ea              Y
# 7    P-7912   BCPrep - Baked Eggs for Wraps      4.3     Kg              Y
# 8    P-1520    BCPrep - Chicken Quinoa Wrap     10.0     ea              Y
# 9    P-1488          BCPrep - Chicken Salad      1.0     ea              Y
# 10   P-2535              BCPrep - Egg Salad      1.0     ea              Y
# 11   P-4582  BCPrep - Ham & Swiss Croissant      1.0     ea              Y
# 12   P-4811     BCPrep - Mediterranean Wrap     10.0     ea              Y
# 13   P-9279             BCPrep - Salsa Wrap      1.0     ea              Y
# 14  P-10863          BCPrep - T-Bird Muffin      1.0     ea              Y
# 15   P-1434       BCPrep - Turkey & Cheddar      1.0     ea              Y
# 16  P-10195       BCPrep - Vegan Egg Muffin     10.0     ea              Y
# 17  P-14403      Prep Cream Cheese - Garlic  11000.0      g              Y
# 18   P-4257                 SGL Chunky Prep      1.0     ea              Y
# 19   P-9928                   SGL JAVA prep      1.0     ea              Y
# 20   P-7873              SGL MARBELOUS prep      1.0     ea              Y
# 21   P-4611                SGL SMARTIE prep      1.0     ea              Y
# 22   P-8359       Vegan Golden Falafel Wrap     10.0     ea              Y

# %%
# Creates 2 new columns called StdQty and StdUom in the Preps DataFrame. These columns contain NaN values
# Preparing to fill in these columns with standardized quantities and units of measurement 
Preps['StdQty'] = np.nan
Preps['StdUom'] = np.nan

# %%
Preps
# Out:
#      PrepId                     Description   PakQty PakUOM InventoryGroup  \
# 0    P-2824             BC - Tomato Focacia     14.0     ea              Y
# 1    P-5012    Catr- Roasted Chicken Breast      1.0     ea              Y
# 2    P-2679              Pro - Tahini Sauce      1.0      L              Y
# 3   P-15427       Pro - Vegan Chipotle Mayo     16.5      L              Y
# 4    P-9935       Baking - Focacia Baguette     14.0     ea              Y
# 5    P-2424      BCPrep - Asian Sesame Wrap     10.0     ea              Y
# 6   P-10674             BCPrep - BACON WRAP      1.0     ea              Y
# 7    P-7912   BCPrep - Baked Eggs for Wraps      4.3     Kg              Y
# 8    P-1520    BCPrep - Chicken Quinoa Wrap     10.0     ea              Y
# 9    P-1488          BCPrep - Chicken Salad      1.0     ea              Y
# 10   P-2535              BCPrep - Egg Salad      1.0     ea              Y
# 11   P-4582  BCPrep - Ham & Swiss Croissant      1.0     ea              Y
# 12   P-4811     BCPrep - Mediterranean Wrap     10.0     ea              Y
# 13   P-9279             BCPrep - Salsa Wrap      1.0     ea              Y
# 14  P-10863          BCPrep - T-Bird Muffin      1.0     ea              Y
# 15   P-1434       BCPrep - Turkey & Cheddar      1.0     ea              Y
# 16  P-10195       BCPrep - Vegan Egg Muffin     10.0     ea              Y
# 17  P-14403      Prep Cream Cheese - Garlic  11000.0      g              Y
# 18   P-4257                 SGL Chunky Prep      1.0     ea              Y
# 19   P-9928                   SGL JAVA prep      1.0     ea              Y
# 20   P-7873              SGL MARBELOUS prep      1.0     ea              Y
# 21   P-4611                SGL SMARTIE prep      1.0     ea              Y
# 22   P-8359       Vegan Golden Falafel Wrap     10.0     ea              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN
# 19     NaN     NaN
# 20     NaN     NaN
# 21     NaN     NaN
# 22     NaN     NaN

# %%
# Function to apply the conversion logic
def convert_units(row):
    if row['PakUOM'].lower() in ['g', 'grams']:
        return row['PakQty'], 'g'
    elif row['PakUOM'].lower() in ['kg']:
        return row['PakQty'] * 1000, 'g'
    elif row['PakUOM'].lower() in ['ml']:
        return row['PakQty'], 'ml'
    elif row['PakUOM'].lower() in ['l']:
        return row['PakQty'] * 1000, 'ml'
    elif row['PakUOM'].lower() in ['lbs']:
        return row['PakQty'] * 453.59, 'g'
    else:
        return np.nan, np.nan

# Apply the function to each row
Preps['StdQty'], Preps['StdUom'] = zip(*Preps.apply(convert_units, axis=1))

# %%
Preps_Cleaned = Preps[~Preps["StdQty"].isna()]
Preps_Cleaned.reset_index(drop=True, inplace=True)
Preps_Cleaned
# Out:
#     PrepId                    Description   PakQty PakUOM InventoryGroup  \
# 0   P-2679             Pro - Tahini Sauce      1.0      L              Y
# 1  P-15427      Pro - Vegan Chipotle Mayo     16.5      L              Y
# 2   P-7912  BCPrep - Baked Eggs for Wraps      4.3     Kg              Y
# 3  P-14403     Prep Cream Cheese - Garlic  11000.0      g              Y
#
#     StdQty StdUom
# 0   1000.0     ml
# 1  16500.0     ml
# 2   4300.0      g
# 3  11000.0      g

# %%
# Save cleaned preps list to file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_Unit_Cleaned.csv")
Preps_Cleaned.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Get Preps with Nonstandard Unit

# %%
col_names = list(Preps.columns.values)
Preps_Nonstd = []

for index, row in Preps.iterrows():
    StdUom = Preps.loc[index,'StdUom']
    if StdUom not in ['g', 'ml']:
        Dict = {}
        Dict.update(dict(row))
        Preps_Nonstd.append(Dict)

Preps_Nonstd = pd.DataFrame(Preps_Nonstd, columns = col_names)

# %%
Preps_Nonstd
# Out:
#      PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0    P-2824             BC - Tomato Focacia    14.0     ea              Y
# 1    P-5012    Catr- Roasted Chicken Breast     1.0     ea              Y
# 2    P-9935       Baking - Focacia Baguette    14.0     ea              Y
# 3    P-2424      BCPrep - Asian Sesame Wrap    10.0     ea              Y
# 4   P-10674             BCPrep - BACON WRAP     1.0     ea              Y
# 5    P-1520    BCPrep - Chicken Quinoa Wrap    10.0     ea              Y
# 6    P-1488          BCPrep - Chicken Salad     1.0     ea              Y
# 7    P-2535              BCPrep - Egg Salad     1.0     ea              Y
# 8    P-4582  BCPrep - Ham & Swiss Croissant     1.0     ea              Y
# 9    P-4811     BCPrep - Mediterranean Wrap    10.0     ea              Y
# 10   P-9279             BCPrep - Salsa Wrap     1.0     ea              Y
# 11  P-10863          BCPrep - T-Bird Muffin     1.0     ea              Y
# 12   P-1434       BCPrep - Turkey & Cheddar     1.0     ea              Y
# 13  P-10195       BCPrep - Vegan Egg Muffin    10.0     ea              Y
# 14   P-4257                 SGL Chunky Prep     1.0     ea              Y
# 15   P-9928                   SGL JAVA prep     1.0     ea              Y
# 16   P-7873              SGL MARBELOUS prep     1.0     ea              Y
# 17   P-4611                SGL SMARTIE prep     1.0     ea              Y
# 18   P-8359       Vegan Golden Falafel Wrap    10.0     ea              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN

# %%
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_NonstdUom.csv")
Preps_Nonstd.to_csv(path, index = False, header = True)

# %%
# NEED TO CONTINUE FROM HERE, FINISH THE UNIT UPDATES
update_prep = pd.read_csv("data/cleaning/update/AMS_data/Preps_UpdateUom.csv")
update_prep #Manual? yes
# Out:
#       PrepId                    Description  PakQty PakUOM InventoryGroup  \
# 0    P-14356               [PREP KAPPA MAKI     6.0   PORT              N
# 1    P-14560  2023 Chicken Caesar wrap Prep     1.0     ea              Y
# 2     P-9003       2022 Gallery Burger prep     1.0     ea              N
# 3    P-17358              2023 Poutine Prep     1.0     ea              N
# 4    P-15006    2023 Power Punch Salad Prep     1.0     ea              N
# ..       ...                            ...     ...    ...            ...
# 103   P-9279            BCPrep - Salsa Wrap     1.0     ea              Y
# 104  P-10863         BCPrep - T-Bird Muffin     1.0     ea              Y
# 105   P-1434      BCPrep - Turkey & Cheddar     1.0     ea              Y
# 106  P-10195      BCPrep - Vegan Egg Muffin    10.0     ea              Y
# 107   P-8359      Vegan Golden Falafel Wrap    10.0     ea              Y
#
#       StdQty StdUom
# 0    1511.82      g
# 1     433.59      g
# 2     501.82      g
# 3     705.80      g
# 4     416.73      g
# ..       ...    ...
# 103   318.00      g
# 104   162.50      g
# 105   310.00      g
# 106  1935.00      g
# 107  3780.00      g
#
# [108 rows x 7 columns]

# %%
# Assuming update_prep and Preps_Nonstd are DataFrames and 'PrepId' is the column of interest
update = set(update_prep["PrepId"])
preps = set(Preps_Nonstd["PrepId"])

# Find the difference between the sets
difference = preps - update

# If you want to print or use the difference
print(difference)
# Out:
# {'P-4611'}

# %% [markdown]
# ***
#
# ## New Items

# %%
# Load current Items List with assigned Emission Factors Category ID
Items_Assigned = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Items_List_Assigned.csv"))
Items_Assigned.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup Food Category
# 0              N           NaN
# 1              N           NaN
# 2              N           NaN
# 3              N           NaN
# 4              N           NaN

# %%
Items_Assigned.shape
# Out:
# (568, 9)

# %%
Items_Assigned["InventoryGroup"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
Items_Assigned["CategoryID"].unique()
# Out:
# array([35, 55, 31, 36, 58, 24, 16, 20,  3, 40,  8, 38, 48, 54, 44, 18, 32,
#        56, 61, 39, 43, 37,  5, 26, 25,  9,  4, 22,  6, 49, 12, 50, 41, 17,
#        57, 11, 34,  1, 45, 42, 59, 46, 10, 51, 53, 21, 28,  7, 13, 30, 14,
#        19, 27])

# %%
Items_Assigned[Items_Assigned["CategoryID"] == 55]
# Out:
#       ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 1     I-8228          55                Grey Goose 1.14L      1.0   fl oz
# 33    I-2640          55                     Water - Tap    250.0      ml
# 92   I-13817          55                  FRENCH AUS JUS    490.0       g
# 102  I-15592          55           JUICE ORANGE CONC 6+1    500.0      ml
# 121   I-3036          55                    MIRIN 5.28GL    720.0      ml
# 171   I-2103          55        PEACH SLCD IN PEAR JUICE    300.0      ml
# 172   I-6204          55     Juice - Lime Fresh Squeezed     30.0       g
# 212  I-17946          55         JUICE orange 100% tetra      1.0       L
# 228   I-6203          55    Juice - Lemon Fresh Squeezed     50.0       g
# 270  I-17129          55                   Boiling Water   3000.0       g
# 274   I-5981          55                Aperol Aperitivo      6.0       L
# 284   I-6182          55             BIB - Coca-Cola 20L      1.0       L
# 285   I-6189          55             BIB - Coke Zero 10L      1.0       L
# 286   I-6188          55  BIB -Canada Dry Ginger Ale 10L      1.0       L
# 287   I-6185          55                BIB - Nestea 20L      1.0       L
# 288  I-12929          55                BIB- Sprite 10L       1.0       L
# 289   I-6224          55           BIB - Tonic Water 12L      1.0       L
# 319   I-7335          55     Tea Assam Brkfst Two Leaves      3.0      ea
# 373   I-1081          55                   GRAND MARNIER    375.0      ml
# 388   I-9117          55       Sawmill Creek - White 16L      1.8       L
# 390   I-7801          55         Sawmill Creek - Red 16L      7.5       L
# 392   I-1471          55          Kronenbourg 1664 Blanc      1.0  bottle
# 441   I-1052          55              BACARDI LIGHT RUM     200.0      ml
# 442   I-1945          55             JUICE PINEAPPLE CAN    350.0      ml
# 444   I-5960          55                  St Remy Brandy    150.0      ml
# 447   I-1093          55                   MALIBU liquor    375.0      ml
# 448   I-1109          55            Meagher's Triple Sec    375.0      ml
# 450  I-16601          55          Sawmill Creek -Rose 4L      8.0       L
# 490   I-4171          55                       Tap Water     10.0       g
#
#      PakQty  PakUOM InventoryGroup      Food Category
# 1       1.0   fl oz              N                NaN
# 33      2.5      ml              N                NaN
# 92      5.0       g              N                NaN
# 102    13.0      ml              N                NaN
# 121  2100.0   fl oz              N                NaN
# 171   300.0      ml              N                NaN
# 172   300.0      oz              N                NaN
# 212     6.0      ml              Y                NaN
# 228     1.2      oz              Y                NaN
# 270  2000.0       g              N                NaN
# 274    18.0   fl oz              Y                NaN
# 284     6.0   fl oz              N                NaN
# 285     6.0   fl oz              N                NaN
# 286     6.0   fl oz              N                NaN
# 287     6.0   fl oz              N                NaN
# 288     6.0   fl oz              N                NaN
# 289     6.0   fl oz              N                NaN
# 319     4.0      ea              N                NaN
# 373    13.0   fl oz              Y                NaN
# 388     2.0   fl oz              N                NaN
# 390   400.0   fl oz              N                NaN
# 392     0.6  bottle              N                NaN
# 441    18.5   fl oz              Y                NaN
# 442    18.5      ml              Y                NaN
# 444    18.5   fl oz              Y                NaN
# 447    18.0   fl oz              Y                NaN
# 448    18.0   fl oz              Y                NaN
# 450    18.0   fl oz              Y                NaN
# 490     1.0      ea              Y  water & beverages

# %% [markdown]
# ### Get the List of New Items

# %%
# Filter new items by itemID that are not in the database and output them in a dataframe
col_names = list(Items.columns.values)
New_Items_List = []

for index, row in Items.iterrows():
    ItemId = Items.loc[index,'ItemId']
    descrp = Items.loc[index,'Description']
    if ItemId not in Items_Assigned['ItemId'].values:
        Dict = {}
        Dict.update(dict(row))
        New_Items_List.append(Dict)
    else:
        print("ItemID: ", ItemId, descrp, " already exists in the database")

New_Items = pd.DataFrame(New_Items_List, columns = col_names)
# Out:
# ItemID:  I-4099 Olive Oil 100 Pct  already exists in the database
# ItemID:  I-2402 TOMATO - 6 X 7 MED  already exists in the database
# ItemID:  I-1874 GARLIC WHOLE PEELED  already exists in the database
# ItemID:  I-4091 SALT KOSHER COARSE  already exists in the database
# ItemID:  I-4104 CHICKEN BRST 6Z B/S 19% IQF  already exists in the database
# ItemID:  I-14422 Onions Green 3ct   already exists in the database
# ItemID:  I-2640 Water - Tap  already exists in the database
# ItemID:  I-4109 CILANTRO 3ct  already exists in the database
# ItemID:  I-1995 MINT LEAVES  already exists in the database
# ItemID:  I-12764 SESAME OIL 1.65L  already exists in the database
# ItemID:  I-5008 Sauce Sriracha Hot Chilli   already exists in the database
# ItemID:  I-2099 PASTE TAHINI  already exists in the database
# ItemID:  I-1660 SAUCE CHIPOTLE IN ADOBO   already exists in the database
# ItemID:  I-2329 SPICE CUMIN SEED GROUND BOX  already exists in the database
# ItemID:  I-4110 ITEM MAYO VEGAN  already exists in the database
# ItemID:  I-4111 MIX - FOCCACHIA  already exists in the database
# ItemID:  I-2367 SUGAR GRANULATED FINE  already exists in the database
# ItemID:  I-4112 TOMATO - SUNDRD JULIENNE  already exists in the database
# ItemID:  I-4113 YEAST BAKERS FRSH  already exists in the database
# ItemID:  I-2209 SALT TABLE IODIZED  already exists in the database
# ItemID:  I-13842 FLOUR ALL PURPOSE.  already exists in the database
# ItemID:  I-4114 TORTILLA 10" FLOUR PRESSED TF  already exists in the database
# ItemID:  I-2349 SPINACH WASHED TRIMMED  already exists in the database
# ItemID:  I-4115 ITEM SLICED RED ONION  already exists in the database
# ItemID:  I-4116 ITEM SHAVED HERL CARROTS  already exists in the database
# ItemID:  I-4117 ITEM SESAME TOFU  already exists in the database
# ItemID:  I-4118 ITEM - Tahini Satay Sauce  already exists in the database
# ItemID:  I-4119 CHEESE SHRED CHEDDAR  already exists in the database
# ItemID:  I-2992 Bacon Pre-Ckd 30-34 ct  already exists in the database
# ItemID:  I-4120 ITEM AIOLI CHIPOLTE  already exists in the database
# ItemID:  I-4122 EGG LIQ WHL CAGE FREE FRSH  already exists in the database
# ItemID:  I-14484 MILK-3.25% 4L jug  already exists in the database
# ItemID:  I-2951 SPICE PEPPER BLACK FINE 540G  already exists in the database
# ItemID:  I-1859 DILL - FRESH   already exists in the database
# ItemID:  I-4125 ITEM ORGANIC QUINOA  already exists in the database
# ItemID:  I-1982 MAYONNAISE GF  already exists in the database
# ItemID:  I-4126 MULTIGRAIN CLUBHOUSE  already exists in the database
# ItemID:  I-5220 Lettuce Green Leaf Fillet  already exists in the database
# ItemID:  I-4127 ITEM SALAD CHICKEN MIX  already exists in the database
# ItemID:  I-4129 ITEM SALAD EGG MIX  already exists in the database
# ItemID:  I-1695 CHEESE SWISS SLCD NAT 21G  already exists in the database
# ItemID:  I-1787 CROISSANT JUMBO  already exists in the database
# ItemID:  I-4131 ITEM SLICED HAM  already exists in the database
# ItemID:  I-4132 TORTILLA 12" SPINACH  already exists in the database
# ItemID:  I-4133 ITEM ROASTED RED ONION  already exists in the database
# ItemID:  I-4135 ITEM - BC Roasted Veggies  already exists in the database
# ItemID:  I-4136 ITEM - Black Olive Hummus  already exists in the database
# ItemID:  I-4137 TORTILLA 10" TOMATO PRESSED  already exists in the database
# ItemID:  I-2203 SALSA MED THICK AND CHUNKY  already exists in the database
# ItemID:  I-3498 Cheese Cheddar Slices 21gm  already exists in the database
# ItemID:  I-4138 ITEM SLICED TURKEY  already exists in the database
# ItemID:  I-4139 MUFFIN - ENGLISH    already exists in the database
# ItemID:  I-4140 BLUE CHIP T BIRD EGG  already exists in the database
# ItemID:  I-4141 ITEM SLICED TOMATO  already exists in the database
# ItemID:  I-4142 Bread Loaf Sourdgh Cranb T/S  already exists in the database
# ItemID:  I-16803 VEGAN Cheddar Slices  already exists in the database
# ItemID:  I-4143 EGG Vegan Cooked Folded  already exists in the database
# ItemID:  I-4144 CHEESE CREAM PLAIN SOFT 10KG  already exists in the database
# ItemID:  I-4147 chocolate - milk chunk  already exists in the database
# ItemID:  I-4148 ITEM COOKIE JAVA NUT  already exists in the database
# ItemID:  I-4149 chocolate - white block  already exists in the database
# ItemID:  I-4152 ITEM COOKIE SMARTIE  already exists in the database
# ItemID:  I-14442 Falafel Balls 300ct  already exists in the database
# ItemID:  I-4153 TORTILLA 10" SPINACH  already exists in the database
# ItemID:  I-2986 Soy Milk Barista Blend  already exists in the database
# ItemID:  I-4195 Cucumber 3ct   already exists in the database
# ItemID:  I-1649 CAPER CAPUCINE  already exists in the database
# ItemID:  I-4190 ITEM BAGEL JALAPENO & CHEESE  already exists in the database
# ItemID:  I-4198 ITEM BAGEL PLAIN  already exists in the database
# ItemID:  I-4237 CHEESE SHREDDED MOZZA  already exists in the database
# ItemID:  I-4238 CHEESE CREAM LT SPREADABLE   already exists in the database
# ItemID:  I-4249 Croissant RTB  already exists in the database
# ItemID:  I-4290 CHUNKY COOKIE  already exists in the database
# ItemID:  I-4296 SMARTIE COOKIE  already exists in the database

# %%
New_Items.insert(1, "CategoryID", '')
New_Items
# Out:
#     ItemId CategoryID                   Description  CaseQty CaseUOM  PakQty  \
# 0   I-4145                      ITEM COOKIE  CHUNKY      1.0      ea     1.0
# 1   I-4146             Chocolate - Semi Sweet Dark      10.0       g     1.0
# 2   I-4150                    ITEM COOKIE MARBELOUS      1.0      ea     1.0
# 3   I-4151                                 Smarties     15.0       g     1.0
# 4   I-4191                   bean green pickled bar      2.0      ea     NaN
# ..     ...        ...                           ...      ...     ...     ...
# 90  I-4324                           VEGAN DATE BAR      1.0      ea     NaN
# 91  I-4325                              CHICK SALAD      1.0      ea     NaN
# 92  I-4326                                EGG SALAD      1.0      ea     NaN
# 93  I-4327             Spirit Bear Raven - Espresso      9.0       g     NaN
# 94  I-4328                            MUFF - BANANA      1.0      ea     NaN
#
#    PakUOM InventoryGroup
# 0      ea              Y
# 1      ea              Y
# 2      ea              Y
# 3      ea              Y
# 4     NaN              Y
# ..    ...            ...
# 90    NaN              Y
# 91    NaN              Y
# 92    NaN              Y
# 93    NaN              Y
# 94    NaN              Y
#
# [95 rows x 8 columns]

# %%
New_Items.shape
# Out:
# (95, 8)

# %%
# Store the list of new items into .csv file
# If New_Items is not empty then we convert it to a csv file. 
if not New_Items.empty:
    path = os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "new items", str(datetime.date(datetime.now()))+"_New_Items.csv")
    New_Items.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Data Summary

# %%
datasum = pd.DataFrame([New_Items.shape, Preps_Nonstd.shape, Items_Nonstd.shape],
                       columns = ['count', 'columns'], 
                       index = ['New_Items', 'Preps_Nonstd', 'Items_Nonstd'])
datasum
# Out:
#               count  columns
# New_Items        95        8
# Preps_Nonstd     19        7
# Items_Nonstd    110        5

# %%
print(New_Items.columns)
# Out:
# Index(['ItemId', 'CategoryID', 'Description', 'CaseQty', 'CaseUOM', 'PakQty',
#        'PakUOM', 'InventoryGroup'],
#       dtype='object')
