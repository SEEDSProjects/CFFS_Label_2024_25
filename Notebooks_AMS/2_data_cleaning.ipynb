# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Part II: Data Cleaning

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
from datetime import datetime

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
#
# ## Import Preprocessed Datasets

# %%
"""
INPUT: a Dataframe
OUPUT: NONE
Description: Prints a description of the datasets
"""
def DescribeDataset(df):
    print(df.dtypes)
    print("\nShape: ", df.shape)
    display(df.head())

# %%
# Reading csv file: data/preprocessed/AMS_data/Items_List.csv
Items = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Items_List.csv"))
DescribeDataset(Items)
# Out:
# ItemId             object
# Description        object
# CaseQty           float64
# CaseUOM            object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (218, 7)
#    ItemId              Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0  I-1927  JALAPENO PEPPER - FRESH     20.0       g    1.25      L
# 1  I-1958          KETCHUP VOL PAK    660.0      ml    1.25      L
# 2  I-2025              MUSTARD DRY     22.5       g    1.25      L
# 3  I-2323    SPICE CAYENNE SHAKER      15.0      ml    1.25      L
# 4  I-2324      SPICE CHILI POWDER      20.0       g    1.25      L
#
#   InventoryGroup
# 0              Y
# 1              Y
# 2              Y
# 3              Y
# 4              Y

# %%
# Read Ingredients_List.csv
Ingredients = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Ingredients_List.csv"))
DescribeDataset(Ingredients)
# Out:
# IngredientId     object
# Qty             float64
# Uom              object
# Recipe           object
# dtype: object
#
# Shape:  (805, 4)
#   IngredientId  Qty   Uom  Recipe
# 0      P-18275  1.0    ea  R-2654
# 1       P-5506  1.0    ea  R-7227
# 2      P-17013  2.0  Tbsp  R-7227
# 3      P-14560  1.0    ea  R-8990
# 4      P-18295  1.0    ea  R-5554

# %%
# Read Preps_List.csv
Preps = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Preps_List.csv"))
DescribeDataset(Preps)
# Out:
# PrepId             object
# Description        object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (114, 5)
#     PrepId              Description   PakQty PakUOM InventoryGroup
# 0   P-6068    Pro - Kansas City BBQ     1.25      L              Y
# 1   P-2824  2023 Alfredo Sauce Gal.  2250.00     ml              Y
# 2   P-1409        2023 Basmati Prep     2.00     Kg              Y
# 3  P-17360   2023 Beef Gravy (prep)     4.50      L              Y
# 4  P-18275    2023 Beets Salad Prep     1.00     ea              Y

# %%
# Read Product_List.csv that was created from 1_data preprocessing
Products = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Products_List.csv"))
DescribeDataset(Products)
# Out:
# ProdId         object
# Description    object
# SalesGroup     object
# dtype: object
#
# Shape:  (38, 3)
#     ProdId                     Description SalesGroup
# 0   R-2654               2024S Beets Salad          Y
# 1   R-7227  2024S Blackend Chick Carbonara          Y
# 2   R-8990     2024S Chicken Caesar (Wrap)          Y
# 3   R-5554       2024S Chicken Pesto Penne          Y
# 4  R-10589            2024S Chicken Po'Boy          Y

# %% [markdown]
# ***
# ## Converter

# %% [markdown]
# ### Create Unit Converter

# %%
# Import standard unit conversion information and construct a dataframe
Std_Unit = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "standard_conversions.csv"))
Std_Unit.head()
# Out:
#    Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty ConvertToUom
# 0     4.92890               1            tsp       4.92890           ml
# 1    14.78700               1           Tbsp      14.78700           ml
# 2   946.35000               1             qt     946.35000           ml
# 3   473.17625               1             pt     473.17625           ml
# 4    28.34950               1             oz      28.34950            g

# %%
# Seperate uoms that converted to 'ml' or 'g'
# Below we create 2 lists. 
# list_unit contains list of unit of measurements that are being converted to milliliters 
# solid_unit contains a list of unit of measurements that are being converted to grams
# tolist() converts a Pandas Series or an array to a python list. 

liquid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'ml', 'ConvertFromUom'].tolist()
solid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'g', 'ConvertFromUom'].tolist()

# %%
# Construct a standard unit converter
def std_converter(qty, uom):
    if uom in Std_Unit['ConvertFromUom'].tolist():
        multiplier = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'Multiplier']
        Qty = float(qty)*float(multiplier)
        Uom = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'ConvertToUom'].values[0]
    else:
        Qty = qty
        Uom = uom
    return (Qty, Uom)

# %% [markdown]
# ***
# ## Items with Non-standard Units

# %%
Ingredients
# Out:
#     IngredientId    Qty   Uom   Recipe
# 0        P-18275    1.0    ea   R-2654
# 1         P-5506    1.0    ea   R-7227
# 2        P-17013    2.0  Tbsp   R-7227
# 3        P-14560    1.0    ea   R-8990
# 4        P-18295    1.0    ea   R-5554
# ..           ...    ...   ...      ...
# 800       I-3005   60.0     g  P-15368
# 801       I-3804   18.0     g  P-15368
# 802       I-6865  500.0     g  P-15368
# 803       I-9117    1.0     L  P-15368
# 804       I-2367  440.0     g  P-16844
#
# [805 rows x 4 columns]

# %%
Items
# Out:
#      ItemId                     Description  CaseQty  CaseUOM  PakQty PakUOM  \
# 0    I-1927         JALAPENO PEPPER - FRESH     20.0        g    1.25      L
# 1    I-1958                 KETCHUP VOL PAK    660.0       ml    1.25      L
# 2    I-2025                     MUSTARD DRY     22.5        g    1.25      L
# 3    I-2323           SPICE CAYENNE SHAKER      15.0       ml    1.25      L
# 4    I-2324             SPICE CHILI POWDER      20.0        g    1.25      L
# ..      ...                             ...      ...      ...     ...    ...
# 213  I-4197          DRESSING Ranch BtrMilk      2.0  oz (fl)     NaN    NaN
# 214  I-4198          Lemon Pepper Seasoning     10.0        g     NaN    NaN
# 215  I-4199  ITEM G21- MANGO HABANERO SAUCE      2.0  oz (fl)     NaN    NaN
# 216  I-4200             Fries Sweet Potato     400.0        g     NaN    NaN
# 217  I-4207  Belgian Waffle Ind.Wrapped 70g      1.0       ea     NaN    NaN
#
#     InventoryGroup
# 0                Y
# 1                Y
# 2                Y
# 3                Y
# 4                Y
# ..             ...
# 213              Y
# 214              Y
# 215              Y
# 216              Y
# 217              Y
#
# [218 rows x 7 columns]

# %%
# Filter out the items whose unit information is unknown 
# We find the column names
col_names = list(Ingredients.columns.values)

# Create a Items_Nonstd list
Items_Nonstd = []

# If the unit of measurement is not grams or ml and ingredient id starts with I and the ingredient is not in ConversionId column of Conversions 
# then we add it to Items_Nonstd list
for index, row in Ingredients.iterrows():
    Ingre = Ingredients.loc[index,'IngredientId']
    Uom = Ingredients.loc[index,'Uom']
    if Uom not in ['g', 'ml'] and Uom not in liquid_unit + solid_unit and Ingre.startswith('I'):
        Dict = {}
        Dict.update(dict(row))
        Items_Nonstd.append(Dict)

# Create a DataFrame from Items_Nonstd list
Items_Nonstd = pd.DataFrame(Items_Nonstd, columns = col_names)
# Remove duplicate ingredients of the same properties so that Items_Nonstd has only unique rows. 
Items_Nonstd.drop_duplicates(subset=['IngredientId'], inplace=True,)
Items_Nonstd
# Out:
#     IngredientId    Qty    Uom   Recipe
# 0        I-14127   1.00     ea  R-14296
# 1        I-14126   1.00     ea  R-14296
# 2         I-2087   0.01  bunch  R-14296
# 4         I-2121   1.00  slice   R-7065
# 5         I-2992   2.00  slice   R-7065
# 6         I-3498   1.00  slice   R-7065
# 7        I-14948   1.00     ea   R-7065
# 9        I-13813   0.09    LBS   R-4598
# 10        I-4207   1.00     ea   R-1916
# 11        I-4172   0.05     ea   R-7572
# 16        I-4109   0.50     ea  P-18275
# 17       I-17991   0.25     ea  P-18275
# 21        I-4118   1.00     ea   P-5506
# 22       I-16224   0.12     ea   P-8990
# 24        I-5505   0.50   HEAD   P-8990
# 27       I-13308   1.00     ea  P-14560
# 28        I-3354   1.00     ea  P-14560
# 30        I-5126   1.00  slice  P-10589
# 32        I-4014   8.00     ea   P-5012
# 33        I-4139   1.00     ea  P-16794
# 34        I-4140   1.00  bunch  P-17013
# 38        I-2066   1.00    LBS  P-11125
# 39       I-11093   1.00   BAGS  P-17358
# 41        I-4153   1.00     ea  P-18268
# 47        I-4161   1.00  slice  P-15057
# 48        I-4162   1.00     ea  P-15057
# 52       I-14978  16.00     ea  P-16856
# 55        I-4173   0.50     ea   P-1488
# 64        I-1695   2.00  slice  P-10195
# 67        I-1789   0.20   HEAD   P-4257
# 68        I-4188   1.00    LBS  P-18052
# 69       I-14442   4.00     ea  P-18327
# 70        I-4190   4.00  piece  P-18327
# 72        I-4193   1.00     ea  P-18327
# 80        I-4201   0.00    LBS   P-8988
# 82        I-5075   2.00     ea  P-10654
# 84        I-1660   1.00    can   P-5552
# 90        I-1588   0.50  2.84L  P-17305
# 92        I-4211   0.50  bunch   P-2584
# 94        I-6203   1.00  1.89L   P-6635
# 95        I-4128  50.00    LBS  P-16748
# 98        I-4226  50.00    LBS  P-10044
# 101       I-4234   3.00   HEAD   P-4733
# 102       I-4236  15.00     ea   P-2307

# %%
# Assigning a Description column to the Items_Nonstd    
for index, row in Items_Nonstd.iterrows():
    idx = row['IngredientId']
    filtered_items = Items.loc[Items['ItemId'] == idx, 'Description']
    if not filtered_items.empty:
        descrp = filtered_items.values[0]
        Items_Nonstd.loc[index, 'Description'] = descrp
    else:
        # Handle the case when there is no matching item for the given 'IngredientId'
        Items_Nonstd.loc[index, 'Description'] = 'Not Found'
        pass

# %%
Items_Nonstd.head()
# Out:
#   IngredientId   Qty    Uom   Recipe                  Description
# 0      I-14127  1.00     ea  R-14296            PITA POCKETS THIN
# 1      I-14126  1.00     ea  R-14296                PITA THICK 5"
# 2       I-2087  0.01  bunch  R-14296                     PARSLEY
# 4       I-2121  1.00  slice   R-7065  PICKLE DILL SANDW LONG SLCD
# 5       I-2992  2.00  slice   R-7065       Bacon Pre-Ckd 30-34 ct

# %%
# Convert the Items_Nonstd DataFrame to a csv file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Items_Nonstd.csv")
Items_Nonstd.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Clean Preps Units

# %%
Preps
# Out:
#       PrepId              Description   PakQty PakUOM InventoryGroup
# 0     P-6068    Pro - Kansas City BBQ     1.25      L              Y
# 1     P-2824  2023 Alfredo Sauce Gal.  2250.00     ml              Y
# 2     P-1409        2023 Basmati Prep     2.00     Kg              Y
# 3    P-17360   2023 Beef Gravy (prep)     4.50      L              Y
# 4    P-18275    2023 Beets Salad Prep     1.00     ea              Y
# ..       ...                      ...      ...    ...            ...
# 109   P-4733                 Tzatziki     4.00     Kg              Y
# 110   P-5741             Veggie Stock     6.00     Kg              Y
# 111   P-2307                  Waffles    55.00     ea              Y
# 112  P-15368     Pro - Marinara Sauce     7.00      L              Y
# 113  P-16844        Simple Syrup 2023   700.00     ml              Y
#
# [114 rows x 5 columns]

# %%
# Creates 2 new columns called StdQty and StdUom in the Preps DataFrame. These columns contain NaN values
# Preparing to fill in these columns with standardized quantities and units of measurement 
Preps['StdQty'] = np.nan
Preps['StdUom'] = np.nan

# %%
Preps
# Out:
#       PrepId              Description   PakQty PakUOM InventoryGroup  StdQty  \
# 0     P-6068    Pro - Kansas City BBQ     1.25      L              Y     NaN
# 1     P-2824  2023 Alfredo Sauce Gal.  2250.00     ml              Y     NaN
# 2     P-1409        2023 Basmati Prep     2.00     Kg              Y     NaN
# 3    P-17360   2023 Beef Gravy (prep)     4.50      L              Y     NaN
# 4    P-18275    2023 Beets Salad Prep     1.00     ea              Y     NaN
# ..       ...                      ...      ...    ...            ...     ...
# 109   P-4733                 Tzatziki     4.00     Kg              Y     NaN
# 110   P-5741             Veggie Stock     6.00     Kg              Y     NaN
# 111   P-2307                  Waffles    55.00     ea              Y     NaN
# 112  P-15368     Pro - Marinara Sauce     7.00      L              Y     NaN
# 113  P-16844        Simple Syrup 2023   700.00     ml              Y     NaN
#
#      StdUom
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 109     NaN
# 110     NaN
# 111     NaN
# 112     NaN
# 113     NaN
#
# [114 rows x 7 columns]

# %%
# Function to apply the conversion logic
def convert_units(row):
    if row['PakUOM'].lower() in ['g', 'grams']:
        return row['PakQty'], 'g'
    elif row['PakUOM'].lower() in ['kg']:
        return row['PakQty'] * 1000, 'g'
    elif row['PakUOM'].lower() in ['ml']:
        return row['PakQty'], 'ml'
    elif row['PakUOM'].lower() in ['l']:
        return row['PakQty'] * 1000, 'ml'
    elif row['PakUOM'].lower() in ['lbs']:
        return row['PakQty'] * 453.59, 'g'
    else:
        return np.nan, np.nan

# Apply the function to each row
Preps['StdQty'], Preps['StdUom'] = zip(*Preps.apply(convert_units, axis=1))

# %%
Preps_Cleaned = Preps[~Preps["StdQty"].isna()]
Preps_Cleaned.reset_index(drop=True, inplace=True)
Preps_Cleaned
# Out:
#      PrepId              Description   PakQty PakUOM InventoryGroup  StdQty  \
# 0    P-6068    Pro - Kansas City BBQ     1.25      L              Y  1250.0
# 1    P-2824  2023 Alfredo Sauce Gal.  2250.00     ml              Y  2250.0
# 2    P-1409        2023 Basmati Prep     2.00     Kg              Y  2000.0
# 3   P-17360   2023 Beef Gravy (prep)     4.50      L              Y  4500.0
# 4   P-16778      2023 Candied walnut     1.00     Kg              Y  1000.0
# ..      ...                      ...      ...    ...            ...     ...
# 60   P-1750       Smoked Paprika Rub     3.00     Kg              Y  3000.0
# 61   P-4733                 Tzatziki     4.00     Kg              Y  4000.0
# 62   P-5741             Veggie Stock     6.00     Kg              Y  6000.0
# 63  P-15368     Pro - Marinara Sauce     7.00      L              Y  7000.0
# 64  P-16844        Simple Syrup 2023   700.00     ml              Y   700.0
#
#    StdUom
# 0      ml
# 1      ml
# 2       g
# 3      ml
# 4       g
# ..    ...
# 60      g
# 61      g
# 62      g
# 63     ml
# 64     ml
#
# [65 rows x 7 columns]

# %%
# Save cleaned preps list to file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_Unit_Cleaned.csv")
Preps_Cleaned.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Get Preps with Nonstandard Unit

# %%
col_names = list(Preps.columns.values)
Preps_Nonstd = []

for index, row in Preps.iterrows():
    StdUom = Preps.loc[index,'StdUom']
    if StdUom not in ['g', 'ml']:
        Dict = {}
        Dict.update(dict(row))
        Preps_Nonstd.append(Dict)

Preps_Nonstd = pd.DataFrame(Preps_Nonstd, columns = col_names)

# %%
Preps_Nonstd
# Out:
#      PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0   P-18275           2023 Beets Salad Prep     1.0     ea              Y
# 1    P-5506   2023 Blackened Carbonara Prep     1.0     ea              Y
# 2    P-8990        2023 Chicken Caesar Prep     1.0     ea              Y
# 3   P-14560   2023 Chicken Caesar wrap Prep     1.0   PORT              Y
# 4   P-10589        2023 Chicken Po'Boy Prep     1.0   PORT              Y
# 5   P-18349            2023 Cooked Linguini    80.0   PORT              Y
# 6   P-11706       2023 Gallery Fries (Side)     1.0     ea              Y
# 7    P-5012  2023 Gallery Nachos Prep (Sml)     1.0     ea              Y
# 8   P-16794     2023 Grilled Pineapple prep    15.0   PORT              Y
# 9    P-4657        2023 Jasmine Rice (Prep)    12.0   PORT              Y
# 10  P-18295              2023 Pesto Chicken     1.0     ea              Y
# 11   P-3286     2023 Po'Boy Prep (Marinate)    22.0     ea              Y
# 12  P-17358               2023 Poutine Prep     1.0     ea              Y
# 13  P-15006     2023 Power Punch Salad Prep     1.0     ea              Y
# 14  P-18451         2023 Truffle Fries Prep     1.0     ea              Y
# 15  P-18272   2023 Truffle Mush. Pasta Prep     1.0   PORT              Y
# 16  P-15057          2023 Vegan Burger Prep     1.0   PORT              Y
# 17  P-16780      2023 Vegan Caesar Dressing    40.0     oz              Y
# 18  P-16782    2023 Vegan Caesar Salad Prep     1.0   PORT              Y
# 19  P-15013                 2023 Wings Prep     1.0   PORT              Y
# 20   P-2424     2023 Yellow Thai Curry Prep     1.0     ea              Y
# 21  P-10674             Aloo tiki prep 2024     1.0     ea              Y
# 22   P-1520             Breading Katsu 2024     1.0     ea              Y
# 23   P-1488            bruschetta Prep 2024     1.0     ea              Y
# 24   P-2535         Caprese Salad Prep 2024     1.0     ea              Y
# 25   P-4582          caramelized onion 2024     1.0      1              Y
# 26   P-4811    Cheese potato ball prep 2024     9.0     ea              Y
# 27  P-10863         chicken katsu prep 2024     1.0     ea              Y
# 28  P-10195        Cuban Sandwich Prep 2024     1.0   PORT              Y
# 29   P-4257        fattoush Salad prep 2024     1.0     ea              Y
# 30   P-9928                Fried Poboy 2024     1.0   PORT              Y
# 31   P-7873          Frying Tofu katsu 2024     1.0     ea              Y
# 32  P-18052          Golden Beets Prep 2023     1.0     lb              Y
# 33  P-18327    Happy Appy platter prep 2024     1.0     ea              Y
# 34  P-18380        HH Babaganoush Prep 2023     1.0     ea              Y
# 35  P-17301             HH Fried Gyoza 2023     1.0     ea              Y
# 36  P-17305             HH Hummus Prep 2023     1.0   PORT              Y
# 37   P-8359        Honey mustard aioli 2024    40.0     oz              Y
# 38   P-8988                House Salad 2024     1.0     ea              Y
# 39  P-10654                Jollof rice 2024    14.0   PORT              Y
# 40   P-6574                Mussel prep 2024     1.0     ea              Y
# 41   P-2674          Tuscan Penne Prep 2024     1.0   PORT              Y
# 42   P-2519        Yellow Thai (Tempeh)2023     1.0   PORT              Y
# 43  P-18336         2023 Cooked Penne Pasta    24.0   PORT              Y
# 44  P-17486          2023 Blackened chicken     1.0     ea              Y
# 45  P-18470        2023 GM Marinated Olives     1.0   PORT              Y
# 46   P-9785                     Greek Salad     1.0     ea              Y
# 47   P-3045     Harissa Chicken (Marinated)   120.0     ea              Y
# 48   P-2307                         Waffles    55.0     ea              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN
# 19     NaN     NaN
# 20     NaN     NaN
# 21     NaN     NaN
# 22     NaN     NaN
# 23     NaN     NaN
# 24     NaN     NaN
# 25     NaN     NaN
# 26     NaN     NaN
# 27     NaN     NaN
# 28     NaN     NaN
# 29     NaN     NaN
# 30     NaN     NaN
# 31     NaN     NaN
# 32     NaN     NaN
# 33     NaN     NaN
# 34     NaN     NaN
# 35     NaN     NaN
# 36     NaN     NaN
# 37     NaN     NaN
# 38     NaN     NaN
# 39     NaN     NaN
# 40     NaN     NaN
# 41     NaN     NaN
# 42     NaN     NaN
# 43     NaN     NaN
# 44     NaN     NaN
# 45     NaN     NaN
# 46     NaN     NaN
# 47     NaN     NaN
# 48     NaN     NaN

# %%
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_NonstdUom.csv")
Preps_Nonstd.to_csv(path, index = False, header = True)

# %%
# NEED TO CONTINUE FROM HERE, FINISH THE UNIT UPDATES
update_prep = pd.read_csv("data/cleaning/update/AMS_data/Preps_UpdateUom.csv")
update_prep #Manual?
# Out:
#      PrepId                    Description  PakQty PakUOM InventoryGroup  \
# 0   P-14356               [PREP KAPPA MAKI     6.0   PORT              N
# 1   P-14560  2023 Chicken Caesar wrap Prep     1.0     ea              Y
# 2    P-9003       2022 Gallery Burger prep     1.0     ea              N
# 3   P-17358              2023 Poutine Prep     1.0     ea              N
# 4   P-15006    2023 Power Punch Salad Prep     1.0     ea              N
# ..      ...                            ...     ...    ...            ...
# 86  P-18470       2023 GM Marinated Olives     1.0   PORT              Y
# 87   P-6881     Candy Cane beets Prep 2023     1.0    LBS              Y
# 88   P-9785                    Greek Salad     1.0     ea              Y
# 89   P-3045    Harissa Chicken (Marinated)   120.0     ea              Y
# 90   P-2307                        Waffles    55.0     ea              Y
#
#       StdQty StdUom
# 0    1511.82      g
# 1     433.59      g
# 2     501.82      g
# 3     705.80      g
# 4     416.73      g
# ..       ...    ...
# 86    143.00      g
# 87    453.59      g
# 88    303.20      g
# 89  25300.00      g
# 90   3711.50      g
#
# [91 rows x 7 columns]

# %% [markdown]
# ***
#
# ## New Items

# %%
# Load current Items List with assigned Emission Factors Category ID
Items_Assigned = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Items_List_Assigned.csv"))
Items_Assigned.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup Food Category
# 0              N           NaN
# 1              N           NaN
# 2              N           NaN
# 3              N           NaN
# 4              N           NaN

# %%
Items_Assigned.shape
# Out:
# (526, 9)

# %%
Items_Assigned["InventoryGroup"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
Items_Assigned["CategoryID"].unique()
# Out:
# array([35, 55, 31, 36, 58, 24, 16,  3, 40,  8, 38, 48, 54, 44, 18, 32, 56,
#        61, 20, 39, 43, 37,  5, 26, 25,  9,  4, 22,  6, 49, 12, 50, 41, 17,
#        57, 11, 34,  1, 45, 42, 46, 10, 51, 53, 21, 28,  7, 13, 30, 63, 59,
#        14])

# %%
Items_Assigned[Items_Assigned["CategoryID"] == 55]
# Out:
#       ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 1     I-8228          55                Grey Goose 1.14L      1.0   fl oz
# 33    I-2640          55                     Water - Tap    250.0      ml
# 92   I-13817          55                  FRENCH AUS JUS    490.0       g
# 102  I-15592          55           JUICE ORANGE CONC 6+1    500.0      ml
# 121   I-3036          55                    MIRIN 5.28GL    720.0      ml
# 171   I-2103          55        PEACH SLCD IN PEAR JUICE    300.0      ml
# 172   I-6204          55     Juice - Lime Fresh Squeezed     30.0       g
# 212  I-17946          55         JUICE orange 100% tetra      1.0       L
# 228   I-6203          55    Juice - Lemon Fresh Squeezed     50.0       g
# 270  I-17129          55                   Boiling Water   3000.0       g
# 274   I-5981          55                Aperol Aperitivo      6.0       L
# 284   I-6182          55             BIB - Coca-Cola 20L      1.0       L
# 285   I-6189          55             BIB - Coke Zero 10L      1.0       L
# 286   I-6188          55  BIB -Canada Dry Ginger Ale 10L      1.0       L
# 287   I-6185          55                BIB - Nestea 20L      1.0       L
# 288  I-12929          55                BIB- Sprite 10L       1.0       L
# 289   I-6224          55           BIB - Tonic Water 12L      1.0       L
# 319   I-7335          55     Tea Assam Brkfst Two Leaves      3.0      ea
# 373   I-1081          55                   GRAND MARNIER    375.0      ml
# 388   I-9117          55       Sawmill Creek - White 16L      1.8       L
# 390   I-7801          55         Sawmill Creek - Red 16L      7.5       L
# 392   I-1471          55          Kronenbourg 1664 Blanc      1.0  bottle
# 441   I-1052          55              BACARDI LIGHT RUM     200.0      ml
# 442   I-1945          55             JUICE PINEAPPLE CAN    350.0      ml
# 444   I-5960          55                  St Remy Brandy    150.0      ml
# 447   I-1093          55                   MALIBU liquor    375.0      ml
# 448   I-1109          55            Meagher's Triple Sec    375.0      ml
# 450  I-16601          55          Sawmill Creek -Rose 4L      8.0       L
# 490   I-4171          55                       Tap Water     10.0       g
#
#      PakQty  PakUOM InventoryGroup      Food Category
# 1       1.0   fl oz              N                NaN
# 33      2.5      ml              N                NaN
# 92      5.0       g              N                NaN
# 102    13.0      ml              N                NaN
# 121  2100.0   fl oz              N                NaN
# 171   300.0      ml              N                NaN
# 172   300.0      oz              N                NaN
# 212     6.0      ml              Y                NaN
# 228     1.2      oz              Y                NaN
# 270  2000.0       g              N                NaN
# 274    18.0   fl oz              Y                NaN
# 284     6.0   fl oz              N                NaN
# 285     6.0   fl oz              N                NaN
# 286     6.0   fl oz              N                NaN
# 287     6.0   fl oz              N                NaN
# 288     6.0   fl oz              N                NaN
# 289     6.0   fl oz              N                NaN
# 319     4.0      ea              N                NaN
# 373    13.0   fl oz              Y                NaN
# 388     2.0   fl oz              N                NaN
# 390   400.0   fl oz              N                NaN
# 392     0.6  bottle              N                NaN
# 441    18.5   fl oz              Y                NaN
# 442    18.5      ml              Y                NaN
# 444    18.5   fl oz              Y                NaN
# 447    18.0   fl oz              Y                NaN
# 448    18.0   fl oz              Y                NaN
# 450    18.0   fl oz              Y                NaN
# 490     1.0      ea              Y  water & beverages

# %% [markdown]
# ### Get the List of New Items

# %%
# Filter new items by itemID that are not in the database and output them in a dataframe
col_names = list(Items.columns.values)
New_Items_List = []

for index, row in Items.iterrows():
    ItemId = Items.loc[index,'ItemId']
    descrp = Items.loc[index,'Description']
    if ItemId not in Items_Assigned['ItemId'].values:
        Dict = {}
        Dict.update(dict(row))
        New_Items_List.append(Dict)
    else:
        print("ItemID: ", ItemId, descrp, " already exists in the database")

New_Items = pd.DataFrame(New_Items_List, columns = col_names)
# Out:
# ItemID:  I-1927 JALAPENO PEPPER - FRESH  already exists in the database
# ItemID:  I-1958 KETCHUP VOL PAK  already exists in the database
# ItemID:  I-2025 MUSTARD DRY  already exists in the database
# ItemID:  I-2323 SPICE CAYENNE SHAKER   already exists in the database
# ItemID:  I-2324 SPICE CHILI POWDER   already exists in the database
# ItemID:  I-2329 SPICE CUMIN SEED GROUND BOX  already exists in the database
# ItemID:  I-4105 SPICE GARLIC GRANULATED   already exists in the database
# ItemID:  I-4106 SPICE Pepper Black Grnd   already exists in the database
# ItemID:  I-2366 SUGAR GOLDEN YEL  already exists in the database
# ItemID:  I-2640 Water - Tap  already exists in the database
# ItemID:  I-2958 Ginger Fresh  already exists in the database
# ItemID:  I-3180 Vinegar White Wine  already exists in the database
# ItemID:  I-4091 SALT KOSHER COARSE  already exists in the database
# ItemID:  I-5095 Onion Granulated powder  already exists in the database
# ItemID:  I-1783 CREAM WHIPPING 33%  already exists in the database
# ItemID:  I-13842 FLOUR ALL PURPOSE.  already exists in the database
# ItemID:  I-2037 BUTTER REG SALTED  already exists in the database
# ItemID:  I-14484 MILK-3.25% 4L jug  already exists in the database
# ItemID:  I-4107 SPICE Nutmeg ground  already exists in the database
# ItemID:  I-2181 RICE BASMATI TEXANA INDIA  already exists in the database
# ItemID:  I-4108 GRAVY MIX TRIO BROWN 1 STEP  already exists in the database
# ItemID:  I-4109 ORANGES 5lb   already exists in the database
# ItemID:  I-5204 ARUGULA WILD BABY  already exists in the database
# ItemID:  I-13001 GOAT CHS CRUMBLE   already exists in the database
# ItemID:  I-17991 GRAPEFRUIT pink lrg 4ct   already exists in the database
# ItemID:  I-1689 CHEESE PARMESAN PURE SHRED  already exists in the database
# ItemID:  I-1874 GARLIC WHOLE PEELED  already exists in the database
# ItemID:  I-2068 ONIONS  already exists in the database
# ItemID:  I-2087 PARSLEY   already exists in the database
# ItemID:  I-2992 Bacon Pre-Ckd 30-34 ct  already exists in the database
# ItemID:  I-13813 Tomato Baby Gem Mix HH  already exists in the database
# ItemID:  I-2119 PFO OIL CANOLA JIB  ANTI FOAM  already exists in the database
# ItemID:  I-2951 SPICE PEPPER BLACK FINE 540G  already exists in the database
# ItemID:  I-4118 Garlic Toast P/baked (Tavoli)  already exists in the database
# ItemID:  I-2446 WALNUT PIECES 1/2 & pcs  already exists in the database
# ItemID:  I-2378 SYRUP CORN GOLDEN  already exists in the database
# ItemID:  I-4119 SPICE Cayenne pepper  already exists in the database
# ItemID:  I-2367 SUGAR GRANULATED FINE  already exists in the database
# ItemID:  I-16224 LEMONS 5lb bag  already exists in the database
# ItemID:  I-5505 Lettuce - Romaine   already exists in the database
# ItemID:  I-13691 DRESSING Caesar  already exists in the database
# ItemID:  I-5777 Flour - Fried Chicken Blend  already exists in the database
# ItemID:  I-13308 TORTILLA 12" FLOUR PRESSED  already exists in the database
# ItemID:  I-3354 Knotted Skewer Bamboo 4"  already exists in the database
# ItemID:  I-14948 Brioche Hamburger Bun  already exists in the database
# ItemID:  I-5220 Lettuce Green Leaf Fillet  already exists in the database
# ItemID:  I-4124 Tomatoes 6x7 5lb bag   already exists in the database
# ItemID:  I-4125 ITEM AIOLI CHIPOLTE  already exists in the database
# ItemID:  I-4127 ITEM G21- CREOLE DRESSING  already exists in the database
# ItemID:  I-5126 CHEESE NATURAL SL MOZZ  already exists in the database
# ItemID:  I-4128 Chicken Flat Thigh s/onknucoff  already exists in the database
# ItemID:  I-4129 ITEM G21-TIKKA MARINADE  already exists in the database
# ItemID:  I-4131 Linguini 20in  already exists in the database
# ItemID:  I-1908 HERB OREGANO LEAVES   already exists in the database
# ItemID:  I-4132 SPICE GARLIC PWDR 3kg  already exists in the database
# ItemID:  I-3804 SPICE CHILI RED PEPPER CRUSHED  already exists in the database
# ItemID:  I-6461 Citric Acid Powder  already exists in the database
# ItemID:  I-7645 Spice Garlic Granulated 700g  already exists in the database
# ItemID:  I-12361 SPICE SMOKED PAPRIKA  already exists in the database
# ItemID:  I-14977 HABANERO peppers  already exists in the database
# ItemID:  I-4133 ROSEMARY - FRESH  already exists in the database
# ItemID:  I-3258 THYME  already exists in the database
# ItemID:  I-7980 Mustard Dijon Grainy Tub  already exists in the database
# ItemID:  I-14556 Beef Ground Lean   already exists in the database
# ItemID:  I-1588 BEAN GARBANZO CHICK PEA  already exists in the database
# ItemID:  I-5803 Garam Masala  already exists in the database
# ItemID:  I-4134 ITEM MAYO GARLIC  already exists in the database
# ItemID:  I-4135 FRIES 3/8 STR/CUT  already exists in the database
# ItemID:  I-1782 CREAM SOUR 4L  already exists in the database
# ItemID:  I-14422 Onions Green 3ct   already exists in the database
# ItemID:  I-2203 SALSA MED THICK AND CHUNKY  already exists in the database
# ItemID:  I-4014 Tortilla Corn 6"  already exists in the database
# ItemID:  I-10955 Cheese 3 Blend Shred   already exists in the database
# ItemID:  I-5731 Olive Kalamata Superior Pitted  already exists in the database
# ItemID:  I-4139 Pineapple each   already exists in the database
# ItemID:  I-4140 CILANTRO 3ct  already exists in the database
# ItemID:  I-3005 BASIL Fresh  already exists in the database
# ItemID:  I-2183 RICE JASMINE FRAGRANT  already exists in the database
# ItemID:  I-6203 Juice - Lemon Fresh Squeezed  already exists in the database
# ItemID:  I-17946 JUICE orange 100% tetra  already exists in the database
# ItemID:  I-4141 Corn Starch 50lb  already exists in the database
# ItemID:  I-5575 Sauce pesto gfs nut free  already exists in the database
# ItemID:  I-2066 ONION RED JUMBO   already exists in the database
# ItemID:  I-2443 VINEGAR WHITE   already exists in the database
# ItemID:  I-16144 SPICE Pickling Whole SO  already exists in the database
# ItemID:  I-6204 Juice - Lime Fresh Squeezed  already exists in the database
# ItemID:  I-2402 TOMATO - 6 X 7 MED  already exists in the database
# ItemID:  I-1635 BUTTERMILK 3.25%  already exists in the database
# ItemID:  I-4184 SAUCE RED HOT  already exists in the database
# ItemID:  I-11093 Cheese Curd Portions 80G  already exists in the database
# ItemID:  I-15200 SALAD TUSCAN MIXED  already exists in the database
# ItemID:  I-4925 Carrots Baby - Tri Color  already exists in the database
# ItemID:  I-4147 ITEM ORGANIC QUINOA  already exists in the database
# ItemID:  I-4148 ITEM EDAMAME FALAFEL MIX  already exists in the database
# ItemID:  I-4149 ITEM G21- GREEN GODDESS  already exists in the database
# ItemID:  I-8851 ITEM PULLED PORK RUB  already exists in the database
# ItemID:  I-2153 PORK BUTT BNLS BULK FZN  already exists in the database
# ItemID:  I-1655 CELERY  already exists in the database
# ItemID:  I-14423 CARROTS JUMBO 5LB   already exists in the database
# ItemID:  I-12173 Sauce BBQ Kansas City Style  already exists in the database
# ItemID:  I-4152 PEPPERS RED 5LB BAG  already exists in the database
# ItemID:  I-15554 PEPPERS YELLOW 5LB  already exists in the database
# ItemID:  I-4153 Eggplant 18-24 CT  already exists in the database
# ItemID:  I-4154 PEPPER GREEN 5LB  already exists in the database
# ItemID:  I-1892 CABBAGE RED   already exists in the database
# ItemID:  I-4155 TAIWAN GREEN CABBAGE  already exists in the database
# ItemID:  I-4156 ITEM MAYO VEGAN  already exists in the database
# ItemID:  I-2436 VINEGAR APPLE CIDER PURE  already exists in the database
# ItemID:  I-5008 Sauce Sriracha Hot Chilli   already exists in the database
# ItemID:  I-15221 White Truffle Oil Truffco  already exists in the database
# ItemID:  I-4158 ITEM WILD MUSHROOM MIX  already exists in the database
# ItemID:  I-2121 PICKLE DILL SANDW LONG SLCD  already exists in the database
# ItemID:  I-4160 Cheese Cheddar Slcd Veg  already exists in the database
# ItemID:  I-4161 SO-VEG BACON VEGAN FZN  already exists in the database
# ItemID:  I-4162 ITEM - Bean Patty  already exists in the database
# ItemID:  I-1649 CAPER CAPUCINE  already exists in the database
# ItemID:  I-18051 CHEESE vegan 4 chz blend  already exists in the database
# ItemID:  I-16699 CHICKEN TENDER Vegan   already exists in the database
# ItemID:  I-2347 SPICE THYME GROUND   already exists in the database
# ItemID:  I-14978 Brioche Bun Vegan Frz  already exists in the database
# ItemID:  I-17977 CHICKEN wing split   already exists in the database
# ItemID:  I-4166 ITEM - Curry Yellow  already exists in the database
# ItemID:  I-14429 LIMES 5lb bag   already exists in the database
# ItemID:  I-12351 SESAME BLACK 5LB SK  already exists in the database
# ItemID:  I-15637 Whole Green Beans IQF  already exists in the database
# ItemID:  I-2102 PEA GRADE A IQF   already exists in the database
# ItemID:  I-1995 MINT LEAVES  already exists in the database
# ItemID:  I-5203 POTATO YUKON GOLD LARGE  already exists in the database
# ItemID:  I-4170 ITEM - Tamarin Chutney  already exists in the database
# ItemID:  I-14419 ONIONS RED 5LB  already exists in the database
# ItemID:  I-14790 Olive Oil Extra virgin   already exists in the database
# ItemID:  I-7656 Egg Yolk Liq  already exists in the database
# ItemID:  I-4171 Tap Water  already exists in the database
# ItemID:  I-2086 PANKO (CRUMBLE)  already exists in the database
# ItemID:  I-4172 Bread Focaccia Slab 10x16  already exists in the database
# ItemID:  I-4173 Bocconcini Lrg 100gm 2kg pail  already exists in the database
# ItemID:  I-4174 Sliced Almonds blanched  already exists in the database
# ItemID:  I-1882 BALSAMIC REDUCTION GL FR  already exists in the database
# ItemID:  I-2159 POTATO RUSSET BAKER 100CT BOX  already exists in the database
# ItemID:  I-3498 Cheese Cheddar Slices 21gm  already exists in the database
# ItemID:  I-1924 IRI SHIRO GOMA (SESAME SEEDS)  already exists in the database
# ItemID:  I-7775 Syrup Table Pancake Maple 4L  already exists in the database
# ItemID:  I-1660 SAUCE CHIPOTLE IN ADOBO   already exists in the database
# ItemID:  I-4180 ITEM SLICED HAM  already exists in the database
# ItemID:  I-1695 CHEESE SWISS SLCD NAT 21G  already exists in the database
# ItemID:  I-1789 CUCUMBER LONG ENGLISH MED  already exists in the database
# ItemID:  I-4186 Tofu MED Firm Sunrise  already exists in the database
# ItemID:  I-4187 STARCH CORN 5kg  already exists in the database
# ItemID:  I-4188 Beets gold 5lb  already exists in the database
# ItemID:  I-4189 POTATO TATER TOTS TFC  already exists in the database
# ItemID:  I-14442 Falafel Balls 300ct  already exists in the database
# ItemID:  I-4190 Gyoza Pork Steamed 5kg  already exists in the database
# ItemID:  I-4192 ITEM DRES ASIAN SESAME  already exists in the database
# ItemID:  I-4193 Misc Extras  already exists in the database
# ItemID:  I-4194 Paste Red Achiote 110G  already exists in the database
# ItemID:  I-4195 SPICE Harissa dry blend  already exists in the database
# ItemID:  I-14126 PITA THICK 5"  already exists in the database
# ItemID:  I-14127 PITA POCKETS THIN  already exists in the database
# ItemID:  I-1894 ONIONS GREEN   already exists in the database
# ItemID:  I-2341 Spice Paprika Shk 540g  already exists in the database
# ItemID:  I-1917 HONEY LIQUID SQUEEZE CAN  already exists in the database
# ItemID:  I-4201 JIT-BEET Candy Cane Teen 5lb  already exists in the database
# ItemID:  I-4202 Carrots Medium Rainbow  already exists in the database
# ItemID:  I-4203 SPICE CURRY POWDER SHAKER   already exists in the database
# ItemID:  I-2400 TOMATO PASTE    already exists in the database
# ItemID:  I-2464 TOMATO - WHOLE PLUM   already exists in the database
# ItemID:  I-5075 Spice Bay Leaf Whl  already exists in the database
# ItemID:  I-4204 SPICE CUMIN SEED WHOLE  already exists in the database
# ItemID:  I-2243 SAUCE WORCESTERSHIRE 5Z  already exists in the database
# ItemID:  I-2920 Sauce Soy Kikkoman Jap  already exists in the database
# ItemID:  I-1941 JUICE LEMON PLAS  already exists in the database
# ItemID:  I-12764 SESAME OIL 1.65L  already exists in the database
# ItemID:  I-12132 Soy Sauce Tamari G/F Yamasa  already exists in the database
# ItemID:  I-11704 Chili Oil - Sanwu Brand Spicy  already exists in the database
# ItemID:  I-8975 VINEGAR - CHINKIANG GOLD PLUM  already exists in the database
# ItemID:  I-4205 MUSSEL 23-39ct cooked frozen  already exists in the database
# ItemID:  I-4206 Rose Cooking Wine 13.2 L  already exists in the database
# ItemID:  I-2339 SPICE PAPRIKA   already exists in the database
# ItemID:  I-5941 Broccoli Crowns  already exists in the database
# ItemID:  I-14418 Cauliflower each   already exists in the database
# ItemID:  I-10834 Tahini 2lb  already exists in the database
# ItemID:  I-4208 SESAME PASTE  already exists in the database
# ItemID:  I-15834 SO-TEMPEH organic   already exists in the database
# ItemID:  I-2093 PASTA PENNE RIGATE   already exists in the database
# ItemID:  I-7338 Chicken Brst b/l s/l random  already exists in the database
# ItemID:  I-2257 SEASONING CAJUN   already exists in the database
# ItemID:  I-1859 DILL - FRESH   already exists in the database
# ItemID:  I-5264 Yogurt Plain 4LTR  already exists in the database
# ItemID:  I-4211 CILANTRO 30ct case  already exists in the database
# ItemID:  I-5773 Chana (Chickpea) Flour  already exists in the database
# ItemID:  I-4212 SPICE Chaat Masala  already exists in the database
# ItemID:  I-1610 BEETS  already exists in the database
# ItemID:  I-4216 SALT HYGRADE FINE  already exists in the database
# ItemID:  I-4219 VINEGAR RED WINE   already exists in the database
# ItemID:  I-4220 SPICE ONION GRANULATED  already exists in the database
# ItemID:  I-4222 CHEESE FETA 3kg  already exists in the database
# ItemID:  I-14532 Black Olives sliced  already exists in the database
# ItemID:  I-4226 Sui Choy  already exists in the database
# ItemID:  I-4229 RED PEPPER PWDR Coarse  already exists in the database
# ItemID:  I-4231 Oat Milk Barista Blend  already exists in the database
# ItemID:  I-2349 SPINACH WASHED TRIMMED  already exists in the database
# ItemID:  I-17129 Boiling Water  already exists in the database
# ItemID:  I-4232 YEAST DRY ACTIVE  already exists in the database
# ItemID:  I-4233 SPICE SUMAC ground  already exists in the database
# ItemID:  I-4234 Cucumber 3ct   already exists in the database
# ItemID:  I-4235 Spice Dill Weed  already exists in the database
# ItemID:  I-2967 Spice Coriander Shaker  already exists in the database
# ItemID:  I-12212 Brown Sugar 1KG Bags  already exists in the database
# ItemID:  I-4236 Egg Med packed by dozen   already exists in the database
# ItemID:  I-4237 Extract Vanilla Pure 500ml  already exists in the database
# ItemID:  I-6865 Onion White Peeled  already exists in the database
# ItemID:  I-9117 Sawmill Creek - White 16L  already exists in the database
# ItemID:  I-4198 Lemon Pepper Seasoning  already exists in the database
# ItemID:  I-4199 ITEM G21- MANGO HABANERO SAUCE  already exists in the database

# %%
New_Items.insert(1, "CategoryID", '')
New_Items
# Out:
#    ItemId CategoryID                     Description  CaseQty  CaseUOM  \
# 0  I-4196                          ITEM SAUCE BURGER      2.0  oz (fl)
# 1  I-4197                     DRESSING Ranch BtrMilk      2.0  oz (fl)
# 2  I-4200                        Fries Sweet Potato     400.0        g
# 3  I-4207             Belgian Waffle Ind.Wrapped 70g      1.0       ea
#
#    PakQty  PakUOM InventoryGroup
# 0     NaN     NaN              Y
# 1     NaN     NaN              Y
# 2     NaN     NaN              Y
# 3     NaN     NaN              Y

# %%
New_Items.shape
# Out:
# (4, 8)

# %%
# Store the list of new items into .csv file
# If New_Items is not empty then we convert it to a csv file. 
if not New_Items.empty:
    path = os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "new items", str(datetime.date(datetime.now()))+"_New_Items.csv")
    New_Items.to_csv(path, index = False, header = True)

# %%
# AMS version
file2 = pd.read_excel("data/mapping/new items added/AMS_data/New_Items_2023/New_Items_Added_2023-11-28.xlsx")
file2.to_csv("data/mapping/new items added/AMS_data/New_Items_2023/New_Items_Added_2023-11-28.csv", index=False)

# %% [markdown]
# ***
# ## Data Summary

# %%
datasum = pd.DataFrame([New_Items.shape, Preps_Nonstd.shape, Items_Nonstd.shape],
                       columns = ['count', 'columns'], 
                       index = ['New_Items', 'Preps_Nonstd', 'Items_Nonstd'])
datasum
# Out:
#               count  columns
# New_Items         4        8
# Preps_Nonstd     49        7
# Items_Nonstd     44        5

# %%
print(New_Items.columns)
# Out:
# Index(['ItemId', 'CategoryID', 'Description', 'CaseQty', 'CaseUOM', 'PakQty',
#        'PakUOM', 'InventoryGroup'],
#       dtype='object')
