# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ****
#
# ## Part II: Data Cleaning

# %% [markdown]
# ## Set up and Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
from datetime import datetime

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
#
# ## Import Preprocessed Datasets

# %%
"""
INPUT: a Dataframe
OUPUT: NONE
Description: Prints a description of the datasets
"""
def DescribeDataset(df):
    print(df.dtypes)
    print("\nShape: ", df.shape)
    display(df.head())

# %%
# Reading csv file: data/preprocessed/AMS_data/Items_List.csv
Items = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Items_List.csv"))
DescribeDataset(Items)
# Out:
# ItemId             object
# Description        object
# CaseQty           float64
# CaseUOM            object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (559, 7)
#     ItemId          Description  CaseQty CaseUOM  PakQty PakUOM InventoryGroup
# 0   I-1971                LIMES     0.25      ea     1.0     ea              N
# 1   I-8228     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz              N
# 2  I-15803  Red Bull Watermelon     1.00     can     1.0    can              N
# 3   I-5505   Lettuce - Romaine      0.25    HEAD     1.0   HEAD              N
# 4   I-8667     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml              N

# %%
# Read Ingredients_List.csv
Ingredients = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Ingredients_List.csv"))
DescribeDataset(Ingredients)
# Out:
# IngredientId     object
# Qty             float64
# Uom              object
# Recipe           object
# dtype: object
#
# Shape:  (2158, 4)
#   IngredientId   Qty    Uom   Recipe
# 0       I-1971  0.25     ea  R-17284
# 1       I-8228  1.00  fl oz  R-17284
# 2      I-15803  1.00    can  R-17284
# 3       I-5505  0.25   HEAD  R-18292
# 4       I-8667  2.00  fl oz  R-18292

# %%
# Read Preps_List.csv
Preps = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Preps_List.csv"))
DescribeDataset(Preps)
# Out:
# PrepId             object
# Description        object
# PakQty            float64
# PakUOM             object
# InventoryGroup     object
# dtype: object
#
# Shape:  (73, 5)
#     PrepId               Description  PakQty PakUOM InventoryGroup
# 0  P-14356          [PREP KAPPA MAKI     6.0   PORT              N
# 1  P-14560     2022 Caesar Wrap prep     1.0     ea              N
# 2   P-9003  2022 Gallery Burger prep     1.0     ea              N
# 3  P-17305          2022 Hummus prep  1600.0      g              N
# 4  P-17358         2022 Poutine Prep     1.0   PORT              N

# %%
# Read Product_List.csv that was created from 1_data preprocessing
Products = pd.read_csv(os.path.join(os.getcwd(), "data", "preprocessed", "AMS_data", "Products_List.csv"))
DescribeDataset(Products)
# Out:
# ProdId         object
# Description    object
# SalesGroup     object
# dtype: object
#
# Shape:  (301, 3)
#     ProdId                 Description SalesGroup
# 0  P-15019   Butter Chicken Prep 2023           N
# 1  P-18296   Teriyaki Tempeh Prep 2023          N
# 2  P-17366  Chicken Teriyaki Prep 2023          Y
# 3  P-18330            Tuscan Prep 2023          N
# 4  P-14560       2022 Caesar Wrap prep          N

# %% [markdown]
# ***
# ## Converter

# %% [markdown]
# ### Create Unit Converter

# %%
# Import standard unit conversion information and construct a dataframe
Std_Unit = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "standard_conversions.csv"))
Std_Unit.head()
# Out:
#    Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty ConvertToUom
# 0     4.92890               1            tsp       4.92890           ml
# 1    14.78700               1           Tbsp      14.78700           ml
# 2   946.35000               1             qt     946.35000           ml
# 3   473.17625               1             pt     473.17625           ml
# 4    28.34950               1             oz      28.34950            g

# %%
# Seperate uoms that converted to 'ml' or 'g'
# Below we create 2 lists. 
# list_unit contains list of unit of measurements that are being converted to milliliters 
# solid_unit contains a list of unit of measurements that are being converted to grams
# tolist() converts a Pandas Series or an array to a python list. 

liquid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'ml', 'ConvertFromUom'].tolist()
solid_unit = Std_Unit.loc[Std_Unit['ConvertToUom'] == 'g', 'ConvertFromUom'].tolist()

# %%
# Construct a standard unit converter
def std_converter(qty, uom):
    if uom in Std_Unit['ConvertFromUom'].tolist():
        multiplier = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'Multiplier']
        Qty = float(qty)*float(multiplier)
        Uom = Std_Unit.loc[Std_Unit['ConvertFromUom'] == uom, 'ConvertToUom'].values[0]
    else:
        Qty = qty
        Uom = uom
    return (Qty, Uom)

# %% [markdown]
# ***
# ## Items with Non-standard Units

# %%
Ingredients
# Out:
#      IngredientId    Qty    Uom   Recipe
# 0          I-1971   0.25     ea  R-17284
# 1          I-8228   1.00  fl oz  R-17284
# 2         I-15803   1.00    can  R-17284
# 3          I-5505   0.25   HEAD  R-18292
# 4          I-8667   2.00  fl oz  R-18292
# ...           ...    ...    ...      ...
# 2153       I-2262   1.00      g  P-18049
# 2154      I-14434  80.00      g  P-18049
# 2155      I-15477   1.00   PORT  P-18049
# 2156      I-15637  20.00      g  P-18049
# 2157      I-17941   8.00  fl oz  P-18049
#
# [2158 rows x 4 columns]

# %%
Items
# Out:
#       ItemId                    Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0     I-1971                          LIMES     0.25      ea     1.0     ea
# 1     I-8228               Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2    I-15803            Red Bull Watermelon     1.00     can     1.0    can
# 3     I-5505             Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4     I-8667               ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
# ..       ...                            ...      ...     ...     ...    ...
# 554  I-14843    PieR Item Wild Mushroom Mix     2.00      oz     1.0      g
# 555  I-18348                 Gremolata 2022     5.00       g     1.0      g
# 556  I-15425  G21 Southwest Tofu Scrambled      1.00    PORT     1.0   PORT
# 557   I-2432           VEG BURGER GARDEN 4Z     1.00      ea     1.0     ea
# 558  I-17977            CHICKEN wing split     14.00      oz     1.0     oz
#
#     InventoryGroup
# 0                N
# 1                N
# 2                N
# 3                N
# 4                N
# ..             ...
# 554              N
# 555              N
# 556              N
# 557              N
# 558              Y
#
# [559 rows x 7 columns]

# %%
# Filter out the items whose unit information is unknown 
# We find the column names
col_names = list(Ingredients.columns.values)

# Create a Items_Nonstd list
Items_Nonstd = []

# If the unit of measurement is not grams or ml and ingredient id starts with I and the ingredient is not in ConversionId column of Conversions 
# then we add it to Items_Nonstd list
for index, row in Ingredients.iterrows():
    Ingre = Ingredients.loc[index,'IngredientId']
    Uom = Ingredients.loc[index,'Uom']
    if Uom not in ['g', 'ml'] and Uom not in liquid_unit + solid_unit and Ingre.startswith('I'):
        Dict = {}
        Dict.update(dict(row))
        Items_Nonstd.append(Dict)

# Create a DataFrame from Items_Nonstd list
Items_Nonstd = pd.DataFrame(Items_Nonstd, columns = col_names)
# Remove duplicate ingredients of the same properties so that Items_Nonstd has only unique rows. 
Items_Nonstd.drop_duplicates(subset=['IngredientId'], inplace=True,)
Items_Nonstd
# Out:
#     IngredientId    Qty   Uom   Recipe
# 0         I-1971  0.250    ea  R-17284
# 1        I-15803  1.000   can  R-17284
# 2         I-5505  0.250  HEAD  R-18292
# 3        I-11706  1.000    ea  R-18292
# 4        I-13308  1.000    ea  R-18292
# ..           ...    ...   ...      ...
# 414      I-12339  1.000  PORT   P-3173
# 430       I-2586  0.005  tank  R-13392
# 443       I-9186  1.000    ea  R-15315
# 450      I-15425  1.000  PORT  R-15426
# 455       I-2432  1.000    ea  R-18675
#
# [134 rows x 4 columns]

# %%
# Assigning a Description column to the Items_Nonstd    
for index, row in Items_Nonstd.iterrows():
    idx = row['IngredientId']
    filtered_items = Items.loc[Items['ItemId'] == idx, 'Description']
    if not filtered_items.empty:
        descrp = filtered_items.values[0]
        Items_Nonstd.loc[index, 'Description'] = descrp
    else:
        # Handle the case when there is no matching item for the given 'IngredientId'
        Items_Nonstd.loc[index, 'Description'] = 'Not Found'
        pass

# %%
Items_Nonstd.head()
# Out:
#   IngredientId   Qty   Uom   Recipe                 Description
# 0       I-1971  0.25    ea  R-17284                       LIMES
# 1      I-15803  1.00   can  R-17284         Red Bull Watermelon
# 2       I-5505  0.25  HEAD  R-18292          Lettuce - Romaine
# 3      I-11706  1.00    ea  R-18292        Glry Side Fries 2023
# 4      I-13308  1.00    ea  R-18292  TORTILLA 12" FLOUR PRESSED

# %%
# Convert the Items_Nonstd DataFrame to a csv file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Items_Nonstd.csv")
Items_Nonstd.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Clean Preps Units

# %%
Preps
# Out:
#      PrepId                  Description  PakQty PakUOM InventoryGroup
# 0   P-14356             [PREP KAPPA MAKI     6.0   PORT              N
# 1   P-14560        2022 Caesar Wrap prep     1.0     ea              N
# 2    P-9003     2022 Gallery Burger prep     1.0     ea              N
# 3   P-17305             2022 Hummus prep  1600.0      g              N
# 4   P-17358            2022 Poutine Prep     1.0   PORT              N
# ..      ...                          ...     ...    ...            ...
# 68  P-18329     Truffle Cream prep 2023    310.0      g              Y
# 69  P-18330             Tuscan Prep 2023     1.0   PORT              N
# 70  P-15013              Wings Prep 2023     1.0   PORT              Y
# 71  P-18313          Yam Fries prep 2023     1.0   PORT              N
# 72  P-18049  Yellow Curry Prep Gall.2023     1.0   PORT              Y
#
# [73 rows x 5 columns]

# %%
# Creates 2 new columns called StdQty and StdUom in the Preps DataFrame. These columns contain NaN values
# Preparing to fill in these columns with standardized quantities and units of measurement 
Preps['StdQty'] = np.nan
Preps['StdUom'] = np.nan

# %%
Preps
# Out:
#      PrepId                  Description  PakQty PakUOM InventoryGroup  \
# 0   P-14356             [PREP KAPPA MAKI     6.0   PORT              N
# 1   P-14560        2022 Caesar Wrap prep     1.0     ea              N
# 2    P-9003     2022 Gallery Burger prep     1.0     ea              N
# 3   P-17305             2022 Hummus prep  1600.0      g              N
# 4   P-17358            2022 Poutine Prep     1.0   PORT              N
# ..      ...                          ...     ...    ...            ...
# 68  P-18329     Truffle Cream prep 2023    310.0      g              Y
# 69  P-18330             Tuscan Prep 2023     1.0   PORT              N
# 70  P-15013              Wings Prep 2023     1.0   PORT              Y
# 71  P-18313          Yam Fries prep 2023     1.0   PORT              N
# 72  P-18049  Yellow Curry Prep Gall.2023     1.0   PORT              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# ..     ...     ...
# 68     NaN     NaN
# 69     NaN     NaN
# 70     NaN     NaN
# 71     NaN     NaN
# 72     NaN     NaN
#
# [73 rows x 7 columns]

# %%
# Function to apply the conversion logic
def convert_units(row):
    if row['PakUOM'].lower() in ['g', 'grams']:
        return row['PakQty'], 'g'
    elif row['PakUOM'].lower() in ['kg']:
        return row['PakQty'] * 1000, 'g'
    elif row['PakUOM'].lower() in ['ml']:
        return row['PakQty'], 'ml'
    elif row['PakUOM'].lower() in ['l']:
        return row['PakQty'] * 1000, 'ml'
    else:
        return np.nan, np.nan

# Apply the function to each row
Preps['StdQty'], Preps['StdUom'] = zip(*Preps.apply(convert_units, axis=1))

# %%
Preps_Cleaned = Preps[~Preps["StdQty"].isna()]
Preps_Cleaned.reset_index(drop=True, inplace=True)
Preps_Cleaned
# Out:
#      PrepId                   Description   PakQty PakUOM InventoryGroup  \
# 0   P-17305              2022 Hummus prep  1600.00      g              N
# 1   P-16793         2022 Pulled Pork Prep     6.00     Kg              Y
# 2   P-18380         2023 Babaganoush Prep   750.00      g              N
# 3   P-18458  2023 Fresh burger Patty prep     2.60     Kg              Y
# 4   P-18575     2023 Wings Hot sauce prep  1650.00      g              Y
# 5   P-18531      2023.7 Chili Garlic Prep  1000.00      g              N
# 6   P-18530      2023.7 Sambal Chili Prep  2000.00      g              N
# 7   P-18052               Beets prep 2023     2.00     Kg              N
# 8   P-18336  Cooked Penne pasta prep 2023     4.00     Kg              N
# 9   P-18381            Eggplant Prep 2023   500.00      g              N
# 10  P-14551        Porch Prep Pulled Pork     4.70     Kg              N
# 11  P-18321       Prep Alfredo (Gall)2023  2250.00      g              N
# 12   P-6150             PREP BURGER SAUCE     8.00      L              N
# 13   P-3249                 PREP CRAB MIX     5.85     Kg              N
# 14   P-8018              PREP GARLIC MAYO     4.00      L              N
# 15  P-18444      Prep hummus Gallery 2023  1408.00      g              N
# 16   P-6068          PREP KANSAS CITY BBQ     1.00      L              N
# 17   P-6053       PREP- MANGO VINAIGRETTE     1.00      L              N
# 18   P-5814          PREP PULLED PORK RUB   880.00      g              N
# 19   P-6476       PREP SRIRACHA MAYONAISE   650.00     ml              N
# 20   P-3237           PREP TERIYAKI SAUCE    76.00      L              N
# 21   P-6811               PREP VEGAN MAYO     2.00      L              N
# 22  P-15419          Spicy mayo prep 2023     1.25      L              N
# 23  P-18329      Truffle Cream prep 2023    310.00      g              Y
#
#      StdQty StdUom
# 0    1600.0      g
# 1    6000.0      g
# 2     750.0      g
# 3    2600.0      g
# 4    1650.0      g
# 5    1000.0      g
# 6    2000.0      g
# 7    2000.0      g
# 8    4000.0      g
# 9     500.0      g
# 10   4700.0      g
# 11   2250.0      g
# 12   8000.0     ml
# 13   5850.0      g
# 14   4000.0     ml
# 15   1408.0      g
# 16   1000.0     ml
# 17   1000.0     ml
# 18    880.0      g
# 19    650.0     ml
# 20  76000.0     ml
# 21   2000.0     ml
# 22   1250.0     ml
# 23    310.0      g

# %%
# Save cleaned preps list to file
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_Unit_Cleaned.csv")
Preps_Cleaned.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Get Preps with Nonstandard Unit

# %%
col_names = list(Preps.columns.values)
Preps_Nonstd = []

for index, row in Preps.iterrows():
    StdUom = Preps.loc[index,'StdUom']
    if StdUom not in ['g', 'ml']:
        Dict = {}
        Dict.update(dict(row))
        Preps_Nonstd.append(Dict)

Preps_Nonstd = pd.DataFrame(Preps_Nonstd, columns = col_names)

# %%
Preps_Nonstd
# Out:
#      PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0   P-14356                [PREP KAPPA MAKI     6.0   PORT              N
# 1   P-14560           2022 Caesar Wrap prep     1.0     ea              N
# 2    P-9003        2022 Gallery Burger prep     1.0     ea              N
# 3   P-17358               2022 Poutine Prep     1.0   PORT              N
# 4   P-15006     2022 Power Punch Salad prep     1.0   PORT              N
# 5   P-16795  2022 Pulled Pork Sandwich prep     1.0   PORT              N
# 6   P-14552     2022 Vegan Pulled Pork Prep     1.0     ea              N
# 7   P-18327          2023 Appi Platter prep     1.0   PORT              N
# 8   P-18453      2023 GM Tempeh curry prep      1.0   PORT              N
# 9   P-18451      2023 Gm truffle Fries prep     1.0   PORT              N
# 10  P-18452          2023 Gm Yam fries prep     1.0   PORT              N
# 11  P-18540      2023 Home made burger prep     1.0     ea              N
# 12  P-18397     2023 Mixed Green salad prep     1.0     ea              N
# 13  P-18275          Beets salad prep 2023      1.0   PORT              N
# 14  P-15019       Butter Chicken Prep 2023      1.0   PORT              N
# 15  P-17366      Chicken Teriyaki Prep 2023     1.0   PORT              Y
# 16  P-18316       Crispy EggPlant prep 2023     3.0   PORT              Y
# 17  P-18266           KFC Gallery prep 2022     1.0   PORT              N
# 18  P-18324                Nachos prep 2023     1.0   PORT              N
# 19  P-18295         Pesto chicken prep 2022     1.0   PORT              N
# 20  P-18335                 Poboy Prep 2023    22.0   PORT              Y
# 21  P-14553      Porch Prep Vegan Cole Slaw     1.0   PORT              N
# 22   P-4326                   PREP AVOCADO      1.0     ea              N
# 23  P-14352            PREP CALIFORNIA ROLL     1.0   PORT              N
# 24   P-8267           PREP CARMALIZED ONION    10.0   2 KG              N
# 25  P-14411           PREP CATERPILLAR ROLL     1.0   PORT              N
# 26  P-14383          PREP CHICKEN TERI ROLL     1.0   PORT              N
# 27  P-14372             PREP CONDIMEMT MAKI     1.0   PORT              N
# 28  P-14376            PREP CONDIMENT COMBO     1.0   PORT              N
# 29   P-8099             PREP CONDIMENT ROLL     1.0   srvg              N
# 30  P-15606             PREP CONTAINER MAKI     1.0   PORT              N
# 31  P-14403               PREP CREAM CHEESE    12.0   PORT              N
# 32  P-14353              PREP DYNAMITE ROLL     1.0   PORT              N
# 33  P-14396                 PREP HOUSE ROLL     1.0   PORT              N
# 34  P-14430             PREP MANGO&AVO ROLL     1.0   PORT              N
# 35  P-14413          PREP PHILADELPHIA ROLL     1.0   PORT              N
# 36  P-14360                PREP SALMON MAKI     1.0   PORT              N
# 37   P-3173          PREP SUSHI RICE COOKED    58.0   PORT              N
# 38  P-14354                PREP TEMPURA YAM     1.0   PORT              N
# 39  P-14357                  PREP TUNA MAKI     1.0   PORT              N
# 40  P-14369                PREP VEGGIE ROLL     1.0   PORT              N
# 41  P-14355                   PREP YAM ROLL     1.0   PORT              N
# 42  P-18358       Sub Onion Rings prep 2023     1.0     ea              N
# 43  P-18361     Sub Truffle fries 2023 Prep     1.0     ea              N
# 44  P-18296       Teriyaki Tempeh Prep 2023     1.0   PORT              N
# 45  P-18330                Tuscan Prep 2023     1.0   PORT              N
# 46  P-15013                 Wings Prep 2023     1.0   PORT              Y
# 47  P-18313             Yam Fries prep 2023     1.0   PORT              N
# 48  P-18049     Yellow Curry Prep Gall.2023     1.0   PORT              Y
#
#     StdQty  StdUom
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 8      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 11     NaN     NaN
# 12     NaN     NaN
# 13     NaN     NaN
# 14     NaN     NaN
# 15     NaN     NaN
# 16     NaN     NaN
# 17     NaN     NaN
# 18     NaN     NaN
# 19     NaN     NaN
# 20     NaN     NaN
# 21     NaN     NaN
# 22     NaN     NaN
# 23     NaN     NaN
# 24     NaN     NaN
# 25     NaN     NaN
# 26     NaN     NaN
# 27     NaN     NaN
# 28     NaN     NaN
# 29     NaN     NaN
# 30     NaN     NaN
# 31     NaN     NaN
# 32     NaN     NaN
# 33     NaN     NaN
# 34     NaN     NaN
# 35     NaN     NaN
# 36     NaN     NaN
# 37     NaN     NaN
# 38     NaN     NaN
# 39     NaN     NaN
# 40     NaN     NaN
# 41     NaN     NaN
# 42     NaN     NaN
# 43     NaN     NaN
# 44     NaN     NaN
# 45     NaN     NaN
# 46     NaN     NaN
# 47     NaN     NaN
# 48     NaN     NaN

# %%
path = os.path.join(os.getcwd(), "data", "cleaning", "AMS_data", "Preps_NonstdUom.csv")
Preps_Nonstd.to_csv(path, index = False, header = True)

# %%
# NEED TO CONTINUE FROM HERE, FINISH THE UNIT UPDATES
update_prep = pd.read_csv("data/cleaning/update/AMS_data/Preps_UpdateUom.csv")
update_prep #Manual?
# Out:
#      PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0   P-14356                [PREP KAPPA MAKI       6   PORT              N
# 1   P-14560           2022 Caesar Wrap prep       1     ea              N
# 2    P-9003        2022 Gallery Burger prep       1     ea              N
# 3   P-17358               2022 Poutine Prep       1   PORT              N
# 4   P-15006     2022 Power Punch Salad prep       1   PORT              N
# 5   P-16795  2022 Pulled Pork Sandwich prep       1   PORT              N
# 6   P-14552     2022 Vegan Pulled Pork Prep       1     ea              N
# 7   P-18327          2023 Appi Platter prep       1   PORT              N
# 8   P-18453      2023 GM Tempeh curry prep        1   PORT              N
# 9   P-18451      2023 Gm truffle Fries prep       1   PORT              N
# 10  P-18452          2023 Gm Yam fries prep       1   PORT              N
# 11  P-18540      2023 Home made burger prep       1     ea              N
# 12  P-18397     2023 Mixed Green salad prep       1     ea              N
# 13  P-18275          Beets salad prep 2023        1   PORT              N
# 14  P-15019       Butter Chicken Prep 2023        1   PORT              N
# 15  P-17366      Chicken Teriyaki Prep 2023       1   PORT              Y
# 16  P-18316       Crispy EggPlant prep 2023       3   PORT              Y
# 17  P-18266           KFC Gallery prep 2022       1   PORT              N
# 18  P-18324                Nachos prep 2023       1   PORT              N
# 19  P-18295         Pesto chicken prep 2022       1   PORT              N
# 20  P-18335                 Poboy Prep 2023      22   PORT              Y
# 21  P-14553      Porch Prep Vegan Cole Slaw       1   PORT              N
# 22   P-4326                   PREP AVOCADO        1     ea              N
# 23  P-14352            PREP CALIFORNIA ROLL       1   PORT              N
# 24   P-8267           PREP CARMALIZED ONION      10   2 KG              N
# 25  P-14411           PREP CATERPILLAR ROLL       1   PORT              N
# 26  P-14383          PREP CHICKEN TERI ROLL       1   PORT              N
# 27  P-14372             PREP CONDIMEMT MAKI       1   PORT              N
# 28  P-14376            PREP CONDIMENT COMBO       1   PORT              N
# 29   P-8099             PREP CONDIMENT ROLL       1   srvg              N
# 30  P-15606             PREP CONTAINER MAKI       1   PORT              N
# 31  P-14403               PREP CREAM CHEESE      12   PORT              N
# 32  P-14353              PREP DYNAMITE ROLL       1   PORT              N
# 33  P-14396                 PREP HOUSE ROLL       1   PORT              N
# 34  P-14430             PREP MANGO&AVO ROLL       1   PORT              N
# 35  P-14413          PREP PHILADELPHIA ROLL       1   PORT              N
# 36  P-14360                PREP SALMON MAKI       1   PORT              N
# 37   P-3173          PREP SUSHI RICE COOKED      58   PORT              N
# 38  P-14354                PREP TEMPURA YAM       1   PORT              N
# 39  P-14357                  PREP TUNA MAKI       1   PORT              N
# 40  P-14369                PREP VEGGIE ROLL       1   PORT              N
# 41  P-14355                   PREP YAM ROLL       1   PORT              N
# 42  P-18358       Sub Onion Rings prep 2023       1     ea              N
# 43  P-18361     Sub Truffle fries 2023 Prep       1     ea              N
# 44  P-18296       Teriyaki Tempeh Prep 2023       1   PORT              N
# 45  P-18330                Tuscan Prep 2023       1   PORT              N
# 46  P-15013                 Wings Prep 2023       1   PORT              Y
# 47  P-18313             Yam Fries prep 2023       1   PORT              N
# 48  P-18049     Yellow Curry Prep Gall.2023       1   PORT              Y
#
#           StdQty StdUom
# 0    1511.820000      g
# 1     433.590000      g
# 2     501.820000      g
# 3     705.800000      g
# 4     416.730000      g
# 5     525.090000      g
# 6     479.380000      g
# 7    1354.570000      g
# 8     690.000000      g
# 9    2756.000000      g
# 10   2630.460000      g
# 11    501.250000      g
# 12    769.370000      g
# 13    384.000000      g
# 14    619.800000      g
# 15    707.970000      g
# 16    933.000000      g
# 17    569.900000      g
# 18    754.340000      g
# 19    612.360000      g
# 20   5170.000000      g
# 21     84.820000      g
# 22     20.100000      g
# 23    265.850000      g
# 24  49869.000000      g
# 25    368.500000      g
# 26    310.640000      g
# 27     23.170000      g
# 28     32.170000      g
# 29     37.340000      g
# 30     24.790000      g
# 31    450.000000      g
# 32    296.560000      g
# 33    428.400000      g
# 34    312.990000      g
# 35    335.170000      g
# 36    248.470000      g
# 37   7100.000000      g
# 38     46.800000      g
# 39    248.470000      g
# 40    319.298000      g
# 41    259.440000      g
# 42    247.823824      g
# 43    272.773820      g
# 44    761.120236      g
# 45    703.800000      g
# 46    500.040059      g
# 47    499.500000      g
# 48    709.906236      g

# %% [markdown]
# ***
#
# ## New Items

# %%
# Load current Items List with assigned Emission Factors Category ID
Items_Assigned = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "Items_List_Assigned.csv"))
Items_Assigned.head()
# Out:
#     ItemId  CategoryID          Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0   I-1971          35                LIMES     0.25      ea     1.0     ea
# 1   I-8228          55     Grey Goose 1.14L     1.00   fl oz     1.0  fl oz
# 2  I-15803          31  Red Bull Watermelon     1.00     can     1.0    can
# 3   I-5505          36   Lettuce - Romaine      0.25    HEAD     1.0   HEAD
# 4   I-8667          58     ITEM GARLIC MAYO     2.00   fl oz     1.0     ml
#
#   InventoryGroup
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N

# %%
Items_Assigned.shape
# Out:
# (456, 8)

# %%
Items_Assigned["InventoryGroup"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
Items_Assigned["CategoryID"].unique()
# Out:
# array([35, 55, 31, 36, 58, 24, 16,  3, 40,  8, 38, 48, 54, 44, 18, 32, 56,
#        61, 20, 39, 43, 37,  5, 26, 25,  9,  4, 22,  6, 49, 12, 50, 41, 17,
#        57, 11, 34,  1, 45, 42, 46, 10, 51, 53, 21, 28,  7, 13, 30])

# %%
Items_Assigned[Items_Assigned["CategoryID"] == 55]
# Out:
#       ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 1     I-8228          55                Grey Goose 1.14L      1.0   fl oz
# 33    I-2640          55                     Water - Tap    250.0      ml
# 92   I-13817          55                  FRENCH AUS JUS    490.0       g
# 102  I-15592          55           JUICE ORANGE CONC 6+1    500.0      ml
# 121   I-3036          55                    MIRIN 5.28GL    720.0      ml
# 171   I-2103          55        PEACH SLCD IN PEAR JUICE    300.0      ml
# 172   I-6204          55     Juice - Lime Fresh Squeezed     30.0       g
# 212  I-17946          55         JUICE orange 100% tetra      1.0       L
# 228   I-6203          55    Juice - Lemon Fresh Squeezed     50.0       g
# 270  I-17129          55                   Boiling Water   3000.0       g
# 274   I-5981          55                Aperol Aperitivo      6.0       L
# 284   I-6182          55             BIB - Coca-Cola 20L      1.0       L
# 285   I-6189          55             BIB - Coke Zero 10L      1.0       L
# 286   I-6188          55  BIB -Canada Dry Ginger Ale 10L      1.0       L
# 287   I-6185          55                BIB - Nestea 20L      1.0       L
# 288  I-12929          55                BIB- Sprite 10L       1.0       L
# 289   I-6224          55           BIB - Tonic Water 12L      1.0       L
# 319   I-7335          55     Tea Assam Brkfst Two Leaves      3.0      ea
# 373   I-1081          55                   GRAND MARNIER    375.0      ml
# 388   I-9117          55       Sawmill Creek - White 16L      1.8       L
# 390   I-7801          55         Sawmill Creek - Red 16L      7.5       L
# 392   I-1471          55          Kronenbourg 1664 Blanc      1.0  bottle
# 441   I-1052          55              BACARDI LIGHT RUM     200.0      ml
# 442   I-1945          55             JUICE PINEAPPLE CAN    350.0      ml
# 444   I-5960          55                  St Remy Brandy    150.0      ml
# 447   I-1093          55                   MALIBU liquor    375.0      ml
# 448   I-1109          55            Meagher's Triple Sec    375.0      ml
# 450  I-16601          55          Sawmill Creek -Rose 4L      8.0       L
#
#      PakQty  PakUOM InventoryGroup
# 1       1.0   fl oz              N
# 33      2.5      ml              N
# 92      5.0       g              N
# 102    13.0      ml              N
# 121  2100.0   fl oz              N
# 171   300.0      ml              N
# 172   300.0      oz              N
# 212     6.0      ml              Y
# 228     1.2      oz              Y
# 270  2000.0       g              N
# 274    18.0   fl oz              Y
# 284     6.0   fl oz              N
# 285     6.0   fl oz              N
# 286     6.0   fl oz              N
# 287     6.0   fl oz              N
# 288     6.0   fl oz              N
# 289     6.0   fl oz              N
# 319     4.0      ea              N
# 373    13.0   fl oz              Y
# 388     2.0   fl oz              N
# 390   400.0   fl oz              N
# 392     0.6  bottle              N
# 441    18.5   fl oz              Y
# 442    18.5      ml              Y
# 444    18.5   fl oz              Y
# 447    18.0   fl oz              Y
# 448    18.0   fl oz              Y
# 450    18.0   fl oz              Y

# %% [markdown]
# ### Get the List of New Items

# %%
# Filter new items by itemID that are not in the database and output them in a dataframe
col_names = list(Items.columns.values)
New_Items_List = []

for index, row in Items.iterrows():
    ItemId = Items.loc[index,'ItemId']
    if ItemId not in Items_Assigned['ItemId'].values:
        Dict = {}
        Dict.update(dict(row))
        New_Items_List.append(Dict)

New_Items = pd.DataFrame(New_Items_List, columns = col_names)

# %%
New_Items.insert(1, "CategoryID", '')
New_Items
# Out:
#       ItemId CategoryID                    Description  CaseQty CaseUOM  \
# 0    I-11706                      Glry Side Fries 2023      1.0      ea
# 1    I-16780                2022 Vegan Caesar dressing      1.5   fl oz
# 2    I-14715                         2022 Coleslaw mix      7.0      oz
# 3    I-15427                       Vegan Chipotle Mayo      2.0   fl oz
# 4    I-13956                                Sushi Rice      6.0    PORT
# ..       ...        ...                            ...      ...     ...
# 98   I-13398                            BIB Mix Sprite      1.0       L
# 99   I-13955                                  Sushi Su      1.0       L
# 100  I-13736                  2019 Ginger Garlic Paste     60.0       g
# 101  I-18348                            Gremolata 2022      5.0       g
# 102  I-15425             G21 Southwest Tofu Scrambled       1.0    PORT
#
#      PakQty PakUOM InventoryGroup
# 0       1.0     ea              N
# 1       1.0  fl oz              N
# 2       1.0     Kg              N
# 3       1.0      L              N
# 4       6.0   PORT              N
# ..      ...    ...            ...
# 98     18.5      L              Y
# 99     50.0      L              N
# 100   500.0     Kg              N
# 101     1.0      g              N
# 102     1.0   PORT              N
#
# [103 rows x 8 columns]

# %%
New_Items.shape
# Out:
# (103, 8)

# %%
# Store the list of new items into .csv file
# If New_Items is not empty then we convert it to a csv file. 
if not New_Items.empty:
    path = os.path.join(os.getcwd(), "data", "mapping", "AMS_data", "new items", str(datetime.date(datetime.now()))+"_New_Items.csv")
    New_Items.to_csv(path, index = False, header = True)

# %%
# AMS version
file2 = pd.read_excel("data/mapping/new items added/AMS_data/New_Items_2023/New_Items_Added_2023-11-28.xlsx")
file2.to_csv("data/mapping/new items added/AMS_data/New_Items_2023/New_Items_Added_2023-11-28.csv", index=False)

# %% [markdown]
# ***
# ## Data Summary

# %%
datasum = pd.DataFrame([New_Items.shape, Preps_Nonstd.shape, Items_Nonstd.shape],
                       columns = ['count', 'columns'], 
                       index = ['New_Items', 'Preps_Nonstd', 'Items_Nonstd'])
datasum
# Out:
#               count  columns
# New_Items       103        8
# Preps_Nonstd     49        7
# Items_Nonstd    134        5

# %%
print(New_Items.columns)
# Out:
# Index(['ItemId', 'CategoryID', 'Description', 'CaseQty', 'CaseUOM', 'PakQty',
#        'PakUOM', 'InventoryGroup'],
#       dtype='object')
